# %%
import tensorflow as tf
import numpy as np
from tensorflow import data
import shutil
import math
from datetime import datetime
from tensorflow.python.feature_column import feature_column

from tensorflow.contrib.learn import learn_runner
from tensorflow.contrib.learn import make_export_strategy

print(tf.__version__)
# Out:
# /Users/khalidsalama/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 1.4.0

# %% [markdown]
# ## Steps to use the TF Experiment APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from .tfrecord files + **feature processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Define an **estimator** (LinearCombinedDNNRegressor) with the required **feature columns (wide/deep) & parameters**
# 5. Define a **serving function** to export the model
# 7. Run an **Experiment** with **learn_runner** to train, evaluate, and export the model
# 8. **Evaluate** the model using test data
# 9. Perform **predictions**

# %%
MODEL_NAME = 'reg-model-06'

TRAIN_DATA_FILES_PATTERN = 'data/train-*.tfrecords'
VALID_DATA_FILES_PATTERN = 'data/valid-*.tfrecords'
TEST_DATA_FILES_PATTERN = 'data/test-*.tfrecords'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## 1. Define Dataset Metadata
# * tf.example feature names and defaults
# * Numeric and categorical feature names
# * Target feature name
# * Unused features

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {}".format(TARGET_NAME))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function
# * Input .tfrecords files name pattern
# * Use TF Dataset APIs to read and process the data
# * Parse tf.exmaples  to feature tensors
# * Apply feature processing
# * Return (features, target) tensors

# %% [markdown]
# ### a. parsing and preprocessing logic

# %%
def parse_tf_example(example_proto):

    feature_spec = {}

    for feature_name in NUMERIC_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)
    
    for feature_name in CATEGORICAL_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(1), dtype=tf.string)
    
    feature_spec[TARGET_NAME] = tf.FixedLenFeature(shape=(1), dtype=tf.float32)

    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    
    target = parsed_features.pop(TARGET_NAME)
    
    return parsed_features, target


def process_features(features):
    
    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
    return features

# %% [markdown]
# ### b. data pipeline input function

# %%
def tfrecods_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TFRecordDataset(filenames=file_names)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example))
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target))
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = tfrecods_input_fn(files_name_pattern="")
print("Feature read from TFRecords: {}".format(list(features.keys())))
print("Target read from TFRecords: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# Feature read from TFRecords: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy']
# Target read from TFRecords: Tensor("IteratorGetNext:8", shape=(?, 1), dtype=float32)

# %% [markdown]
# ## 3. Define Feature Columns

# %%
def extend_feature_columns(feature_columns, hparams):
    
    num_buckets = hparams.num_buckets
    embedding_size = hparams.embedding_size

    buckets = np.linspace(-3, 3, num_buckets).tolist()

    alpha_X_beta = tf.feature_column.crossed_column(
            [feature_columns['alpha'], feature_columns['beta']], 4)

    x_bucketized = tf.feature_column.bucketized_column(
            feature_columns['x'], boundaries=buckets)

    y_bucketized = tf.feature_column.bucketized_column(
            feature_columns['y'], boundaries=buckets)

    x_bucketized_X_y_bucketized = tf.feature_column.crossed_column(
           [x_bucketized, y_bucketized], num_buckets**2)

    x_bucketized_X_y_bucketized_embedded = tf.feature_column.embedding_column(
            x_bucketized_X_y_bucketized, dimension=embedding_size)


    feature_columns['alpha_X_beta'] = alpha_X_beta
    feature_columns['x_bucketized_X_y_bucketized'] = x_bucketized_X_y_bucketized
    feature_columns['x_bucketized_X_y_bucketized_embedded'] = x_bucketized_X_y_bucketized_embedded
    
    return feature_columns
    

def get_feature_columns(hparams):
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if PROCESS_FEATURES:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), 'x_bucketized_X_y_bucketized': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), 'x_bucketized_X_y_bucketized_embedded': _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x121d57b00>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)}

# %% [markdown]
# ## 4. Define an Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns
# * dense columns = numeric columns + embedding columns
# * categorical columns = vocabolary list columns + bucketized columns
# * sparse columns = hashed categorical columns + crossed columns
# * categorical columns => indicator columns
# * deep columns = dense columns + indicator columns
# * wide columns = categorical columns + sparse columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %%
def create_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedRegressor(
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.elu,
        dnn_dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 5. Define Serving Funcion

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='rows_string_tensor')
    
    receiver_tensor = {'rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))

    return tf.estimator.export.ServingInputReceiver(
        process_features(features), receiver_tensor)

# %% [markdown]
# ## 6. Run Experiment

# %% [markdown]
# ### a. Define Experiment Function

# %%
def generate_experiment_fn(**experiment_args):

    def _experiment_fn(run_config, hparams):

        train_input_fn = lambda: tfrecods_input_fn(
            TRAIN_DATA_FILES_PATTERN,
            mode = tf.contrib.learn.ModeKeys.TRAIN,
            num_epochs=hparams.num_epochs,
            batch_size=hparams.batch_size
        )

        eval_input_fn = lambda: tfrecods_input_fn(
            VALID_DATA_FILES_PATTERN,
            mode=tf.contrib.learn.ModeKeys.EVAL,
            num_epochs=1,
            batch_size=hparams.batch_size
        )

        estimator = create_estimator(run_config, hparams, True)

        return tf.contrib.learn.Experiment(
            estimator,
            train_input_fn=train_input_fn,
            eval_input_fn=eval_input_fn,
            eval_steps=None,
            **experiment_args
        )

    return _experiment_fn

# %% [markdown]
# ### b. Set HParam and RunConfig

# %%
TRAIN_SIZE = 12000
NUM_EPOCHS = 1000
BATCH_SIZE = 500
NUM_EVAL = 10
CHECKPOINT_STEPS = int((TRAIN_SIZE/BATCH_SIZE) * (NUM_EPOCHS/NUM_EVAL))

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units=[16, 12, 8],
    num_buckets = 6,
    embedding_size = 3,
    dropout_prob = 0.001)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.contrib.learn.RunConfig(
    save_checkpoints_steps=CHECKPOINT_STEPS,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS)
print("Required Evaluation Steps:", NUM_EVAL) 
print("That is 1 evaluation step after each",NUM_EPOCHS/NUM_EVAL," epochs")
print("Save Checkpoint After",CHECKPOINT_STEPS,"steps")
# Out:
# [('batch_size', 500), ('dropout_prob', 0.001), ('embedding_size', 3), ('hidden_units', [16, 12, 8]), ('num_buckets', 6), ('num_epochs', 1000)]
# Model Directory: trained_models/reg-model-05
#
# Dataset Size: 12000
# Batch Size: 500
# Steps per Epoch: 24.0
# Total Steps: 24000.0
# Required Evaluation Steps: 10
# That is 1 evaluation step after each, 100.0  epochs
# Save Checkpoint After 2400 steps

# %% [markdown]
# ### c. Run Experiment via learn_runner

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 

    
tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 


learn_runner.run(
    experiment_fn=generate_experiment_fn(

        export_strategies=[make_export_strategy(
            csv_serving_input_fn,
            exports_to_keep=1
        )]
    ),
    run_config=run_config,
    schedule="train_and_evaluate",
    hparams=hparams
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 14:45:02
# .......................................
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x121d3c898>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-05'}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedRegressor'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x121c5fd68>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None)]
#
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From /Users/khalidsalama/anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/reg-model-05/model.ckpt.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:45:14
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:45:15
# INFO:tensorflow:Saving dict for global step 1: average_loss = 323.292, global_step = 1, loss = 161646.0
# INFO:tensorflow:Validation (step 1): average_loss = 323.292, loss = 161646.0, global_step = 1
# INFO:tensorflow:loss = 160565.0, step = 1
# INFO:tensorflow:global_step/sec: 25.4955
# INFO:tensorflow:loss = 137380.0, step = 101 (0.685 sec)
# INFO:tensorflow:global_step/sec: 206.933
# INFO:tensorflow:loss = 126462.0, step = 201 (0.483 sec)
# INFO:tensorflow:global_step/sec: 207.283
# INFO:tensorflow:loss = 102794.0, step = 301 (0.483 sec)
# INFO:tensorflow:global_step/sec: 205.072
# INFO:tensorflow:loss = 80143.5, step = 401 (0.487 sec)
# INFO:tensorflow:global_step/sec: 160.042
# INFO:tensorflow:loss = 67611.3, step = 501 (0.629 sec)
# INFO:tensorflow:global_step/sec: 150.951
# INFO:tensorflow:loss = 64641.8, step = 601 (0.659 sec)
# INFO:tensorflow:global_step/sec: 199.03
# INFO:tensorflow:loss = 70291.3, step = 701 (0.503 sec)
# INFO:tensorflow:global_step/sec: 202.456
# INFO:tensorflow:loss = 61979.2, step = 801 (0.492 sec)
# INFO:tensorflow:global_step/sec: 185.401
# INFO:tensorflow:loss = 55404.9, step = 901 (0.543 sec)
# INFO:tensorflow:global_step/sec: 165.274
# INFO:tensorflow:loss = 49137.8, step = 1001 (0.602 sec)
# INFO:tensorflow:global_step/sec: 180.646
# INFO:tensorflow:loss = 58193.4, step = 1101 (0.554 sec)
# INFO:tensorflow:global_step/sec: 176.889
# INFO:tensorflow:loss = 54016.0, step = 1201 (0.567 sec)
# INFO:tensorflow:global_step/sec: 166.105
# INFO:tensorflow:loss = 47703.1, step = 1301 (0.602 sec)
# INFO:tensorflow:global_step/sec: 184.674
# INFO:tensorflow:loss = 52737.7, step = 1401 (0.540 sec)
# INFO:tensorflow:global_step/sec: 205.924
# INFO:tensorflow:loss = 49361.7, step = 1501 (0.484 sec)
# INFO:tensorflow:global_step/sec: 187.778
# INFO:tensorflow:loss = 60642.4, step = 1601 (0.533 sec)
# INFO:tensorflow:global_step/sec: 164.364
# INFO:tensorflow:loss = 51423.3, step = 1701 (0.612 sec)
# INFO:tensorflow:global_step/sec: 143.142
# INFO:tensorflow:loss = 54290.2, step = 1801 (0.698 sec)
# INFO:tensorflow:global_step/sec: 153.258
# INFO:tensorflow:loss = 45824.4, step = 1901 (0.651 sec)
# INFO:tensorflow:global_step/sec: 141.92
# INFO:tensorflow:loss = 58466.6, step = 2001 (0.706 sec)
# INFO:tensorflow:global_step/sec: 156.183
# INFO:tensorflow:loss = 60018.4, step = 2101 (0.641 sec)
# INFO:tensorflow:global_step/sec: 180.87
# INFO:tensorflow:loss = 41793.5, step = 2201 (0.550 sec)
# INFO:tensorflow:global_step/sec: 184.405
# INFO:tensorflow:loss = 51737.3, step = 2301 (0.540 sec)
# INFO:tensorflow:Saving checkpoints for 2401 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.7504
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:45:33
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-2401
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:45:34
# INFO:tensorflow:Saving dict for global step 2401: average_loss = 110.008, global_step = 2401, loss = 55004.1
# INFO:tensorflow:Validation (step 2401): average_loss = 110.008, loss = 55004.1, global_step = 2401
# INFO:tensorflow:loss = 50533.7, step = 2401 (4.330 sec)
# INFO:tensorflow:global_step/sec: 36.3585
# INFO:tensorflow:loss = 48817.8, step = 2501 (0.607 sec)
# INFO:tensorflow:global_step/sec: 169.122
# INFO:tensorflow:loss = 46738.0, step = 2601 (0.595 sec)
# INFO:tensorflow:global_step/sec: 170.994
# INFO:tensorflow:loss = 41714.2, step = 2701 (0.581 sec)
# INFO:tensorflow:global_step/sec: 197.507
# INFO:tensorflow:loss = 54132.5, step = 2801 (0.507 sec)
# INFO:tensorflow:global_step/sec: 184.968
# INFO:tensorflow:loss = 44191.5, step = 2901 (0.541 sec)
# INFO:tensorflow:global_step/sec: 173.489
# INFO:tensorflow:loss = 61527.9, step = 3001 (0.577 sec)
# INFO:tensorflow:global_step/sec: 163.514
# INFO:tensorflow:loss = 49861.8, step = 3101 (0.611 sec)
# INFO:tensorflow:global_step/sec: 184.718
# INFO:tensorflow:loss = 55832.5, step = 3201 (0.541 sec)
# INFO:tensorflow:global_step/sec: 171.845
# INFO:tensorflow:loss = 47604.0, step = 3301 (0.585 sec)
# INFO:tensorflow:global_step/sec: 199.26
# INFO:tensorflow:loss = 49082.0, step = 3401 (0.499 sec)
# INFO:tensorflow:global_step/sec: 185.356
# INFO:tensorflow:loss = 49985.2, step = 3501 (0.541 sec)
# INFO:tensorflow:global_step/sec: 180.602
# INFO:tensorflow:loss = 54626.0, step = 3601 (0.553 sec)
# INFO:tensorflow:global_step/sec: 173.892
# INFO:tensorflow:loss = 44927.0, step = 3701 (0.573 sec)
# INFO:tensorflow:global_step/sec: 176.442
# INFO:tensorflow:loss = 46833.5, step = 3801 (0.570 sec)
# INFO:tensorflow:global_step/sec: 192.65
# INFO:tensorflow:loss = 52572.5, step = 3901 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.509
# INFO:tensorflow:loss = 47212.6, step = 4001 (0.518 sec)
# INFO:tensorflow:global_step/sec: 178.476
# INFO:tensorflow:loss = 49466.8, step = 4101 (0.560 sec)
# INFO:tensorflow:global_step/sec: 174.755
# INFO:tensorflow:loss = 47623.0, step = 4201 (0.572 sec)
# INFO:tensorflow:global_step/sec: 201.565
# INFO:tensorflow:loss = 43078.1, step = 4301 (0.497 sec)
# INFO:tensorflow:global_step/sec: 184.676
# INFO:tensorflow:loss = 41924.9, step = 4401 (0.541 sec)
# INFO:tensorflow:global_step/sec: 179.369
# INFO:tensorflow:loss = 53805.8, step = 4501 (0.556 sec)
# INFO:tensorflow:global_step/sec: 191.206
# INFO:tensorflow:loss = 49148.4, step = 4601 (0.524 sec)
# INFO:tensorflow:global_step/sec: 197.59
# INFO:tensorflow:loss = 46907.3, step = 4701 (0.506 sec)
# INFO:tensorflow:Saving checkpoints for 4801 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 51.3462
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:45:50
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-4801
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:45:51
# INFO:tensorflow:Saving dict for global step 4801: average_loss = 102.891, global_step = 4801, loss = 51445.6
# INFO:tensorflow:Validation (step 4801): average_loss = 102.891, loss = 51445.6, global_step = 4801
# INFO:tensorflow:loss = 42877.6, step = 4801 (4.714 sec)
# INFO:tensorflow:global_step/sec: 29.4339
# INFO:tensorflow:loss = 48071.3, step = 4901 (0.636 sec)
# INFO:tensorflow:global_step/sec: 160.342
# INFO:tensorflow:loss = 51567.0, step = 5001 (0.621 sec)
# INFO:tensorflow:global_step/sec: 159.741
# INFO:tensorflow:loss = 44414.4, step = 5101 (0.626 sec)
# INFO:tensorflow:global_step/sec: 152.427
# INFO:tensorflow:loss = 43658.1, step = 5201 (0.654 sec)
# INFO:tensorflow:global_step/sec: 147.982
# INFO:tensorflow:loss = 50656.9, step = 5301 (0.676 sec)
# INFO:tensorflow:global_step/sec: 174.017
# INFO:tensorflow:loss = 52793.8, step = 5401 (0.572 sec)
# INFO:tensorflow:global_step/sec: 176.623
# INFO:tensorflow:loss = 43644.4, step = 5501 (0.567 sec)
# INFO:tensorflow:global_step/sec: 173.755
# INFO:tensorflow:loss = 45374.0, step = 5601 (0.576 sec)
# INFO:tensorflow:global_step/sec: 193.095
# INFO:tensorflow:loss = 38881.1, step = 5701 (0.517 sec)
# INFO:tensorflow:global_step/sec: 177.957
# INFO:tensorflow:loss = 47921.4, step = 5801 (0.563 sec)
# INFO:tensorflow:global_step/sec: 172.279
# INFO:tensorflow:loss = 50320.6, step = 5901 (0.579 sec)
# INFO:tensorflow:global_step/sec: 178.266
# INFO:tensorflow:loss = 48902.9, step = 6001 (0.562 sec)
# INFO:tensorflow:global_step/sec: 185.436
# INFO:tensorflow:loss = 46687.1, step = 6101 (0.540 sec)
# INFO:tensorflow:global_step/sec: 179.401
# INFO:tensorflow:loss = 47977.4, step = 6201 (0.557 sec)
# INFO:tensorflow:global_step/sec: 200.033
# INFO:tensorflow:loss = 50965.1, step = 6301 (0.499 sec)
# INFO:tensorflow:global_step/sec: 195.343
# INFO:tensorflow:loss = 43474.4, step = 6401 (0.511 sec)
# INFO:tensorflow:global_step/sec: 193.32
# INFO:tensorflow:loss = 47853.4, step = 6501 (0.517 sec)
# INFO:tensorflow:global_step/sec: 201.989
# INFO:tensorflow:loss = 37000.7, step = 6601 (0.495 sec)
# INFO:tensorflow:global_step/sec: 191.422
# INFO:tensorflow:loss = 47335.7, step = 6701 (0.524 sec)
# INFO:tensorflow:global_step/sec: 203.296
# INFO:tensorflow:loss = 47203.8, step = 6801 (0.492 sec)
# INFO:tensorflow:global_step/sec: 174.699
# INFO:tensorflow:loss = 47441.8, step = 6901 (0.572 sec)
# INFO:tensorflow:global_step/sec: 181.78
# INFO:tensorflow:loss = 40555.8, step = 7001 (0.550 sec)
# INFO:tensorflow:global_step/sec: 173.719
# INFO:tensorflow:loss = 52464.4, step = 7101 (0.575 sec)
# INFO:tensorflow:Saving checkpoints for 7201 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 51.7013
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:46:07
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-7201
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:46:08
# INFO:tensorflow:Saving dict for global step 7201: average_loss = 99.1498, global_step = 7201, loss = 49574.9
# INFO:tensorflow:Validation (step 7201): average_loss = 99.1498, loss = 49574.9, global_step = 7201
# INFO:tensorflow:loss = 54619.5, step = 7201 (3.950 sec)
# INFO:tensorflow:global_step/sec: 38.4549
# INFO:tensorflow:loss = 45446.9, step = 7301 (0.590 sec)
# INFO:tensorflow:global_step/sec: 154.619
# INFO:tensorflow:loss = 45686.4, step = 7401 (0.647 sec)
# INFO:tensorflow:global_step/sec: 157.207
# INFO:tensorflow:loss = 56201.1, step = 7501 (0.633 sec)
# INFO:tensorflow:global_step/sec: 175.571
# INFO:tensorflow:loss = 46456.2, step = 7601 (0.569 sec)
# INFO:tensorflow:global_step/sec: 158.64
# INFO:tensorflow:loss = 35579.1, step = 7701 (0.630 sec)
# INFO:tensorflow:global_step/sec: 186.491
# INFO:tensorflow:loss = 56134.2, step = 7801 (0.537 sec)
# INFO:tensorflow:global_step/sec: 191.123
# INFO:tensorflow:loss = 50404.7, step = 7901 (0.522 sec)
# INFO:tensorflow:global_step/sec: 198.529
# INFO:tensorflow:loss = 41662.1, step = 8001 (0.503 sec)
# INFO:tensorflow:global_step/sec: 199.112
# INFO:tensorflow:loss = 37885.0, step = 8101 (0.502 sec)
# INFO:tensorflow:global_step/sec: 195.357
# INFO:tensorflow:loss = 56509.6, step = 8201 (0.513 sec)
# INFO:tensorflow:global_step/sec: 151.537
# INFO:tensorflow:loss = 32506.5, step = 8301 (0.660 sec)
# INFO:tensorflow:global_step/sec: 176.751
# INFO:tensorflow:loss = 52256.8, step = 8401 (0.566 sec)
# INFO:tensorflow:global_step/sec: 185.525
# INFO:tensorflow:loss = 41784.6, step = 8501 (0.540 sec)
# INFO:tensorflow:global_step/sec: 191.895
# INFO:tensorflow:loss = 41078.5, step = 8601 (0.520 sec)
# INFO:tensorflow:global_step/sec: 201.39
# INFO:tensorflow:loss = 38175.0, step = 8701 (0.496 sec)
# INFO:tensorflow:global_step/sec: 200.671
# INFO:tensorflow:loss = 46965.9, step = 8801 (0.498 sec)
# INFO:tensorflow:global_step/sec: 192.575
# INFO:tensorflow:loss = 40593.2, step = 8901 (0.523 sec)
# INFO:tensorflow:global_step/sec: 179.854
# INFO:tensorflow:loss = 40854.0, step = 9001 (0.552 sec)
# INFO:tensorflow:global_step/sec: 186.547
# INFO:tensorflow:loss = 39758.7, step = 9101 (0.536 sec)
# INFO:tensorflow:global_step/sec: 180.553
# INFO:tensorflow:loss = 42881.7, step = 9201 (0.555 sec)
# INFO:tensorflow:global_step/sec: 178.353
# INFO:tensorflow:loss = 49046.9, step = 9301 (0.559 sec)
# INFO:tensorflow:global_step/sec: 196.553
# INFO:tensorflow:loss = 40224.3, step = 9401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 197.554
# INFO:tensorflow:loss = 40080.3, step = 9501 (0.506 sec)
# INFO:tensorflow:Saving checkpoints for 9601 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 51.5125
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:46:23
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-9601
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:46:24
# INFO:tensorflow:Saving dict for global step 9601: average_loss = 97.5258, global_step = 9601, loss = 48762.9
# INFO:tensorflow:Validation (step 9601): average_loss = 97.5258, loss = 48762.9, global_step = 9601
# INFO:tensorflow:loss = 45880.4, step = 9601 (3.821 sec)
# INFO:tensorflow:global_step/sec: 40.5679
# INFO:tensorflow:loss = 54476.2, step = 9701 (0.587 sec)
# INFO:tensorflow:global_step/sec: 166.797
# INFO:tensorflow:loss = 39617.1, step = 9801 (0.599 sec)
# INFO:tensorflow:global_step/sec: 159.146
# INFO:tensorflow:loss = 45527.9, step = 9901 (0.628 sec)
# INFO:tensorflow:global_step/sec: 172.704
# INFO:tensorflow:loss = 53873.9, step = 10001 (0.580 sec)
# INFO:tensorflow:global_step/sec: 166.38
# INFO:tensorflow:loss = 57278.7, step = 10101 (0.603 sec)
# INFO:tensorflow:global_step/sec: 138.485
# INFO:tensorflow:loss = 45099.1, step = 10201 (0.719 sec)
# INFO:tensorflow:global_step/sec: 160.511
# INFO:tensorflow:loss = 41409.3, step = 10301 (0.624 sec)
# INFO:tensorflow:global_step/sec: 170.82
# INFO:tensorflow:loss = 41310.1, step = 10401 (0.585 sec)
# INFO:tensorflow:global_step/sec: 198.467
# INFO:tensorflow:loss = 45384.8, step = 10501 (0.505 sec)
# INFO:tensorflow:global_step/sec: 168.128
# INFO:tensorflow:loss = 40096.9, step = 10601 (0.595 sec)
# INFO:tensorflow:global_step/sec: 142.281
# INFO:tensorflow:loss = 48378.2, step = 10701 (0.702 sec)
# INFO:tensorflow:global_step/sec: 153.037
# INFO:tensorflow:loss = 56407.7, step = 10801 (0.653 sec)
# INFO:tensorflow:global_step/sec: 171.976
# INFO:tensorflow:loss = 47738.3, step = 10901 (0.581 sec)
# INFO:tensorflow:global_step/sec: 165.925
# INFO:tensorflow:loss = 46867.7, step = 11001 (0.603 sec)
# INFO:tensorflow:global_step/sec: 160.83
# INFO:tensorflow:loss = 54764.1, step = 11101 (0.622 sec)
# INFO:tensorflow:global_step/sec: 171.572
# INFO:tensorflow:loss = 42543.5, step = 11201 (0.584 sec)
# INFO:tensorflow:global_step/sec: 152.716
# INFO:tensorflow:loss = 52642.5, step = 11301 (0.656 sec)
# INFO:tensorflow:global_step/sec: 175.072
# INFO:tensorflow:loss = 45808.1, step = 11401 (0.568 sec)
# INFO:tensorflow:global_step/sec: 150.849
# INFO:tensorflow:loss = 41820.9, step = 11501 (0.665 sec)
# INFO:tensorflow:global_step/sec: 155.389
# INFO:tensorflow:loss = 40484.1, step = 11601 (0.643 sec)
# INFO:tensorflow:global_step/sec: 151.999
# INFO:tensorflow:loss = 39598.3, step = 11701 (0.661 sec)
# INFO:tensorflow:global_step/sec: 165.66
# INFO:tensorflow:loss = 57965.6, step = 11801 (0.602 sec)
# INFO:tensorflow:global_step/sec: 163.992
# INFO:tensorflow:loss = 48617.2, step = 11901 (0.607 sec)
# INFO:tensorflow:Saving checkpoints for 12001 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 47.8173
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:46:42
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-12001
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:46:43
# INFO:tensorflow:Saving dict for global step 12001: average_loss = 96.4267, global_step = 12001, loss = 48213.4
# INFO:tensorflow:Validation (step 12001): average_loss = 96.4267, loss = 48213.4, global_step = 12001
# INFO:tensorflow:loss = 55236.4, step = 12001 (4.422 sec)
# INFO:tensorflow:global_step/sec: 34.3028
# INFO:tensorflow:loss = 45313.8, step = 12101 (0.587 sec)
# INFO:tensorflow:global_step/sec: 154.785
# INFO:tensorflow:loss = 43379.6, step = 12201 (0.644 sec)
# INFO:tensorflow:global_step/sec: 167.53
# INFO:tensorflow:loss = 48620.9, step = 12301 (0.597 sec)
# INFO:tensorflow:global_step/sec: 170.393
# INFO:tensorflow:loss = 46558.2, step = 12401 (0.587 sec)
# INFO:tensorflow:global_step/sec: 174.856
# INFO:tensorflow:loss = 48267.0, step = 12501 (0.571 sec)
# INFO:tensorflow:global_step/sec: 177.053
# INFO:tensorflow:loss = 40267.3, step = 12601 (0.565 sec)
# INFO:tensorflow:global_step/sec: 174.541
# INFO:tensorflow:loss = 49801.9, step = 12701 (0.573 sec)
# INFO:tensorflow:global_step/sec: 173.133
# INFO:tensorflow:loss = 42185.1, step = 12801 (0.577 sec)
# INFO:tensorflow:global_step/sec: 172.264
# INFO:tensorflow:loss = 45847.5, step = 12901 (0.580 sec)
# INFO:tensorflow:global_step/sec: 172.035
# INFO:tensorflow:loss = 46321.4, step = 13001 (0.581 sec)
# INFO:tensorflow:global_step/sec: 168.855
# INFO:tensorflow:loss = 44416.0, step = 13101 (0.593 sec)
# INFO:tensorflow:global_step/sec: 171.921
# INFO:tensorflow:loss = 44067.6, step = 13201 (0.581 sec)
# INFO:tensorflow:global_step/sec: 173.443
# INFO:tensorflow:loss = 38561.8, step = 13301 (0.577 sec)
# INFO:tensorflow:global_step/sec: 140.276
# INFO:tensorflow:loss = 40409.6, step = 13401 (0.716 sec)
# INFO:tensorflow:global_step/sec: 176.33
# INFO:tensorflow:loss = 43440.4, step = 13501 (0.563 sec)
# INFO:tensorflow:global_step/sec: 170.042
# INFO:tensorflow:loss = 42029.1, step = 13601 (0.594 sec)
# INFO:tensorflow:global_step/sec: 185.523
# INFO:tensorflow:loss = 47972.2, step = 13701 (0.533 sec)
# INFO:tensorflow:global_step/sec: 195.89
# INFO:tensorflow:loss = 38532.7, step = 13801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 129.146
# INFO:tensorflow:loss = 46449.1, step = 13901 (0.777 sec)
# INFO:tensorflow:global_step/sec: 139.829
# INFO:tensorflow:loss = 47294.4, step = 14001 (0.712 sec)
# INFO:tensorflow:global_step/sec: 158.638
# INFO:tensorflow:loss = 57022.6, step = 14101 (0.629 sec)
# INFO:tensorflow:global_step/sec: 149.31
# INFO:tensorflow:loss = 38003.8, step = 14201 (0.675 sec)
# INFO:tensorflow:global_step/sec: 182.531
# INFO:tensorflow:loss = 39165.0, step = 14301 (0.543 sec)
# INFO:tensorflow:Saving checkpoints for 14401 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 54.916
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:47:00
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-14401
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:47:01
# INFO:tensorflow:Saving dict for global step 14401: average_loss = 95.66, global_step = 14401, loss = 47830.0
# INFO:tensorflow:Validation (step 14401): average_loss = 95.66, loss = 47830.0, global_step = 14401
# INFO:tensorflow:loss = 50882.2, step = 14401 (3.676 sec)
# INFO:tensorflow:global_step/sec: 41.7528
# INFO:tensorflow:loss = 46333.2, step = 14501 (0.541 sec)
# INFO:tensorflow:global_step/sec: 196.188
# INFO:tensorflow:loss = 45086.0, step = 14601 (0.507 sec)
# INFO:tensorflow:global_step/sec: 198.731
# INFO:tensorflow:loss = 41419.0, step = 14701 (0.503 sec)
# INFO:tensorflow:global_step/sec: 197.854
# INFO:tensorflow:loss = 44981.3, step = 14801 (0.506 sec)
# INFO:tensorflow:global_step/sec: 201.168
# INFO:tensorflow:loss = 47723.4, step = 14901 (0.497 sec)
# INFO:tensorflow:global_step/sec: 203.088
# INFO:tensorflow:loss = 52328.7, step = 15001 (0.492 sec)
# INFO:tensorflow:global_step/sec: 204.508
# INFO:tensorflow:loss = 51222.3, step = 15101 (0.489 sec)
# INFO:tensorflow:global_step/sec: 200.668
# INFO:tensorflow:loss = 34508.5, step = 15201 (0.498 sec)
# INFO:tensorflow:global_step/sec: 198.176
# INFO:tensorflow:loss = 53236.7, step = 15301 (0.505 sec)
# INFO:tensorflow:global_step/sec: 198.048
# INFO:tensorflow:loss = 45037.4, step = 15401 (0.504 sec)
# INFO:tensorflow:global_step/sec: 197.407
# INFO:tensorflow:loss = 52015.6, step = 15501 (0.507 sec)
# INFO:tensorflow:global_step/sec: 182.14
# INFO:tensorflow:loss = 43264.9, step = 15601 (0.550 sec)
# INFO:tensorflow:global_step/sec: 170.018
# INFO:tensorflow:loss = 43633.4, step = 15701 (0.588 sec)
# INFO:tensorflow:global_step/sec: 195.487
# INFO:tensorflow:loss = 29999.6, step = 15801 (0.511 sec)
# INFO:tensorflow:global_step/sec: 178.816
# INFO:tensorflow:loss = 30115.9, step = 15901 (0.562 sec)
# INFO:tensorflow:global_step/sec: 189.557
# INFO:tensorflow:loss = 33335.3, step = 16001 (0.529 sec)
# INFO:tensorflow:global_step/sec: 202.714
# INFO:tensorflow:loss = 47532.6, step = 16101 (0.490 sec)
# INFO:tensorflow:global_step/sec: 204.291
# INFO:tensorflow:loss = 44005.1, step = 16201 (0.489 sec)
# INFO:tensorflow:global_step/sec: 163.117
# INFO:tensorflow:loss = 43327.8, step = 16301 (0.621 sec)
# INFO:tensorflow:global_step/sec: 163.657
# INFO:tensorflow:loss = 48558.7, step = 16401 (0.604 sec)
# INFO:tensorflow:global_step/sec: 211.509
# INFO:tensorflow:loss = 41165.4, step = 16501 (0.473 sec)
# INFO:tensorflow:global_step/sec: 210.604
# INFO:tensorflow:loss = 36233.0, step = 16601 (0.475 sec)
# INFO:tensorflow:global_step/sec: 212.437
# INFO:tensorflow:loss = 38792.4, step = 16701 (0.471 sec)
# INFO:tensorflow:Saving checkpoints for 16801 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 43.2828
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:47:16
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-16801
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:47:17
# INFO:tensorflow:Saving dict for global step 16801: average_loss = 95.2447, global_step = 16801, loss = 47622.3
# INFO:tensorflow:Validation (step 16801): average_loss = 95.2447, loss = 47622.3, global_step = 16801
# INFO:tensorflow:loss = 52536.3, step = 16801 (4.889 sec)
# INFO:tensorflow:global_step/sec: 31.5247
# INFO:tensorflow:loss = 40462.8, step = 16901 (0.597 sec)
# INFO:tensorflow:global_step/sec: 144.156
# INFO:tensorflow:loss = 33229.0, step = 17001 (0.691 sec)
# INFO:tensorflow:global_step/sec: 184.122
# INFO:tensorflow:loss = 47972.6, step = 17101 (0.544 sec)
# INFO:tensorflow:global_step/sec: 139.354
# INFO:tensorflow:loss = 39119.9, step = 17201 (0.717 sec)
# INFO:tensorflow:global_step/sec: 157.674
# INFO:tensorflow:loss = 43013.5, step = 17301 (0.636 sec)
# INFO:tensorflow:global_step/sec: 162.199
# INFO:tensorflow:loss = 48486.6, step = 17401 (0.615 sec)
# INFO:tensorflow:global_step/sec: 148.247
# INFO:tensorflow:loss = 38979.7, step = 17501 (0.676 sec)
# INFO:tensorflow:global_step/sec: 147.192
# INFO:tensorflow:loss = 36704.6, step = 17601 (0.679 sec)
# INFO:tensorflow:global_step/sec: 193.89
# INFO:tensorflow:loss = 38791.8, step = 17701 (0.513 sec)
# INFO:tensorflow:global_step/sec: 191.614
# INFO:tensorflow:loss = 45565.8, step = 17801 (0.521 sec)
# INFO:tensorflow:global_step/sec: 205.222
# INFO:tensorflow:loss = 41375.7, step = 17901 (0.487 sec)
# INFO:tensorflow:global_step/sec: 164.336
# INFO:tensorflow:loss = 49846.4, step = 18001 (0.612 sec)
# INFO:tensorflow:global_step/sec: 139.161
# INFO:tensorflow:loss = 43816.1, step = 18101 (0.719 sec)
# INFO:tensorflow:global_step/sec: 195.748
# INFO:tensorflow:loss = 41038.8, step = 18201 (0.507 sec)
# INFO:tensorflow:global_step/sec: 151.833
# INFO:tensorflow:loss = 42606.4, step = 18301 (0.662 sec)
# INFO:tensorflow:global_step/sec: 137.978
# INFO:tensorflow:loss = 46919.4, step = 18401 (0.724 sec)
# INFO:tensorflow:global_step/sec: 156.665
# INFO:tensorflow:loss = 48936.7, step = 18501 (0.640 sec)
# INFO:tensorflow:global_step/sec: 140.237
# INFO:tensorflow:loss = 45114.6, step = 18601 (0.712 sec)
# INFO:tensorflow:global_step/sec: 180.506
# INFO:tensorflow:loss = 44833.6, step = 18701 (0.551 sec)
# INFO:tensorflow:global_step/sec: 162.557
# INFO:tensorflow:loss = 41944.4, step = 18801 (0.618 sec)
# INFO:tensorflow:global_step/sec: 153.631
# INFO:tensorflow:loss = 46873.4, step = 18901 (0.651 sec)
# INFO:tensorflow:global_step/sec: 202.341
# INFO:tensorflow:loss = 39177.4, step = 19001 (0.493 sec)
# INFO:tensorflow:global_step/sec: 174.699
# INFO:tensorflow:loss = 42203.3, step = 19101 (0.571 sec)
# INFO:tensorflow:Saving checkpoints for 19201 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 51.991
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:47:34
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-19201
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:47:35
# INFO:tensorflow:Saving dict for global step 19201: average_loss = 94.9449, global_step = 19201, loss = 47472.5
# INFO:tensorflow:Validation (step 19201): average_loss = 94.9449, loss = 47472.5, global_step = 19201
# INFO:tensorflow:loss = 47126.2, step = 19201 (3.957 sec)
# INFO:tensorflow:global_step/sec: 38.1811
# INFO:tensorflow:loss = 38006.2, step = 19301 (0.587 sec)
# INFO:tensorflow:global_step/sec: 141.275
# INFO:tensorflow:loss = 32550.4, step = 19401 (0.708 sec)
# INFO:tensorflow:global_step/sec: 176.091
# INFO:tensorflow:loss = 42542.9, step = 19501 (0.570 sec)
# INFO:tensorflow:global_step/sec: 186.699
# INFO:tensorflow:loss = 47292.7, step = 19601 (0.532 sec)
# INFO:tensorflow:global_step/sec: 203.593
# INFO:tensorflow:loss = 43887.2, step = 19701 (0.491 sec)
# INFO:tensorflow:global_step/sec: 210.217
# INFO:tensorflow:loss = 46568.9, step = 19801 (0.475 sec)
# INFO:tensorflow:global_step/sec: 212.603
# INFO:tensorflow:loss = 37989.9, step = 19901 (0.470 sec)
# INFO:tensorflow:global_step/sec: 208.317
# INFO:tensorflow:loss = 47775.5, step = 20001 (0.480 sec)
# INFO:tensorflow:global_step/sec: 207.552
# INFO:tensorflow:loss = 48369.5, step = 20101 (0.482 sec)
# INFO:tensorflow:global_step/sec: 209.95
# INFO:tensorflow:loss = 44663.5, step = 20201 (0.476 sec)
# INFO:tensorflow:global_step/sec: 206.353
# INFO:tensorflow:loss = 43105.0, step = 20301 (0.485 sec)
# INFO:tensorflow:global_step/sec: 200.609
# INFO:tensorflow:loss = 56440.8, step = 20401 (0.499 sec)
# INFO:tensorflow:global_step/sec: 203.679
# INFO:tensorflow:loss = 37120.5, step = 20501 (0.491 sec)
# INFO:tensorflow:global_step/sec: 205.493
# INFO:tensorflow:loss = 40338.2, step = 20601 (0.486 sec)
# INFO:tensorflow:global_step/sec: 205.763
# INFO:tensorflow:loss = 37491.7, step = 20701 (0.486 sec)
# INFO:tensorflow:global_step/sec: 192.961
# INFO:tensorflow:loss = 40886.0, step = 20801 (0.518 sec)
# INFO:tensorflow:global_step/sec: 202.664
# INFO:tensorflow:loss = 55855.6, step = 20901 (0.493 sec)
# INFO:tensorflow:global_step/sec: 207.579
# INFO:tensorflow:loss = 55780.0, step = 21001 (0.482 sec)
# INFO:tensorflow:global_step/sec: 205.296
# INFO:tensorflow:loss = 33775.9, step = 21101 (0.487 sec)
# INFO:tensorflow:global_step/sec: 203.248
# INFO:tensorflow:loss = 35061.5, step = 21201 (0.492 sec)
# INFO:tensorflow:global_step/sec: 205.145
# INFO:tensorflow:loss = 60921.7, step = 21301 (0.488 sec)
# INFO:tensorflow:global_step/sec: 203.466
# INFO:tensorflow:loss = 48460.1, step = 21401 (0.491 sec)
# INFO:tensorflow:global_step/sec: 177.547
# INFO:tensorflow:loss = 38936.8, step = 21501 (0.565 sec)
# INFO:tensorflow:Saving checkpoints for 21601 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:global_step/sec: 53.1405
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:47:50
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-21601
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:47:51
# INFO:tensorflow:Saving dict for global step 21601: average_loss = 94.7711, global_step = 21601, loss = 47385.5
# INFO:tensorflow:Validation (step 21601): average_loss = 94.7711, loss = 47385.5, global_step = 21601
# INFO:tensorflow:loss = 45806.9, step = 21601 (4.215 sec)
# INFO:tensorflow:global_step/sec: 32.8905
# INFO:tensorflow:loss = 48317.0, step = 21701 (0.706 sec)
# INFO:tensorflow:global_step/sec: 160.605
# INFO:tensorflow:loss = 35943.6, step = 21801 (0.628 sec)
# INFO:tensorflow:global_step/sec: 147.104
# INFO:tensorflow:loss = 46075.7, step = 21901 (0.674 sec)
# INFO:tensorflow:global_step/sec: 144.728
# INFO:tensorflow:loss = 41913.2, step = 22001 (0.695 sec)
# INFO:tensorflow:global_step/sec: 141.829
# INFO:tensorflow:loss = 44520.4, step = 22101 (0.702 sec)
# INFO:tensorflow:global_step/sec: 158.356
# INFO:tensorflow:loss = 43243.3, step = 22201 (0.631 sec)
# INFO:tensorflow:global_step/sec: 173.845
# INFO:tensorflow:loss = 51610.5, step = 22301 (0.575 sec)
# INFO:tensorflow:global_step/sec: 196.08
# INFO:tensorflow:loss = 41342.1, step = 22401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 195.075
# INFO:tensorflow:loss = 60272.2, step = 22501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 196.459
# INFO:tensorflow:loss = 44953.5, step = 22601 (0.509 sec)
# INFO:tensorflow:global_step/sec: 199.884
# INFO:tensorflow:loss = 47719.7, step = 22701 (0.500 sec)
# INFO:tensorflow:global_step/sec: 172.587
# INFO:tensorflow:loss = 37863.8, step = 22801 (0.581 sec)
# INFO:tensorflow:global_step/sec: 166.369
# INFO:tensorflow:loss = 37875.9, step = 22901 (0.602 sec)
# INFO:tensorflow:global_step/sec: 153.789
# INFO:tensorflow:loss = 52081.1, step = 23001 (0.651 sec)
# INFO:tensorflow:global_step/sec: 178.575
# INFO:tensorflow:loss = 43988.6, step = 23101 (0.556 sec)
# INFO:tensorflow:global_step/sec: 175.298
# INFO:tensorflow:loss = 47354.2, step = 23201 (0.571 sec)
# INFO:tensorflow:global_step/sec: 196.895
# INFO:tensorflow:loss = 48326.4, step = 23301 (0.507 sec)
# INFO:tensorflow:global_step/sec: 209.103
# INFO:tensorflow:loss = 40898.5, step = 23401 (0.478 sec)
# INFO:tensorflow:global_step/sec: 201.522
# INFO:tensorflow:loss = 34773.8, step = 23501 (0.496 sec)
# INFO:tensorflow:global_step/sec: 182.674
# INFO:tensorflow:loss = 40628.4, step = 23601 (0.548 sec)
# INFO:tensorflow:global_step/sec: 201.766
# INFO:tensorflow:loss = 40137.9, step = 23701 (0.496 sec)
# INFO:tensorflow:global_step/sec: 208.788
# INFO:tensorflow:loss = 51337.3, step = 23801 (0.479 sec)
# INFO:tensorflow:global_step/sec: 208.864
# INFO:tensorflow:loss = 41643.7, step = 23901 (0.479 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/reg-model-05/model.ckpt.
# INFO:tensorflow:Loss for final step: 43364.5.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:48:07
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:48:08
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 94.695, global_step = 24000, loss = 47347.5
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"trained_models/reg-model-05/export/Servo/temp-b'1510411689'/saved_model.pb"
# .......................................
# Experiment finished at 14:48:11
#
# Experiment elapsed time: 189.333083 seconds

# %% [markdown]
# ## 7. Evaluate the Model

# %%
TRAIN_SIZE = 12000
VALID_SIZE = 3000
TEST_SIZE = 5000
train_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

valid_input_fn = lambda: tfrecods_input_fn(files_name_pattern= VALID_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= VALID_SIZE)

test_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
train_rmse = round(math.sqrt(train_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Train RMSE: {} - {}".format(train_rmse, train_results))
print("############################################################################################")

valid_results = estimator.evaluate(input_fn=valid_input_fn, steps=1)
valid_rmse = round(math.sqrt(valid_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Valid RMSE: {} - {}".format(valid_rmse,valid_results))
print("############################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
test_rmse = round(math.sqrt(test_results["average_loss"]),5)
print()
print("############################################################################################")
print("# Test RMSE: {} - {}".format(test_rmse, test_results))
print("############################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x121d3c898>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-05'}
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 12000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:55:50
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:55:51
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 84.8091, global_step = 24000, loss = 1.01771e+06
#
# ############################################################################################
# # Train RMSE: 9.20919 - {'average_loss': 84.809143, 'loss': 1017709.8, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 3000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:55:52
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:55:53
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 94.695, global_step = 24000, loss = 284085.0
#
# ############################################################################################
# # Valid RMSE: 9.73113 - {'average_loss': 94.694977, 'loss': 284084.94, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# INFO:tensorflow:Starting evaluation at 2017-11-11-14:55:54
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-14:55:56
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 96.8167, global_step = 24000, loss = 484083.0
#
# ############################################################################################
# # Test RMSE: 9.83955 - {'average_loss': 96.816666, 'loss': 484083.31, 'global_step': 24000}
# ############################################################################################

# %% [markdown]
# ## 8. Prediction

# %%
import itertools

predict_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)

predictions = estimator.predict(input_fn=predict_input_fn)
values = list(map(lambda item: item["predictions"][0],list(itertools.islice(predictions, 5))))
print()
print("Predicted Values: {}".format(values))
# Out:
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5
# Epoch Count: None
# Mode: infer
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-05/model.ckpt-24000
#
# Predicted Values: [50.291748, -2.9376802, 17.63748, 2.4469378, 2.4902878]
