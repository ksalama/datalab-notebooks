# %%
import tensorflow as tf
import shutil
import math
import multiprocessing
from tensorflow.python.feature_column import feature_column

from tensorflow.contrib.learn import learn_runner
from tensorflow.contrib.learn import make_export_strategy


print(tf.__version__)
# Out:
# 1.3.0

# %% [markdown]
# ## Steps to use the TF Estimator APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from the source + **apply pre-processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Instantiate an **estimator** with the required **feature columns & parameters**
# 5. Define a **serving function**
# 6. Run **Experiment** by supplying training and validation data, as well as required parameters
# 7. **Evaluate** the model using test data
# 8. Perform **predictions**

# %%
train_data_files = 'data/train-*.csv'
valid_data_files = 'data/valid-*.csv'
test_data_files = 'data/test-*.csv'

model_name = 'reg-model-02'

resume = True
train = False

# %% [markdown]
# ## 1. Define Dataset Metadata

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {}".format(TARGET_NAME))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function

# %%
def process_features(features):
    
    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
    return features

# %%
def csv_input_fn(file_names, mode=tf.estimator.ModeKeys.EVAL, 
                 skip_header_lines=0, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    input_file_names = tf.train.match_filenames_once(file_names)
    
    print(input_file_names)

    filename_queue = tf.train.string_input_producer(
        input_file_names, num_epochs=num_epochs, shuffle=shuffle)

    reader = tf.TextLineReader(skip_header_lines=skip_header_lines)

    _, rows = reader.read_up_to(filename_queue, num_records=batch_size)
    
    row_columns = tf.expand_dims(rows, -1)
    columns = tf.decode_csv(row_columns, record_defaults=HEADER_DEFAULTS)
    features = dict(zip(HEADER, columns))
    
    # Remove unused columns
    for column in UNUSED_FEATURE_NAMES:
        features.pop(column)
        
    if shuffle:
        features = tf.train.shuffle_batch(
            features,
            batch_size,
            min_after_dequeue=2 * batch_size + 1,
            capacity=batch_size * 10,
            num_threads=multiprocessing.cpu_count(),
            enqueue_many=True,
            allow_smaller_final_batch=True
        )
    else:
        features = tf.train.batch(
            features,
            batch_size,
            capacity=batch_size * 10,
            num_threads=multiprocessing.cpu_count(),
            enqueue_many=True,
            allow_smaller_final_batch=True
        )

    target = features.pop(TARGET_NAME)
    
    # apply pre-processing
    
#     features["x_2"] = tf.square(features['x'])
#     features["y_2"] = tf.square(features['y'])
#     features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
#     features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
#     return features, target

    return process_features(features), target

# %%
features, target = csv_input_fn(file_names=train_data_files)
print("Feature read from CSV: {}".format(list(features.keys())))
print("Target read from CSV: {}".format(target))
# Out:
# <tf.Variable 'matching_filenames:0' shape=<unknown> dtype=string_ref>
# Feature read from CSV: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy']
# Target read from CSV: Tensor("batch:2", shape=(?, 1), dtype=float32)

# %% [markdown]
# ## 3. Define Feature Columns

# %%
def get_feature_columns():
    
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES + CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
        
    
    # apply feature extentions
    
    feature_columns['alpha_X_beta'] = tf.feature_column.crossed_column(
        [feature_columns['alpha'], feature_columns['beta']], 4)
    
    return feature_columns

feature_columns = get_feature_columns()
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None)}

# %% [markdown]
# ## 4. Instantiate an Estimator

# %%
def create_estimator(run_config, hparams):
    
    feature_columns = list(get_feature_columns().values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    
    estimator = tf.estimator.DNNRegressor(
        
        feature_columns= dense_columns + indicator_columns ,
        hidden_units= hparams.hidden_units,
        
        optimizer= tf.train.AdamOptimizer(),
        activation_fn= tf.nn.elu,
        dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    return estimator

# %% [markdown]
# ## 5. Define Serving Funcion

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='rows_string_tensor')
    
    receiver_tensor = {'rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))

    return tf.estimator.export.ServingInputReceiver(
        process_features(features), receiver_tensor)

# %% [markdown]
# ## 6. Run Experiment

# %%
metrics = {
    'rmse': tf.contrib.learn.MetricSpec(
        metric_fn=tf.metrics.root_mean_squared_error
    )
}

def generate_experiment_fn(**experiment_args):

    def _experiment_fn(run_config, hparams):

        train_input_fn = lambda: csv_input_fn(
            train_data_files,
            mode = tf.contrib.learn.ModeKeys.TRAIN,
            num_epochs=hparams.num_epochs,
            batch_size=hparams.batch_size
        )

        eval_input_fn = lambda: csv_input_fn(
            valid_data_files,
            mode=tf.contrib.learn.ModeKeys.EVAL,
            batch_size=hparams.batch_size
        )

        estimator = create_estimator(run_config, hparams)

        return tf.contrib.learn.Experiment(
            estimator,
            train_input_fn=train_input_fn,
            eval_input_fn=eval_input_fn,
            **experiment_args
        )

    return _experiment_fn

# %%
hparams  = tf.contrib.training.HParams(
    num_epochs = 1000,
    batch_size = 500,
    hidden_units=[8, 4], 
    dropout_prob = 0.1)



model_dir = 'trained_models/{}'.format(model_name)

# run_config = tf.estimator.RunConfig().replace(
#     model_dir=model_dir
# )

run_config = tf.contrib.learn.RunConfig(
            model_dir=model_dir
)

print(run_config.model_dir)

if not resume:
    shutil.rmtree(model_dir, ignore_errors=True)
    
tf.logging.set_verbosity(tf.logging.INFO)

learn_runner.run(
    experiment_fn=generate_experiment_fn(
        
        export_strategies=[make_export_strategy(
            csv_serving_input_fn,
            exports_to_keep=1
        )]
    ),
    run_config=run_config,
    schedule="train_and_evaluate",
    hparams=hparams
)
# Out:
# trained_models/reg-model-02
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11fefa278>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-02'}
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From /Users/khalidsalama/anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:269: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# <tf.Variable 'matching_filenames:0' shape=<unknown> dtype=string_ref>
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/reg-model-02/model.ckpt.
# <tf.Variable 'matching_filenames:0' shape=<unknown> dtype=string_ref>
# INFO:tensorflow:Starting evaluation at 2017-10-27-20:04:39
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-02/model.ckpt-1
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Evaluation [2/100]
# INFO:tensorflow:Evaluation [3/100]
# INFO:tensorflow:Evaluation [4/100]
# INFO:tensorflow:Evaluation [5/100]
# INFO:tensorflow:Evaluation [6/100]
# INFO:tensorflow:Evaluation [7/100]
# INFO:tensorflow:Evaluation [8/100]
# INFO:tensorflow:Evaluation [9/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [11/100]
# INFO:tensorflow:Evaluation [12/100]
# INFO:tensorflow:Evaluation [13/100]
# INFO:tensorflow:Evaluation [14/100]
# INFO:tensorflow:Evaluation [15/100]
# INFO:tensorflow:Evaluation [16/100]
# INFO:tensorflow:Evaluation [17/100]
# INFO:tensorflow:Evaluation [18/100]
# INFO:tensorflow:Evaluation [19/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [21/100]
# INFO:tensorflow:Evaluation [22/100]
# INFO:tensorflow:Evaluation [23/100]
# INFO:tensorflow:Evaluation [24/100]
# INFO:tensorflow:Evaluation [25/100]
# INFO:tensorflow:Evaluation [26/100]
# INFO:tensorflow:Evaluation [27/100]
# INFO:tensorflow:Evaluation [28/100]
# INFO:tensorflow:Evaluation [29/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [31/100]
# INFO:tensorflow:Evaluation [32/100]
# INFO:tensorflow:Evaluation [33/100]
# INFO:tensorflow:Evaluation [34/100]
# INFO:tensorflow:Evaluation [35/100]
# INFO:tensorflow:Evaluation [36/100]
# INFO:tensorflow:Evaluation [37/100]
# INFO:tensorflow:Evaluation [38/100]
# INFO:tensorflow:Evaluation [39/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [41/100]
# INFO:tensorflow:Evaluation [42/100]
# INFO:tensorflow:Evaluation [43/100]
# INFO:tensorflow:Evaluation [44/100]
# INFO:tensorflow:Evaluation [45/100]
# INFO:tensorflow:Evaluation [46/100]
# INFO:tensorflow:Evaluation [47/100]
# INFO:tensorflow:Evaluation [48/100]
# INFO:tensorflow:Evaluation [49/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [51/100]
# INFO:tensorflow:Evaluation [52/100]
# INFO:tensorflow:Evaluation [53/100]
# INFO:tensorflow:Evaluation [54/100]
# INFO:tensorflow:Evaluation [55/100]
# INFO:tensorflow:Evaluation [56/100]
# INFO:tensorflow:Evaluation [57/100]
# INFO:tensorflow:Evaluation [58/100]
# INFO:tensorflow:Evaluation [59/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [61/100]
# INFO:tensorflow:Evaluation [62/100]
# INFO:tensorflow:Evaluation [63/100]
# INFO:tensorflow:Evaluation [64/100]
# INFO:tensorflow:Evaluation [65/100]
# INFO:tensorflow:Evaluation [66/100]
# INFO:tensorflow:Evaluation [67/100]
# INFO:tensorflow:Evaluation [68/100]
# INFO:tensorflow:Evaluation [69/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [71/100]
# INFO:tensorflow:Evaluation [72/100]
# INFO:tensorflow:Evaluation [73/100]
# INFO:tensorflow:Evaluation [74/100]
# INFO:tensorflow:Evaluation [75/100]
# INFO:tensorflow:Evaluation [76/100]
# INFO:tensorflow:Evaluation [77/100]
# INFO:tensorflow:Evaluation [78/100]
# INFO:tensorflow:Evaluation [79/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [81/100]
# INFO:tensorflow:Evaluation [82/100]
# INFO:tensorflow:Evaluation [83/100]
# INFO:tensorflow:Evaluation [84/100]
# INFO:tensorflow:Evaluation [85/100]
# INFO:tensorflow:Evaluation [86/100]
# INFO:tensorflow:Evaluation [87/100]
# INFO:tensorflow:Evaluation [88/100]
# INFO:tensorflow:Evaluation [89/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [91/100]
# INFO:tensorflow:Evaluation [92/100]
# INFO:tensorflow:Evaluation [93/100]
# INFO:tensorflow:Evaluation [94/100]
# INFO:tensorflow:Evaluation [95/100]
# INFO:tensorflow:Evaluation [96/100]
# INFO:tensorflow:Evaluation [97/100]
# INFO:tensorflow:Evaluation [98/100]
# INFO:tensorflow:Evaluation [99/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2017-10-27-20:04:40
# INFO:tensorflow:Saving dict for global step 1: average_loss = 323.157, global_step = 1, loss = 161579.0
# INFO:tensorflow:Validation (step 1): average_loss = 323.157, loss = 161579.0, global_step = 1
# INFO:tensorflow:loss = 144801.0, step = 1
# INFO:tensorflow:global_step/sec: 42.3881
# INFO:tensorflow:loss = 137808.0, step = 101 (0.555 sec)
# INFO:tensorflow:global_step/sec: 180.377
# INFO:tensorflow:loss = 150468.0, step = 201 (0.554 sec)
# INFO:tensorflow:global_step/sec: 182.709
# INFO:tensorflow:loss = 146286.0, step = 301 (0.547 sec)
# INFO:tensorflow:global_step/sec: 188.506
# INFO:tensorflow:loss = 144657.0, step = 401 (0.531 sec)
# INFO:tensorflow:global_step/sec: 204.508
# INFO:tensorflow:loss = 112029.0, step = 501 (0.489 sec)
# INFO:tensorflow:global_step/sec: 200.794
# INFO:tensorflow:loss = 118560.0, step = 601 (0.498 sec)
# INFO:tensorflow:global_step/sec: 202.213
# INFO:tensorflow:loss = 110745.0, step = 701 (0.495 sec)
# INFO:tensorflow:global_step/sec: 199.204
# INFO:tensorflow:loss = 131683.0, step = 801 (0.502 sec)
# INFO:tensorflow:global_step/sec: 203.973
# INFO:tensorflow:loss = 115880.0, step = 901 (0.490 sec)
# INFO:tensorflow:global_step/sec: 200.537
# INFO:tensorflow:loss = 120540.0, step = 1001 (0.499 sec)
# INFO:tensorflow:global_step/sec: 200.235
# INFO:tensorflow:loss = 103338.0, step = 1101 (0.499 sec)
# INFO:tensorflow:global_step/sec: 201.368
# INFO:tensorflow:loss = 104773.0, step = 1201 (0.498 sec)
# INFO:tensorflow:global_step/sec: 205.853
# INFO:tensorflow:loss = 99802.7, step = 1301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 206.369
# INFO:tensorflow:loss = 88123.1, step = 1401 (0.485 sec)
# INFO:tensorflow:global_step/sec: 206.007
# INFO:tensorflow:loss = 88039.4, step = 1501 (0.484 sec)
# INFO:tensorflow:global_step/sec: 200.717
# INFO:tensorflow:loss = 116277.0, step = 1601 (0.498 sec)
# INFO:tensorflow:global_step/sec: 199.542
# INFO:tensorflow:loss = 94504.8, step = 1701 (0.501 sec)
# INFO:tensorflow:global_step/sec: 201.02
# INFO:tensorflow:loss = 96598.0, step = 1801 (0.497 sec)
# INFO:tensorflow:global_step/sec: 200.273
# INFO:tensorflow:loss = 92885.1, step = 1901 (0.500 sec)
# INFO:tensorflow:global_step/sec: 198.703
# INFO:tensorflow:loss = 71519.0, step = 2001 (0.502 sec)
# INFO:tensorflow:global_step/sec: 201.385
# INFO:tensorflow:loss = 108144.0, step = 2101 (0.496 sec)
# INFO:tensorflow:global_step/sec: 196.275
# INFO:tensorflow:loss = 80085.9, step = 2201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 200.418
# INFO:tensorflow:loss = 100920.0, step = 2301 (0.499 sec)
# INFO:tensorflow:global_step/sec: 184.825
# INFO:tensorflow:loss = 91337.6, step = 2401 (0.542 sec)
# INFO:tensorflow:global_step/sec: 154.111
# INFO:tensorflow:loss = 101377.0, step = 2501 (0.648 sec)
# INFO:tensorflow:global_step/sec: 144.617
# INFO:tensorflow:loss = 93422.1, step = 2601 (0.691 sec)
# INFO:tensorflow:global_step/sec: 140.264
# INFO:tensorflow:loss = 85108.5, step = 2701 (0.713 sec)
# INFO:tensorflow:global_step/sec: 157.723
# INFO:tensorflow:loss = 88820.9, step = 2801 (0.637 sec)
# INFO:tensorflow:global_step/sec: 161.031
# INFO:tensorflow:loss = 90817.5, step = 2901 (0.620 sec)
# INFO:tensorflow:global_step/sec: 171.991
# INFO:tensorflow:loss = 92188.9, step = 3001 (0.584 sec)
# INFO:tensorflow:global_step/sec: 187.141
# INFO:tensorflow:loss = 96736.8, step = 3101 (0.532 sec)
# INFO:tensorflow:global_step/sec: 168.392
# INFO:tensorflow:loss = 85701.6, step = 3201 (0.596 sec)
# INFO:tensorflow:global_step/sec: 185.675
# INFO:tensorflow:loss = 81094.4, step = 3301 (0.538 sec)
# INFO:tensorflow:global_step/sec: 184.744
# INFO:tensorflow:loss = 101552.0, step = 3401 (0.539 sec)
# INFO:tensorflow:global_step/sec: 194.539
# INFO:tensorflow:loss = 96798.4, step = 3501 (0.514 sec)
# INFO:tensorflow:global_step/sec: 196.047
# INFO:tensorflow:loss = 64207.4, step = 3601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.266
# INFO:tensorflow:loss = 101845.0, step = 3701 (0.511 sec)
# INFO:tensorflow:global_step/sec: 200.665
# INFO:tensorflow:loss = 92900.1, step = 3801 (0.497 sec)
# INFO:tensorflow:global_step/sec: 193.338
# INFO:tensorflow:loss = 80723.6, step = 3901 (0.517 sec)
# INFO:tensorflow:global_step/sec: 195.746
# INFO:tensorflow:loss = 110036.0, step = 4001 (0.511 sec)
# INFO:tensorflow:global_step/sec: 187.868
# INFO:tensorflow:loss = 87227.4, step = 4101 (0.533 sec)
# INFO:tensorflow:global_step/sec: 195.869
# INFO:tensorflow:loss = 74034.4, step = 4201 (0.510 sec)
# INFO:tensorflow:global_step/sec: 191.992
# INFO:tensorflow:loss = 81908.5, step = 4301 (0.521 sec)
# INFO:tensorflow:global_step/sec: 196.442
# INFO:tensorflow:loss = 81234.8, step = 4401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 196.336
# INFO:tensorflow:loss = 67338.4, step = 4501 (0.509 sec)
# INFO:tensorflow:global_step/sec: 197.737
# INFO:tensorflow:loss = 75386.4, step = 4601 (0.506 sec)
# INFO:tensorflow:global_step/sec: 196.898
# INFO:tensorflow:loss = 81187.7, step = 4701 (0.508 sec)
# INFO:tensorflow:global_step/sec: 195.388
# INFO:tensorflow:loss = 71258.4, step = 4801 (0.511 sec)
# INFO:tensorflow:global_step/sec: 198.095
# INFO:tensorflow:loss = 98716.7, step = 4901 (0.505 sec)
# INFO:tensorflow:global_step/sec: 197.663
# INFO:tensorflow:loss = 78012.7, step = 5001 (0.506 sec)
# INFO:tensorflow:global_step/sec: 195.852
# INFO:tensorflow:loss = 75844.4, step = 5101 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.26
# INFO:tensorflow:loss = 80843.0, step = 5201 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.07
# INFO:tensorflow:loss = 84154.5, step = 5301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 196.4
# INFO:tensorflow:loss = 78669.6, step = 5401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 200.535
# INFO:tensorflow:loss = 85806.6, step = 5501 (0.499 sec)
# INFO:tensorflow:global_step/sec: 195.926
# INFO:tensorflow:loss = 69393.7, step = 5601 (0.510 sec)
# INFO:tensorflow:global_step/sec: 200.84
# INFO:tensorflow:loss = 75361.6, step = 5701 (0.498 sec)
# INFO:tensorflow:global_step/sec: 204.503
# INFO:tensorflow:loss = 86524.0, step = 5801 (0.489 sec)
# INFO:tensorflow:global_step/sec: 194.84
# INFO:tensorflow:loss = 78489.0, step = 5901 (0.513 sec)
# INFO:tensorflow:global_step/sec: 201.349
# INFO:tensorflow:loss = 71597.4, step = 6001 (0.497 sec)
# INFO:tensorflow:global_step/sec: 183.362
# INFO:tensorflow:loss = 80693.3, step = 6101 (0.549 sec)
# INFO:tensorflow:global_step/sec: 162.993
# INFO:tensorflow:loss = 91666.2, step = 6201 (0.611 sec)
# INFO:tensorflow:global_step/sec: 197.931
# INFO:tensorflow:loss = 81948.6, step = 6301 (0.504 sec)
# INFO:tensorflow:global_step/sec: 196.188
# INFO:tensorflow:loss = 80170.5, step = 6401 (0.509 sec)
# INFO:tensorflow:global_step/sec: 166.109
# INFO:tensorflow:loss = 91588.3, step = 6501 (0.603 sec)
# INFO:tensorflow:global_step/sec: 185.223
# INFO:tensorflow:loss = 80734.8, step = 6601 (0.539 sec)
# INFO:tensorflow:global_step/sec: 178.209
# INFO:tensorflow:loss = 94625.3, step = 6701 (0.560 sec)
# INFO:tensorflow:global_step/sec: 175.964
# INFO:tensorflow:loss = 67287.5, step = 6801 (0.568 sec)
# INFO:tensorflow:global_step/sec: 194.818
# INFO:tensorflow:loss = 86490.7, step = 6901 (0.513 sec)
# INFO:tensorflow:global_step/sec: 198.969
# INFO:tensorflow:loss = 69663.5, step = 7001 (0.503 sec)
# INFO:tensorflow:global_step/sec: 196.206
# INFO:tensorflow:loss = 69080.2, step = 7101 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.309
# INFO:tensorflow:loss = 77321.9, step = 7201 (0.515 sec)
# INFO:tensorflow:global_step/sec: 196.098
# INFO:tensorflow:loss = 73948.2, step = 7301 (0.510 sec)
# INFO:tensorflow:global_step/sec: 194.532
# INFO:tensorflow:loss = 75122.5, step = 7401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 198.708
# INFO:tensorflow:loss = 71435.2, step = 7501 (0.503 sec)
# INFO:tensorflow:global_step/sec: 197.727
# INFO:tensorflow:loss = 80269.0, step = 7601 (0.506 sec)
# INFO:tensorflow:global_step/sec: 197.236
# INFO:tensorflow:loss = 78270.7, step = 7701 (0.507 sec)
# INFO:tensorflow:global_step/sec: 194.549
# INFO:tensorflow:loss = 69009.8, step = 7801 (0.513 sec)
# INFO:tensorflow:global_step/sec: 201.647
# INFO:tensorflow:loss = 70011.7, step = 7901 (0.496 sec)
# INFO:tensorflow:global_step/sec: 200.854
# INFO:tensorflow:loss = 68699.4, step = 8001 (0.499 sec)
# INFO:tensorflow:global_step/sec: 200.188
# INFO:tensorflow:loss = 64701.6, step = 8101 (0.500 sec)
# INFO:tensorflow:global_step/sec: 201.125
# INFO:tensorflow:loss = 69813.8, step = 8201 (0.495 sec)
# INFO:tensorflow:global_step/sec: 162.424
# INFO:tensorflow:loss = 71707.5, step = 8301 (0.618 sec)
# INFO:tensorflow:global_step/sec: 178.326
# INFO:tensorflow:loss = 63818.2, step = 8401 (0.559 sec)
# INFO:tensorflow:global_step/sec: 179.277
# INFO:tensorflow:loss = 78772.5, step = 8501 (0.557 sec)
# INFO:tensorflow:global_step/sec: 179.601
# INFO:tensorflow:loss = 83442.0, step = 8601 (0.557 sec)
# INFO:tensorflow:global_step/sec: 194.724
# INFO:tensorflow:loss = 70344.5, step = 8701 (0.514 sec)
# INFO:tensorflow:global_step/sec: 193.892
# INFO:tensorflow:loss = 70847.5, step = 8801 (0.516 sec)
# INFO:tensorflow:global_step/sec: 164.429
# INFO:tensorflow:loss = 83916.2, step = 8901 (0.609 sec)
# INFO:tensorflow:global_step/sec: 133.18
# INFO:tensorflow:loss = 79136.3, step = 9001 (0.751 sec)
# INFO:tensorflow:global_step/sec: 150.354
# INFO:tensorflow:loss = 74964.0, step = 9101 (0.668 sec)
# INFO:tensorflow:global_step/sec: 138.298
# INFO:tensorflow:loss = 72150.5, step = 9201 (0.722 sec)
# INFO:tensorflow:global_step/sec: 150.591
# INFO:tensorflow:loss = 83133.4, step = 9301 (0.665 sec)
# INFO:tensorflow:global_step/sec: 126.873
# INFO:tensorflow:loss = 75777.7, step = 9401 (0.786 sec)
# INFO:tensorflow:global_step/sec: 150.344
# INFO:tensorflow:loss = 79235.6, step = 9501 (0.665 sec)
# INFO:tensorflow:global_step/sec: 143.354
# INFO:tensorflow:loss = 73031.4, step = 9601 (0.701 sec)
# INFO:tensorflow:global_step/sec: 144.951
# INFO:tensorflow:loss = 83355.1, step = 9701 (0.686 sec)
# INFO:tensorflow:global_step/sec: 128.042
# INFO:tensorflow:loss = 62981.7, step = 9801 (0.781 sec)
# INFO:tensorflow:global_step/sec: 160.426
# INFO:tensorflow:loss = 76663.9, step = 9901 (0.624 sec)
# INFO:tensorflow:global_step/sec: 155.658
# INFO:tensorflow:loss = 84008.4, step = 10001 (0.641 sec)
# INFO:tensorflow:global_step/sec: 166.828
# INFO:tensorflow:loss = 61897.5, step = 10101 (0.600 sec)
# INFO:tensorflow:global_step/sec: 148.187
# INFO:tensorflow:loss = 71699.7, step = 10201 (0.674 sec)
# INFO:tensorflow:global_step/sec: 141.341
# INFO:tensorflow:loss = 78250.9, step = 10301 (0.710 sec)
# INFO:tensorflow:global_step/sec: 158.126
# INFO:tensorflow:loss = 67547.0, step = 10401 (0.631 sec)
# INFO:tensorflow:global_step/sec: 168.879
# INFO:tensorflow:loss = 65697.0, step = 10501 (0.592 sec)
# INFO:tensorflow:global_step/sec: 167.481
# INFO:tensorflow:loss = 59458.8, step = 10601 (0.596 sec)
# INFO:tensorflow:global_step/sec: 166.015
# INFO:tensorflow:loss = 80799.3, step = 10701 (0.604 sec)
# INFO:tensorflow:global_step/sec: 168.206
# INFO:tensorflow:loss = 70319.2, step = 10801 (0.593 sec)
# INFO:tensorflow:global_step/sec: 169.677
# INFO:tensorflow:loss = 78176.2, step = 10901 (0.589 sec)
# INFO:tensorflow:global_step/sec: 161.759
# INFO:tensorflow:loss = 80195.8, step = 11001 (0.618 sec)
# INFO:tensorflow:global_step/sec: 155.534
# INFO:tensorflow:loss = 75079.0, step = 11101 (0.643 sec)
# INFO:tensorflow:global_step/sec: 160.829
# INFO:tensorflow:loss = 75492.9, step = 11201 (0.624 sec)
# INFO:tensorflow:global_step/sec: 153.154
# INFO:tensorflow:loss = 66632.2, step = 11301 (0.651 sec)
# INFO:tensorflow:global_step/sec: 162.962
# INFO:tensorflow:loss = 80771.7, step = 11401 (0.614 sec)
# INFO:tensorflow:global_step/sec: 160.097
# INFO:tensorflow:loss = 79693.3, step = 11501 (0.624 sec)
# INFO:tensorflow:global_step/sec: 154.442
# INFO:tensorflow:loss = 79629.8, step = 11601 (0.647 sec)
# INFO:tensorflow:global_step/sec: 154.686
# INFO:tensorflow:loss = 79889.7, step = 11701 (0.648 sec)
# INFO:tensorflow:global_step/sec: 165.306
# INFO:tensorflow:loss = 82053.1, step = 11801 (0.604 sec)
# INFO:tensorflow:global_step/sec: 165.067
# INFO:tensorflow:loss = 68798.9, step = 11901 (0.606 sec)
# INFO:tensorflow:global_step/sec: 169.129
# INFO:tensorflow:loss = 69555.6, step = 12001 (0.592 sec)
# INFO:tensorflow:global_step/sec: 161.813
# INFO:tensorflow:loss = 77160.9, step = 12101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 163.164
# INFO:tensorflow:loss = 94630.8, step = 12201 (0.612 sec)
# INFO:tensorflow:global_step/sec: 164.306
# INFO:tensorflow:loss = 85652.8, step = 12301 (0.608 sec)
# INFO:tensorflow:global_step/sec: 167.494
# INFO:tensorflow:loss = 74132.9, step = 12401 (0.597 sec)
# INFO:tensorflow:global_step/sec: 168.243
# INFO:tensorflow:loss = 79043.3, step = 12501 (0.596 sec)
# INFO:tensorflow:global_step/sec: 158.826
# INFO:tensorflow:loss = 79416.4, step = 12601 (0.630 sec)
# INFO:tensorflow:global_step/sec: 136.318
# INFO:tensorflow:loss = 73825.3, step = 12701 (0.734 sec)
# INFO:tensorflow:global_step/sec: 129.599
# INFO:tensorflow:loss = 57473.9, step = 12801 (0.774 sec)
# INFO:tensorflow:global_step/sec: 136.284
# INFO:tensorflow:loss = 69736.5, step = 12901 (0.733 sec)
# INFO:tensorflow:global_step/sec: 103.745
# INFO:tensorflow:loss = 80035.4, step = 13001 (0.962 sec)
# INFO:tensorflow:global_step/sec: 139.852
# INFO:tensorflow:loss = 72950.9, step = 13101 (0.717 sec)
# INFO:tensorflow:global_step/sec: 151.825
# INFO:tensorflow:loss = 73397.0, step = 13201 (0.657 sec)
# INFO:tensorflow:global_step/sec: 150.295
# INFO:tensorflow:loss = 68390.2, step = 13301 (0.666 sec)
# INFO:tensorflow:global_step/sec: 153.665
# INFO:tensorflow:loss = 67675.4, step = 13401 (0.650 sec)
# INFO:tensorflow:global_step/sec: 129.796
# INFO:tensorflow:loss = 65581.3, step = 13501 (0.771 sec)
# INFO:tensorflow:global_step/sec: 117.295
# INFO:tensorflow:loss = 90777.5, step = 13601 (0.858 sec)
# INFO:tensorflow:global_step/sec: 109.509
# INFO:tensorflow:loss = 87081.4, step = 13701 (0.908 sec)
# INFO:tensorflow:global_step/sec: 117.625
# INFO:tensorflow:loss = 65737.3, step = 13801 (0.848 sec)
# INFO:tensorflow:global_step/sec: 147.219
# INFO:tensorflow:loss = 77283.8, step = 13901 (0.678 sec)
# INFO:tensorflow:global_step/sec: 165.857
# INFO:tensorflow:loss = 68929.3, step = 14001 (0.604 sec)
# INFO:tensorflow:global_step/sec: 143.138
# INFO:tensorflow:loss = 80285.8, step = 14101 (0.700 sec)
# INFO:tensorflow:global_step/sec: 151.233
# INFO:tensorflow:loss = 73249.4, step = 14201 (0.659 sec)
# INFO:tensorflow:global_step/sec: 154.593
# INFO:tensorflow:loss = 65154.4, step = 14301 (0.648 sec)
# INFO:tensorflow:global_step/sec: 163.381
# INFO:tensorflow:loss = 81683.4, step = 14401 (0.610 sec)
# INFO:tensorflow:global_step/sec: 166.671
# INFO:tensorflow:loss = 78299.6, step = 14501 (0.602 sec)
# INFO:tensorflow:global_step/sec: 190.16
# INFO:tensorflow:loss = 81231.3, step = 14601 (0.524 sec)
# INFO:tensorflow:global_step/sec: 179.777
# INFO:tensorflow:loss = 73998.3, step = 14701 (0.558 sec)
# INFO:tensorflow:global_step/sec: 175.68
# INFO:tensorflow:loss = 74538.8, step = 14801 (0.570 sec)
# INFO:tensorflow:global_step/sec: 164.642
# INFO:tensorflow:loss = 95590.0, step = 14901 (0.609 sec)
# INFO:tensorflow:global_step/sec: 167.03
# INFO:tensorflow:loss = 67500.5, step = 15001 (0.597 sec)
# INFO:tensorflow:global_step/sec: 157.245
# INFO:tensorflow:loss = 82010.4, step = 15101 (0.635 sec)
# INFO:tensorflow:global_step/sec: 174.599
# INFO:tensorflow:loss = 79149.2, step = 15201 (0.572 sec)
# INFO:tensorflow:global_step/sec: 187.916
# INFO:tensorflow:loss = 67548.7, step = 15301 (0.533 sec)
# INFO:tensorflow:global_step/sec: 194.243
# INFO:tensorflow:loss = 70798.4, step = 15401 (0.514 sec)
# INFO:tensorflow:global_step/sec: 194.811
# INFO:tensorflow:loss = 79883.4, step = 15501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 181.677
# INFO:tensorflow:loss = 59692.2, step = 15601 (0.553 sec)
# INFO:tensorflow:global_step/sec: 173.424
# INFO:tensorflow:loss = 76202.9, step = 15701 (0.575 sec)
# INFO:tensorflow:global_step/sec: 171.741
# INFO:tensorflow:loss = 69387.2, step = 15801 (0.583 sec)
# INFO:tensorflow:global_step/sec: 168.238
# INFO:tensorflow:loss = 77813.8, step = 15901 (0.596 sec)
# INFO:tensorflow:global_step/sec: 171.009
# INFO:tensorflow:loss = 73390.0, step = 16001 (0.583 sec)
# INFO:tensorflow:global_step/sec: 161.377
# INFO:tensorflow:loss = 82550.3, step = 16101 (0.620 sec)
# INFO:tensorflow:global_step/sec: 163.749
# INFO:tensorflow:loss = 68498.8, step = 16201 (0.611 sec)
# INFO:tensorflow:global_step/sec: 178.905
# INFO:tensorflow:loss = 77579.0, step = 16301 (0.559 sec)
# INFO:tensorflow:global_step/sec: 176.863
# INFO:tensorflow:loss = 72179.4, step = 16401 (0.566 sec)
# INFO:tensorflow:global_step/sec: 169.904
# INFO:tensorflow:loss = 81137.4, step = 16501 (0.588 sec)
# INFO:tensorflow:global_step/sec: 144.905
# INFO:tensorflow:loss = 87279.8, step = 16601 (0.689 sec)
# INFO:tensorflow:global_step/sec: 178.909
# INFO:tensorflow:loss = 83904.4, step = 16701 (0.560 sec)
# INFO:tensorflow:global_step/sec: 181.003
# INFO:tensorflow:loss = 61106.5, step = 16801 (0.552 sec)
# INFO:tensorflow:global_step/sec: 177.922
# INFO:tensorflow:loss = 70056.5, step = 16901 (0.563 sec)
# INFO:tensorflow:global_step/sec: 174.508
# INFO:tensorflow:loss = 59801.2, step = 17001 (0.571 sec)
# INFO:tensorflow:global_step/sec: 164.522
# INFO:tensorflow:loss = 86604.8, step = 17101 (0.608 sec)
# INFO:tensorflow:global_step/sec: 165.679
# INFO:tensorflow:loss = 79414.9, step = 17201 (0.604 sec)
# INFO:tensorflow:global_step/sec: 179.874
# INFO:tensorflow:loss = 81047.7, step = 17301 (0.560 sec)
# INFO:tensorflow:global_step/sec: 174.222
# INFO:tensorflow:loss = 84269.7, step = 17401 (0.572 sec)
# INFO:tensorflow:global_step/sec: 168.591
# INFO:tensorflow:loss = 78460.2, step = 17501 (0.593 sec)
# INFO:tensorflow:global_step/sec: 174.95
# INFO:tensorflow:loss = 84624.2, step = 17601 (0.570 sec)
# INFO:tensorflow:global_step/sec: 167.533
# INFO:tensorflow:loss = 69805.8, step = 17701 (0.600 sec)
# INFO:tensorflow:global_step/sec: 159.616
# INFO:tensorflow:loss = 74612.7, step = 17801 (0.625 sec)
# INFO:tensorflow:global_step/sec: 167.689
# INFO:tensorflow:loss = 76614.5, step = 17901 (0.597 sec)
# INFO:tensorflow:global_step/sec: 149.745
# INFO:tensorflow:loss = 76785.9, step = 18001 (0.667 sec)
# INFO:tensorflow:global_step/sec: 172.797
# INFO:tensorflow:loss = 69008.1, step = 18101 (0.579 sec)
# INFO:tensorflow:global_step/sec: 169.972
# INFO:tensorflow:loss = 80057.7, step = 18201 (0.589 sec)
# INFO:tensorflow:global_step/sec: 175.388
# INFO:tensorflow:loss = 68785.2, step = 18301 (0.567 sec)
# INFO:tensorflow:global_step/sec: 179.866
# INFO:tensorflow:loss = 82229.6, step = 18401 (0.558 sec)
# INFO:tensorflow:global_step/sec: 173.918
# INFO:tensorflow:loss = 76905.6, step = 18501 (0.574 sec)
# INFO:tensorflow:global_step/sec: 188.239
# INFO:tensorflow:loss = 71857.0, step = 18601 (0.531 sec)
# INFO:tensorflow:global_step/sec: 177.186
# INFO:tensorflow:loss = 83739.5, step = 18701 (0.564 sec)
# INFO:tensorflow:global_step/sec: 159.279
# INFO:tensorflow:loss = 66163.5, step = 18801 (0.631 sec)
# INFO:tensorflow:global_step/sec: 154.766
# INFO:tensorflow:loss = 76092.9, step = 18901 (0.646 sec)
# INFO:tensorflow:global_step/sec: 165.109
# INFO:tensorflow:loss = 65668.5, step = 19001 (0.604 sec)
# INFO:tensorflow:global_step/sec: 176.83
# INFO:tensorflow:loss = 77415.8, step = 19101 (0.566 sec)
# INFO:tensorflow:global_step/sec: 179.901
# INFO:tensorflow:loss = 78892.1, step = 19201 (0.556 sec)
# INFO:tensorflow:global_step/sec: 171.652
# INFO:tensorflow:loss = 75692.3, step = 19301 (0.582 sec)
# INFO:tensorflow:global_step/sec: 181.37
# INFO:tensorflow:loss = 67834.8, step = 19401 (0.551 sec)
# INFO:tensorflow:global_step/sec: 176.552
# INFO:tensorflow:loss = 67369.4, step = 19501 (0.566 sec)
# INFO:tensorflow:global_step/sec: 184.675
# INFO:tensorflow:loss = 70623.3, step = 19601 (0.541 sec)
# INFO:tensorflow:global_step/sec: 186.937
# INFO:tensorflow:loss = 72790.2, step = 19701 (0.537 sec)
# INFO:tensorflow:global_step/sec: 177.411
# INFO:tensorflow:loss = 56251.0, step = 19801 (0.563 sec)
# INFO:tensorflow:global_step/sec: 176.231
# INFO:tensorflow:loss = 73118.6, step = 19901 (0.569 sec)
# INFO:tensorflow:global_step/sec: 167.566
# INFO:tensorflow:loss = 64623.1, step = 20001 (0.594 sec)
# INFO:tensorflow:global_step/sec: 187.972
# INFO:tensorflow:loss = 73105.5, step = 20101 (0.533 sec)
# INFO:tensorflow:global_step/sec: 180.093
# INFO:tensorflow:loss = 72255.8, step = 20201 (0.558 sec)
# INFO:tensorflow:global_step/sec: 165.732
# INFO:tensorflow:loss = 60530.2, step = 20301 (0.601 sec)
# INFO:tensorflow:global_step/sec: 177.198
# INFO:tensorflow:loss = 67387.7, step = 20401 (0.563 sec)
# INFO:tensorflow:global_step/sec: 184.304
# INFO:tensorflow:loss = 66620.9, step = 20501 (0.545 sec)
# INFO:tensorflow:global_step/sec: 185.151
# INFO:tensorflow:loss = 68416.3, step = 20601 (0.538 sec)
# INFO:tensorflow:global_step/sec: 177.557
# INFO:tensorflow:loss = 66117.7, step = 20701 (0.562 sec)
# INFO:tensorflow:global_step/sec: 181.83
# INFO:tensorflow:loss = 77605.1, step = 20801 (0.550 sec)
# INFO:tensorflow:global_step/sec: 165.429
# INFO:tensorflow:loss = 80551.6, step = 20901 (0.606 sec)
# INFO:tensorflow:global_step/sec: 157.221
# INFO:tensorflow:loss = 63022.3, step = 21001 (0.636 sec)
# INFO:tensorflow:global_step/sec: 178.669
# INFO:tensorflow:loss = 70865.0, step = 21101 (0.559 sec)
# INFO:tensorflow:global_step/sec: 170.191
# INFO:tensorflow:loss = 60755.6, step = 21201 (0.587 sec)
# INFO:tensorflow:global_step/sec: 176.423
# INFO:tensorflow:loss = 62624.6, step = 21301 (0.569 sec)
# INFO:tensorflow:global_step/sec: 182.963
# INFO:tensorflow:loss = 71006.8, step = 21401 (0.544 sec)
# INFO:tensorflow:global_step/sec: 182.524
# INFO:tensorflow:loss = 73512.0, step = 21501 (0.547 sec)
# INFO:tensorflow:global_step/sec: 181.963
# INFO:tensorflow:loss = 57761.3, step = 21601 (0.550 sec)
# INFO:tensorflow:global_step/sec: 171.559
# INFO:tensorflow:loss = 74867.0, step = 21701 (0.583 sec)
# INFO:tensorflow:global_step/sec: 175.089
# INFO:tensorflow:loss = 82495.6, step = 21801 (0.571 sec)
# INFO:tensorflow:global_step/sec: 171.255
# INFO:tensorflow:loss = 73272.1, step = 21901 (0.585 sec)
# INFO:tensorflow:global_step/sec: 166.849
# INFO:tensorflow:loss = 77213.6, step = 22001 (0.598 sec)
# INFO:tensorflow:global_step/sec: 176.603
# INFO:tensorflow:loss = 78775.0, step = 22101 (0.566 sec)
# INFO:tensorflow:global_step/sec: 178.425
# INFO:tensorflow:loss = 61305.4, step = 22201 (0.561 sec)
# INFO:tensorflow:global_step/sec: 176.02
# INFO:tensorflow:loss = 78344.3, step = 22301 (0.569 sec)
# INFO:tensorflow:global_step/sec: 177.594
# INFO:tensorflow:loss = 74250.6, step = 22401 (0.563 sec)
# INFO:tensorflow:global_step/sec: 184.556
# INFO:tensorflow:loss = 53336.1, step = 22501 (0.541 sec)
# INFO:tensorflow:global_step/sec: 185.044
# INFO:tensorflow:loss = 74132.2, step = 22601 (0.541 sec)
# INFO:tensorflow:global_step/sec: 185.237
# INFO:tensorflow:loss = 70140.5, step = 22701 (0.541 sec)
# INFO:tensorflow:global_step/sec: 181.337
# INFO:tensorflow:loss = 85666.4, step = 22801 (0.552 sec)
# INFO:tensorflow:global_step/sec: 158.623
# INFO:tensorflow:loss = 84886.6, step = 22901 (0.630 sec)
# INFO:tensorflow:global_step/sec: 143.181
# INFO:tensorflow:loss = 61903.4, step = 23001 (0.697 sec)
# INFO:tensorflow:global_step/sec: 155.926
# INFO:tensorflow:loss = 59964.8, step = 23101 (0.641 sec)
# INFO:tensorflow:global_step/sec: 156.607
# INFO:tensorflow:loss = 73811.2, step = 23201 (0.642 sec)
# INFO:tensorflow:global_step/sec: 156.797
# INFO:tensorflow:loss = 64936.4, step = 23301 (0.636 sec)
# INFO:tensorflow:global_step/sec: 171.781
# INFO:tensorflow:loss = 56767.5, step = 23401 (0.580 sec)
# INFO:tensorflow:global_step/sec: 155.983
# INFO:tensorflow:loss = 74199.5, step = 23501 (0.642 sec)
# INFO:tensorflow:global_step/sec: 164.477
# INFO:tensorflow:loss = 69564.2, step = 23601 (0.610 sec)
# INFO:tensorflow:global_step/sec: 179.346
# INFO:tensorflow:loss = 72710.3, step = 23701 (0.554 sec)
# INFO:tensorflow:global_step/sec: 178.484
# INFO:tensorflow:loss = 68234.1, step = 23801 (0.562 sec)
# INFO:tensorflow:global_step/sec: 185.547
# INFO:tensorflow:loss = 87701.0, step = 23901 (0.537 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/reg-model-02/model.ckpt.
# INFO:tensorflow:Loss for final step: 66395.8.
# <tf.Variable 'matching_filenames:0' shape=<unknown> dtype=string_ref>
# INFO:tensorflow:Starting evaluation at 2017-10-27-20:07:01
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-02/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Evaluation [2/100]
# INFO:tensorflow:Evaluation [3/100]
# INFO:tensorflow:Evaluation [4/100]
# INFO:tensorflow:Evaluation [5/100]
# INFO:tensorflow:Evaluation [6/100]
# INFO:tensorflow:Evaluation [7/100]
# INFO:tensorflow:Evaluation [8/100]
# INFO:tensorflow:Evaluation [9/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [11/100]
# INFO:tensorflow:Evaluation [12/100]
# INFO:tensorflow:Evaluation [13/100]
# INFO:tensorflow:Evaluation [14/100]
# INFO:tensorflow:Evaluation [15/100]
# INFO:tensorflow:Evaluation [16/100]
# INFO:tensorflow:Evaluation [17/100]
# INFO:tensorflow:Evaluation [18/100]
# INFO:tensorflow:Evaluation [19/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [21/100]
# INFO:tensorflow:Evaluation [22/100]
# INFO:tensorflow:Evaluation [23/100]
# INFO:tensorflow:Evaluation [24/100]
# INFO:tensorflow:Evaluation [25/100]
# INFO:tensorflow:Evaluation [26/100]
# INFO:tensorflow:Evaluation [27/100]
# INFO:tensorflow:Evaluation [28/100]
# INFO:tensorflow:Evaluation [29/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [31/100]
# INFO:tensorflow:Evaluation [32/100]
# INFO:tensorflow:Evaluation [33/100]
# INFO:tensorflow:Evaluation [34/100]
# INFO:tensorflow:Evaluation [35/100]
# INFO:tensorflow:Evaluation [36/100]
# INFO:tensorflow:Evaluation [37/100]
# INFO:tensorflow:Evaluation [38/100]
# INFO:tensorflow:Evaluation [39/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [41/100]
# INFO:tensorflow:Evaluation [42/100]
# INFO:tensorflow:Evaluation [43/100]
# INFO:tensorflow:Evaluation [44/100]
# INFO:tensorflow:Evaluation [45/100]
# INFO:tensorflow:Evaluation [46/100]
# INFO:tensorflow:Evaluation [47/100]
# INFO:tensorflow:Evaluation [48/100]
# INFO:tensorflow:Evaluation [49/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [51/100]
# INFO:tensorflow:Evaluation [52/100]
# INFO:tensorflow:Evaluation [53/100]
# INFO:tensorflow:Evaluation [54/100]
# INFO:tensorflow:Evaluation [55/100]
# INFO:tensorflow:Evaluation [56/100]
# INFO:tensorflow:Evaluation [57/100]
# INFO:tensorflow:Evaluation [58/100]
# INFO:tensorflow:Evaluation [59/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [61/100]
# INFO:tensorflow:Evaluation [62/100]
# INFO:tensorflow:Evaluation [63/100]
# INFO:tensorflow:Evaluation [64/100]
# INFO:tensorflow:Evaluation [65/100]
# INFO:tensorflow:Evaluation [66/100]
# INFO:tensorflow:Evaluation [67/100]
# INFO:tensorflow:Evaluation [68/100]
# INFO:tensorflow:Evaluation [69/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [71/100]
# INFO:tensorflow:Evaluation [72/100]
# INFO:tensorflow:Evaluation [73/100]
# INFO:tensorflow:Evaluation [74/100]
# INFO:tensorflow:Evaluation [75/100]
# INFO:tensorflow:Evaluation [76/100]
# INFO:tensorflow:Evaluation [77/100]
# INFO:tensorflow:Evaluation [78/100]
# INFO:tensorflow:Evaluation [79/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [81/100]
# INFO:tensorflow:Evaluation [82/100]
# INFO:tensorflow:Evaluation [83/100]
# INFO:tensorflow:Evaluation [84/100]
# INFO:tensorflow:Evaluation [85/100]
# INFO:tensorflow:Evaluation [86/100]
# INFO:tensorflow:Evaluation [87/100]
# INFO:tensorflow:Evaluation [88/100]
# INFO:tensorflow:Evaluation [89/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [91/100]
# INFO:tensorflow:Evaluation [92/100]
# INFO:tensorflow:Evaluation [93/100]
# INFO:tensorflow:Evaluation [94/100]
# INFO:tensorflow:Evaluation [95/100]
# INFO:tensorflow:Evaluation [96/100]
# INFO:tensorflow:Evaluation [97/100]
# INFO:tensorflow:Evaluation [98/100]
# INFO:tensorflow:Evaluation [99/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2017-10-27-20:07:02
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 117.873, global_step = 24000, loss = 58936.4
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-02/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'trained_models/reg-model-02/export/Servo/1509134822/saved_model.pb'
# ({'average_loss': 117.87284, 'global_step': 24000, 'loss': 58936.422},
#  [b'trained_models/reg-model-02/export/Servo/1509134822'])

# %% [markdown]
# ## 6. Evaluate the Model

# %%
test_size = 5000

test_input_fn = lambda: csv_input_fn(file_names= test_data_files, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= test_size)

estimator = create_estimator(run_config, hparams)
results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print("")
print(results)
rmse = round(math.sqrt(results["average_loss"]),5)
print("")
print("RMSE: {}".format(rmse))
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11fefa278>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-02'}
# <tf.Variable 'matching_filenames:0' shape=<unknown> dtype=string_ref>
# INFO:tensorflow:Starting evaluation at 2017-10-27-20:07:51
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-02/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-10-27-20:07:51
# INFO:tensorflow:Saving dict for global step 24000: average_loss = 120.256, global_step = 24000, loss = 601281.0
#
# {'average_loss': 120.25615, 'loss': 601280.75, 'global_step': 24000}
#
# RMSE: 10.96614
