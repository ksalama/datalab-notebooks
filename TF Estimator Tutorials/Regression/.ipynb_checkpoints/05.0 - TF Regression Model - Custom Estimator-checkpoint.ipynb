# %%
import tensorflow as tf
import tensorflow.contrib.data as data
import shutil
import math
import multiprocessing
from tensorflow.python.feature_column import feature_column

from tensorflow.contrib.learn import learn_runner
from tensorflow.contrib.learn import make_export_strategy

print(tf.__version__)
# Out:
# 1.3.0

# %% [markdown]
# ## Steps to use the TF Estimator APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from the source + **apply pre-processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Instantiate an **model function** with the required **feature columns, ops, & parameters**
# 5. Define a **serving function**
# 6. Run **Experiment** by supplying training and validation data, as well as required parameters
# 7. **Evaluate** the model using test data
# 8. Perform **predictions**

# %%
train_data_files = ['data/train-data.csv']
valid_data_files = ['data/valid-data.csv']
test_data_files = ['data/test-data.csv']

model_name = 'reg-model-04'

resume = False
train = True
preprocess = True

# %% [markdown]
# ## 1. Define Dataset Metadata

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {}".format(TARGET_NAME))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function

# %% [markdown]
# ### a. parsing and preprocessing logic

# %%
def parse_csv_row(csv_row):
    
    columns = tf.decode_csv(csv_row, record_defaults=HEADER_DEFAULTS)
    features = dict(zip(HEADER, columns))
    
    for column in UNUSED_FEATURE_NAMES:
        features.pop(column)
    
    target = features.pop(TARGET_NAME)

    return features, target

def process_features(features):
    
    if preprocess:
        features["x_2"] = tf.square(features['x'])
        features["y_2"] = tf.square(features['y'])
        features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
        features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
    return features

# %% [markdown]
# ### b. data pipeline input function

# %%
def csv_input_fn(file_names, mode=tf.estimator.ModeKeys.EVAL, 
                 skip_header_lines=0, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False

    dataset = data.TextLineDataset(filenames=file_names)
    dataset = dataset.skip(skip_header_lines)
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda csv_row: parse_csv_row(csv_row))
    dataset = dataset.map(lambda features, target: (process_features(features), target))
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = csv_input_fn(file_names=train_data_files)
print("Feature read from CSV: {}".format(list(features.keys())))
print("Target read from CSV: {}".format(target))
# Out:
# Feature read from CSV: ['alpha', 'beta', 'dist_xy', 'x', 'x_2', 'xy', 'y', 'y_2']
# Target read from CSV: Tensor("IteratorGetNext:8", shape=(?,), dtype=float32)

# %% [markdown]
# ## 3. Define Feature Columns

# %%
def get_feature_columns():
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if preprocess:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
        
    
    # apply feature extentions
    
    feature_columns['alpha_X_beta'] = tf.feature_column.crossed_column(
        [feature_columns['alpha'], feature_columns['beta']], 4)
    
    return feature_columns

feature_columns = get_feature_columns()
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None)}

# %% [markdown]
# ## 4. Define Model Function

# %%
def regression_model_fn(features, labels, mode, params):

    hidden_units = params.hidden_units
    output_layer_size = 1

    feature_columns = list(get_feature_columns().values())

    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )


    # Create the input layers from the features
    input_layer = tf.feature_column.input_layer(features= features, 
                                                feature_columns= dense_columns+indicator_columns)

#     # Create only 1 hidden layer based on the first element of the hidden_units in the params
#     hidden_layer_size = hidden_units[0]

#     # Connect the input layer to the hidden layer
#     hidden_layer = tf.layers.dense(inputs= input_layer, 
#                                    units=hidden_layer_size, 
#                                    activation=tf.nn.relu)

    # Create a fully-connected layer-stack based on the hidden_units in the params
    hidden_layers = tf.contrib.layers.stack(inputs= input_layer,
                                            layer= tf.contrib.layers.fully_connected,
                                            stack_args= hidden_units)

    # Connect the output layer (logits) to the hidden layer (no activation fn)
    logits = tf.layers.dense(inputs=hidden_layers, 
                             units=output_layer_size)

    # Reshape output layer to 1-dim Tensor to return predictions
    output = tf.squeeze(logits)

    # Provide an estimator spec for `ModeKeys.PREDICT`.
    if mode == tf.estimator.ModeKeys.PREDICT:

        predictions = {
            'scores': output
        }

        export_outputs = {
            'predictions': tf.estimator.export.PredictOutput(predictions)
        }

        return tf.estimator.EstimatorSpec(
            mode=mode,
            predictions=predictions,
            export_outputs=export_outputs)

    # Calculate loss using mean squared error
    loss = tf.losses.mean_squared_error(labels, output)

    # Create Optimiser
    optimizer = tf.train.AdamOptimizer()

    # Create training operation
    train_op = optimizer.minimize(
        loss=loss, global_step=tf.train.get_global_step())

    # Calculate root mean squared error as additional eval metric
    eval_metric_ops = {
        "rmse": tf.metrics.root_mean_squared_error(
            labels, output)
    }

    # Provide an estimator spec for `ModeKeys.EVAL` and `ModeKeys.TRAIN` modes.
    estimator_spec = tf.estimator.EstimatorSpec(mode=mode,
                                                loss=loss,
                                                train_op=train_op,
                                                eval_metric_ops=eval_metric_ops)
    return estimator_spec


def create_estimator(run_config, hparams):
    return tf.estimator.Estimator(model_fn=regression_model_fn, 
                                  params=hparams, 
                                  config=run_config)

# %% [markdown]
# ## 5. Define Serving Funcion

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='rows_string_tensor')
    
    receiver_tensor = {'rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))

    return tf.estimator.export.ServingInputReceiver(
        process_features(features), receiver_tensor)

# %% [markdown]
# ## 6. Run Experiment

# %% [markdown]
# ### a. Define Experiment Function

# %%
def generate_experiment_fn(**experiment_args):

    def _experiment_fn(run_config, hparams):

        train_input_fn = lambda: csv_input_fn(
            train_data_files,
            mode = tf.contrib.learn.ModeKeys.TRAIN,
            num_epochs=hparams.num_epochs,
            batch_size=hparams.batch_size
        )

        eval_input_fn = lambda: csv_input_fn(
            valid_data_files,
            mode=tf.contrib.learn.ModeKeys.EVAL,
            batch_size=hparams.batch_size
        )

        estimator = create_estimator(run_config, hparams)

        return tf.contrib.learn.Experiment(
            estimator,
            train_input_fn=train_input_fn,
            eval_input_fn=eval_input_fn,
            **experiment_args
        )

    return _experiment_fn

# %% [markdown]
# ### b. Set HParam and RunConfig

# %%
hparams  = tf.contrib.training.HParams(
    num_epochs = 1000,
    batch_size = 500,
    hidden_units=[8, 4], 
    dropout_prob = 0.1)

model_dir = 'trained_models/{}'.format(model_name)

run_config = tf.contrib.learn.RunConfig(
            model_dir=model_dir
)

print(run_config.model_dir)
# Out:
# trained_models/reg-model-04

# %% [markdown]
# ### c. Run Experiment via learn_runner

# %%
if not resume:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 

if train:
    tf.logging.set_verbosity(tf.logging.INFO)
    
    print("")
    print("Starting experiment...") 
    print("") 
    
    learn_runner.run(
        experiment_fn=generate_experiment_fn(

            export_strategies=[make_export_strategy(
                csv_serving_input_fn,
                exports_to_keep=1
            )]
        ),
        run_config=run_config,
        schedule="train_and_evaluate",
        hparams=hparams
    )
    
    print("") 
    print("experiment finished...")
# Out:
# Removing previous artifacts...
#
# Starting experiment...
#
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11d1919b0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-04'}
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From /Users/khalidsalama/anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:269: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/reg-model-04/model.ckpt.
# INFO:tensorflow:Starting evaluation at 2017-10-29-19:57:34
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-04/model.ckpt-1
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Evaluation [2/100]
# INFO:tensorflow:Evaluation [3/100]
# INFO:tensorflow:Evaluation [4/100]
# INFO:tensorflow:Evaluation [5/100]
# INFO:tensorflow:Evaluation [6/100]
# INFO:tensorflow:Evaluation [7/100]
# INFO:tensorflow:Evaluation [8/100]
# INFO:tensorflow:Evaluation [9/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [11/100]
# INFO:tensorflow:Evaluation [12/100]
# INFO:tensorflow:Evaluation [13/100]
# INFO:tensorflow:Evaluation [14/100]
# INFO:tensorflow:Evaluation [15/100]
# INFO:tensorflow:Evaluation [16/100]
# INFO:tensorflow:Evaluation [17/100]
# INFO:tensorflow:Evaluation [18/100]
# INFO:tensorflow:Evaluation [19/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [21/100]
# INFO:tensorflow:Evaluation [22/100]
# INFO:tensorflow:Evaluation [23/100]
# INFO:tensorflow:Evaluation [24/100]
# INFO:tensorflow:Evaluation [25/100]
# INFO:tensorflow:Evaluation [26/100]
# INFO:tensorflow:Evaluation [27/100]
# INFO:tensorflow:Evaluation [28/100]
# INFO:tensorflow:Evaluation [29/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [31/100]
# INFO:tensorflow:Evaluation [32/100]
# INFO:tensorflow:Evaluation [33/100]
# INFO:tensorflow:Evaluation [34/100]
# INFO:tensorflow:Evaluation [35/100]
# INFO:tensorflow:Evaluation [36/100]
# INFO:tensorflow:Evaluation [37/100]
# INFO:tensorflow:Evaluation [38/100]
# INFO:tensorflow:Evaluation [39/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [41/100]
# INFO:tensorflow:Evaluation [42/100]
# INFO:tensorflow:Evaluation [43/100]
# INFO:tensorflow:Evaluation [44/100]
# INFO:tensorflow:Evaluation [45/100]
# INFO:tensorflow:Evaluation [46/100]
# INFO:tensorflow:Evaluation [47/100]
# INFO:tensorflow:Evaluation [48/100]
# INFO:tensorflow:Evaluation [49/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [51/100]
# INFO:tensorflow:Evaluation [52/100]
# INFO:tensorflow:Evaluation [53/100]
# INFO:tensorflow:Evaluation [54/100]
# INFO:tensorflow:Evaluation [55/100]
# INFO:tensorflow:Evaluation [56/100]
# INFO:tensorflow:Evaluation [57/100]
# INFO:tensorflow:Evaluation [58/100]
# INFO:tensorflow:Evaluation [59/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [61/100]
# INFO:tensorflow:Evaluation [62/100]
# INFO:tensorflow:Evaluation [63/100]
# INFO:tensorflow:Evaluation [64/100]
# INFO:tensorflow:Evaluation [65/100]
# INFO:tensorflow:Evaluation [66/100]
# INFO:tensorflow:Evaluation [67/100]
# INFO:tensorflow:Evaluation [68/100]
# INFO:tensorflow:Evaluation [69/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [71/100]
# INFO:tensorflow:Evaluation [72/100]
# INFO:tensorflow:Evaluation [73/100]
# INFO:tensorflow:Evaluation [74/100]
# INFO:tensorflow:Evaluation [75/100]
# INFO:tensorflow:Evaluation [76/100]
# INFO:tensorflow:Evaluation [77/100]
# INFO:tensorflow:Evaluation [78/100]
# INFO:tensorflow:Evaluation [79/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [81/100]
# INFO:tensorflow:Evaluation [82/100]
# INFO:tensorflow:Evaluation [83/100]
# INFO:tensorflow:Evaluation [84/100]
# INFO:tensorflow:Evaluation [85/100]
# INFO:tensorflow:Evaluation [86/100]
# INFO:tensorflow:Evaluation [87/100]
# INFO:tensorflow:Evaluation [88/100]
# INFO:tensorflow:Evaluation [89/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [91/100]
# INFO:tensorflow:Evaluation [92/100]
# INFO:tensorflow:Evaluation [93/100]
# INFO:tensorflow:Evaluation [94/100]
# INFO:tensorflow:Evaluation [95/100]
# INFO:tensorflow:Evaluation [96/100]
# INFO:tensorflow:Evaluation [97/100]
# INFO:tensorflow:Evaluation [98/100]
# INFO:tensorflow:Evaluation [99/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2017-10-29-19:57:36
# INFO:tensorflow:Saving dict for global step 1: global_step = 1, loss = 324.035, rmse = 18.001
# INFO:tensorflow:Validation (step 1): loss = 324.035, rmse = 18.001, global_step = 1
# INFO:tensorflow:loss = 330.229, step = 1
# INFO:tensorflow:global_step/sec: 20.8829
# INFO:tensorflow:loss = 302.459, step = 101 (0.858 sec)
# INFO:tensorflow:global_step/sec: 136.727
# INFO:tensorflow:loss = 279.311, step = 201 (0.731 sec)
# INFO:tensorflow:global_step/sec: 141.232
# INFO:tensorflow:loss = 287.845, step = 301 (0.708 sec)
# INFO:tensorflow:global_step/sec: 133.78
# INFO:tensorflow:loss = 251.275, step = 401 (0.748 sec)
# INFO:tensorflow:global_step/sec: 133.418
# INFO:tensorflow:loss = 230.43, step = 501 (0.749 sec)
# INFO:tensorflow:global_step/sec: 99.0815
# INFO:tensorflow:loss = 237.118, step = 601 (1.010 sec)
# INFO:tensorflow:global_step/sec: 127.159
# INFO:tensorflow:loss = 177.798, step = 701 (0.787 sec)
# INFO:tensorflow:global_step/sec: 132.569
# INFO:tensorflow:loss = 212.532, step = 801 (0.754 sec)
# INFO:tensorflow:global_step/sec: 134.465
# INFO:tensorflow:loss = 214.413, step = 901 (0.743 sec)
# INFO:tensorflow:global_step/sec: 135.676
# INFO:tensorflow:loss = 187.046, step = 1001 (0.737 sec)
# INFO:tensorflow:global_step/sec: 140.147
# INFO:tensorflow:loss = 140.653, step = 1101 (0.713 sec)
# INFO:tensorflow:global_step/sec: 138.049
# INFO:tensorflow:loss = 142.419, step = 1201 (0.725 sec)
# INFO:tensorflow:global_step/sec: 137.905
# INFO:tensorflow:loss = 140.697, step = 1301 (0.725 sec)
# INFO:tensorflow:global_step/sec: 141.896
# INFO:tensorflow:loss = 123.64, step = 1401 (0.704 sec)
# INFO:tensorflow:global_step/sec: 143.251
# INFO:tensorflow:loss = 137.042, step = 1501 (0.698 sec)
# INFO:tensorflow:global_step/sec: 148.154
# INFO:tensorflow:loss = 120.813, step = 1601 (0.675 sec)
# INFO:tensorflow:global_step/sec: 157.63
# INFO:tensorflow:loss = 113.628, step = 1701 (0.634 sec)
# INFO:tensorflow:global_step/sec: 150.154
# INFO:tensorflow:loss = 117.044, step = 1801 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.945
# INFO:tensorflow:loss = 96.3455, step = 1901 (0.662 sec)
# INFO:tensorflow:global_step/sec: 152.138
# INFO:tensorflow:loss = 93.4612, step = 2001 (0.657 sec)
# INFO:tensorflow:global_step/sec: 150.994
# INFO:tensorflow:loss = 109.805, step = 2101 (0.662 sec)
# INFO:tensorflow:global_step/sec: 147.92
# INFO:tensorflow:loss = 113.176, step = 2201 (0.677 sec)
# INFO:tensorflow:global_step/sec: 141.428
# INFO:tensorflow:loss = 106.91, step = 2301 (0.707 sec)
# INFO:tensorflow:global_step/sec: 144.936
# INFO:tensorflow:loss = 122.054, step = 2401 (0.690 sec)
# INFO:tensorflow:global_step/sec: 143.356
# INFO:tensorflow:loss = 125.605, step = 2501 (0.697 sec)
# INFO:tensorflow:global_step/sec: 140.908
# INFO:tensorflow:loss = 112.001, step = 2601 (0.710 sec)
# INFO:tensorflow:global_step/sec: 149.374
# INFO:tensorflow:loss = 99.0871, step = 2701 (0.669 sec)
# INFO:tensorflow:global_step/sec: 128.477
# INFO:tensorflow:loss = 97.7146, step = 2801 (0.779 sec)
# INFO:tensorflow:global_step/sec: 125.089
# INFO:tensorflow:loss = 115.12, step = 2901 (0.799 sec)
# INFO:tensorflow:global_step/sec: 131.757
# INFO:tensorflow:loss = 99.0083, step = 3001 (0.759 sec)
# INFO:tensorflow:global_step/sec: 118.013
# INFO:tensorflow:loss = 90.8786, step = 3101 (0.847 sec)
# INFO:tensorflow:global_step/sec: 145.937
# INFO:tensorflow:loss = 112.087, step = 3201 (0.685 sec)
# INFO:tensorflow:global_step/sec: 148.126
# INFO:tensorflow:loss = 100.422, step = 3301 (0.675 sec)
# INFO:tensorflow:global_step/sec: 151.065
# INFO:tensorflow:loss = 105.145, step = 3401 (0.662 sec)
# INFO:tensorflow:global_step/sec: 150.198
# INFO:tensorflow:loss = 100.598, step = 3501 (0.665 sec)
# INFO:tensorflow:global_step/sec: 145.582
# INFO:tensorflow:loss = 110.852, step = 3601 (0.687 sec)
# INFO:tensorflow:global_step/sec: 146.474
# INFO:tensorflow:loss = 93.2669, step = 3701 (0.683 sec)
# INFO:tensorflow:global_step/sec: 141.12
# INFO:tensorflow:loss = 85.7701, step = 3801 (0.708 sec)
# INFO:tensorflow:global_step/sec: 146.409
# INFO:tensorflow:loss = 100.847, step = 3901 (0.683 sec)
# INFO:tensorflow:global_step/sec: 147.625
# INFO:tensorflow:loss = 85.2093, step = 4001 (0.678 sec)
# INFO:tensorflow:global_step/sec: 147.123
# INFO:tensorflow:loss = 99.81, step = 4101 (0.679 sec)
# INFO:tensorflow:global_step/sec: 146.245
# INFO:tensorflow:loss = 90.3055, step = 4201 (0.684 sec)
# INFO:tensorflow:global_step/sec: 146.472
# INFO:tensorflow:loss = 105.904, step = 4301 (0.683 sec)
# INFO:tensorflow:global_step/sec: 139.082
# INFO:tensorflow:loss = 80.0945, step = 4401 (0.719 sec)
# INFO:tensorflow:global_step/sec: 151.808
# INFO:tensorflow:loss = 98.467, step = 4501 (0.659 sec)
# INFO:tensorflow:global_step/sec: 150.716
# INFO:tensorflow:loss = 102.546, step = 4601 (0.663 sec)
# INFO:tensorflow:global_step/sec: 148.669
# INFO:tensorflow:loss = 91.4817, step = 4701 (0.673 sec)
# INFO:tensorflow:global_step/sec: 139.307
# INFO:tensorflow:loss = 94.4223, step = 4801 (0.718 sec)
# INFO:tensorflow:global_step/sec: 142.338
# INFO:tensorflow:loss = 101.714, step = 4901 (0.702 sec)
# INFO:tensorflow:global_step/sec: 143.485
# INFO:tensorflow:loss = 91.6776, step = 5001 (0.697 sec)
# INFO:tensorflow:global_step/sec: 140.468
# INFO:tensorflow:loss = 87.9008, step = 5101 (0.711 sec)
# INFO:tensorflow:global_step/sec: 147.58
# INFO:tensorflow:loss = 100.663, step = 5201 (0.678 sec)
# INFO:tensorflow:global_step/sec: 147.352
# INFO:tensorflow:loss = 99.9111, step = 5301 (0.678 sec)
# INFO:tensorflow:global_step/sec: 148.539
# INFO:tensorflow:loss = 119.75, step = 5401 (0.673 sec)
# INFO:tensorflow:global_step/sec: 148.915
# INFO:tensorflow:loss = 94.4453, step = 5501 (0.672 sec)
# INFO:tensorflow:global_step/sec: 152.553
# INFO:tensorflow:loss = 111.509, step = 5601 (0.656 sec)
# INFO:tensorflow:global_step/sec: 138.927
# INFO:tensorflow:loss = 112.305, step = 5701 (0.720 sec)
# INFO:tensorflow:global_step/sec: 133.443
# INFO:tensorflow:loss = 103.16, step = 5801 (0.748 sec)
# INFO:tensorflow:global_step/sec: 130.683
# INFO:tensorflow:loss = 119.697, step = 5901 (0.766 sec)
# INFO:tensorflow:global_step/sec: 116.809
# INFO:tensorflow:loss = 97.5569, step = 6001 (0.856 sec)
# INFO:tensorflow:global_step/sec: 137.258
# INFO:tensorflow:loss = 112.883, step = 6101 (0.728 sec)
# INFO:tensorflow:global_step/sec: 144.211
# INFO:tensorflow:loss = 93.7395, step = 6201 (0.693 sec)
# INFO:tensorflow:global_step/sec: 147.99
# INFO:tensorflow:loss = 85.9967, step = 6301 (0.676 sec)
# INFO:tensorflow:global_step/sec: 148.808
# INFO:tensorflow:loss = 102.521, step = 6401 (0.672 sec)
# INFO:tensorflow:global_step/sec: 151.495
# INFO:tensorflow:loss = 112.454, step = 6501 (0.660 sec)
# INFO:tensorflow:global_step/sec: 153.97
# INFO:tensorflow:loss = 106.087, step = 6601 (0.650 sec)
# INFO:tensorflow:global_step/sec: 148.063
# INFO:tensorflow:loss = 103.81, step = 6701 (0.675 sec)
# INFO:tensorflow:global_step/sec: 146.06
# INFO:tensorflow:loss = 96.2263, step = 6801 (0.685 sec)
# INFO:tensorflow:global_step/sec: 148.007
# INFO:tensorflow:loss = 97.4425, step = 6901 (0.676 sec)
# INFO:tensorflow:global_step/sec: 152.047
# INFO:tensorflow:loss = 102.061, step = 7001 (0.658 sec)
# INFO:tensorflow:global_step/sec: 150.874
# INFO:tensorflow:loss = 95.2338, step = 7101 (0.663 sec)
# INFO:tensorflow:global_step/sec: 127.819
# INFO:tensorflow:loss = 82.1205, step = 7201 (0.782 sec)
# INFO:tensorflow:global_step/sec: 143.398
# INFO:tensorflow:loss = 102.429, step = 7301 (0.697 sec)
# INFO:tensorflow:global_step/sec: 119.92
# INFO:tensorflow:loss = 69.0874, step = 7401 (0.834 sec)
# INFO:tensorflow:global_step/sec: 143.37
# INFO:tensorflow:loss = 102.859, step = 7501 (0.697 sec)
# INFO:tensorflow:global_step/sec: 150.51
# INFO:tensorflow:loss = 81.9313, step = 7601 (0.664 sec)
# INFO:tensorflow:global_step/sec: 141.469
# INFO:tensorflow:loss = 99.7235, step = 7701 (0.707 sec)
# INFO:tensorflow:global_step/sec: 146.848
# INFO:tensorflow:loss = 107.659, step = 7801 (0.681 sec)
# INFO:tensorflow:global_step/sec: 145.922
# INFO:tensorflow:loss = 112.447, step = 7901 (0.685 sec)
# INFO:tensorflow:global_step/sec: 152.994
# INFO:tensorflow:loss = 89.2538, step = 8001 (0.654 sec)
# INFO:tensorflow:global_step/sec: 145.38
# INFO:tensorflow:loss = 106.296, step = 8101 (0.688 sec)
# INFO:tensorflow:global_step/sec: 150.029
# INFO:tensorflow:loss = 77.8856, step = 8201 (0.667 sec)
# INFO:tensorflow:global_step/sec: 150.564
# INFO:tensorflow:loss = 98.722, step = 8301 (0.664 sec)
# INFO:tensorflow:global_step/sec: 154.839
# INFO:tensorflow:loss = 100.607, step = 8401 (0.646 sec)
# INFO:tensorflow:global_step/sec: 151.247
# INFO:tensorflow:loss = 106.85, step = 8501 (0.661 sec)
# INFO:tensorflow:global_step/sec: 155.842
# INFO:tensorflow:loss = 85.4205, step = 8601 (0.642 sec)
# INFO:tensorflow:global_step/sec: 150.381
# INFO:tensorflow:loss = 86.3569, step = 8701 (0.665 sec)
# INFO:tensorflow:global_step/sec: 150.239
# INFO:tensorflow:loss = 106.172, step = 8801 (0.666 sec)
# INFO:tensorflow:global_step/sec: 148.771
# INFO:tensorflow:loss = 93.7512, step = 8901 (0.672 sec)
# INFO:tensorflow:global_step/sec: 149.562
# INFO:tensorflow:loss = 92.4537, step = 9001 (0.668 sec)
# INFO:tensorflow:global_step/sec: 146.223
# INFO:tensorflow:loss = 78.3385, step = 9101 (0.684 sec)
# INFO:tensorflow:global_step/sec: 152.883
# INFO:tensorflow:loss = 91.6304, step = 9201 (0.654 sec)
# INFO:tensorflow:global_step/sec: 147.477
# INFO:tensorflow:loss = 90.2825, step = 9301 (0.678 sec)
# INFO:tensorflow:global_step/sec: 150.185
# INFO:tensorflow:loss = 90.266, step = 9401 (0.666 sec)
# INFO:tensorflow:global_step/sec: 147.801
# INFO:tensorflow:loss = 86.2829, step = 9501 (0.676 sec)
# INFO:tensorflow:global_step/sec: 148.762
# INFO:tensorflow:loss = 91.914, step = 9601 (0.672 sec)
# INFO:tensorflow:global_step/sec: 144.548
# INFO:tensorflow:loss = 87.3686, step = 9701 (0.692 sec)
# INFO:tensorflow:global_step/sec: 152.718
# INFO:tensorflow:loss = 103.258, step = 9801 (0.655 sec)
# INFO:tensorflow:global_step/sec: 147.271
# INFO:tensorflow:loss = 106.461, step = 9901 (0.679 sec)
# INFO:tensorflow:global_step/sec: 152.028
# INFO:tensorflow:loss = 70.8816, step = 10001 (0.658 sec)
# INFO:tensorflow:global_step/sec: 149.31
# INFO:tensorflow:loss = 100.971, step = 10101 (0.670 sec)
# INFO:tensorflow:global_step/sec: 155.218
# INFO:tensorflow:loss = 108.786, step = 10201 (0.644 sec)
# INFO:tensorflow:global_step/sec: 140.347
# INFO:tensorflow:loss = 86.6553, step = 10301 (0.713 sec)
# INFO:tensorflow:global_step/sec: 115.915
# INFO:tensorflow:loss = 100.532, step = 10401 (0.863 sec)
# INFO:tensorflow:global_step/sec: 142.849
# INFO:tensorflow:loss = 109.598, step = 10501 (0.700 sec)
# INFO:tensorflow:global_step/sec: 152.902
# INFO:tensorflow:loss = 95.3725, step = 10601 (0.654 sec)
# INFO:tensorflow:global_step/sec: 150.09
# INFO:tensorflow:loss = 78.9049, step = 10701 (0.668 sec)
# INFO:tensorflow:global_step/sec: 148.211
# INFO:tensorflow:loss = 102.396, step = 10801 (0.673 sec)
# INFO:tensorflow:global_step/sec: 147.563
# INFO:tensorflow:loss = 81.6907, step = 10901 (0.678 sec)
# INFO:tensorflow:global_step/sec: 151.324
# INFO:tensorflow:loss = 90.6469, step = 11001 (0.661 sec)
# INFO:tensorflow:global_step/sec: 146.475
# INFO:tensorflow:loss = 86.505, step = 11101 (0.683 sec)
# INFO:tensorflow:global_step/sec: 149.298
# INFO:tensorflow:loss = 73.0328, step = 11201 (0.670 sec)
# INFO:tensorflow:global_step/sec: 151.31
# INFO:tensorflow:loss = 91.617, step = 11301 (0.661 sec)
# INFO:tensorflow:global_step/sec: 156.91
# INFO:tensorflow:loss = 106.425, step = 11401 (0.637 sec)
# INFO:tensorflow:global_step/sec: 154.961
# INFO:tensorflow:loss = 98.8104, step = 11501 (0.645 sec)
# INFO:tensorflow:global_step/sec: 156.563
# INFO:tensorflow:loss = 90.868, step = 11601 (0.639 sec)
# INFO:tensorflow:global_step/sec: 143.684
# INFO:tensorflow:loss = 100.791, step = 11701 (0.696 sec)
# INFO:tensorflow:global_step/sec: 145.266
# INFO:tensorflow:loss = 99.4279, step = 11801 (0.688 sec)
# INFO:tensorflow:global_step/sec: 150.992
# INFO:tensorflow:loss = 101.837, step = 11901 (0.662 sec)
# INFO:tensorflow:global_step/sec: 94.5234
# INFO:tensorflow:loss = 110.169, step = 12001 (1.059 sec)
# INFO:tensorflow:global_step/sec: 134.259
# INFO:tensorflow:loss = 111.614, step = 12101 (0.744 sec)
# INFO:tensorflow:global_step/sec: 151.113
# INFO:tensorflow:loss = 99.4724, step = 12201 (0.662 sec)
# INFO:tensorflow:global_step/sec: 152.426
# INFO:tensorflow:loss = 94.0161, step = 12301 (0.656 sec)
# INFO:tensorflow:global_step/sec: 151.227
# INFO:tensorflow:loss = 82.0076, step = 12401 (0.661 sec)
# INFO:tensorflow:global_step/sec: 150.735
# INFO:tensorflow:loss = 93.9586, step = 12501 (0.663 sec)
# INFO:tensorflow:global_step/sec: 147.896
# INFO:tensorflow:loss = 81.6096, step = 12601 (0.676 sec)
# INFO:tensorflow:global_step/sec: 153.195
# INFO:tensorflow:loss = 99.7233, step = 12701 (0.653 sec)
# INFO:tensorflow:global_step/sec: 142.364
# INFO:tensorflow:loss = 96.3768, step = 12801 (0.702 sec)
# INFO:tensorflow:global_step/sec: 153.796
# INFO:tensorflow:loss = 97.6808, step = 12901 (0.651 sec)
# INFO:tensorflow:global_step/sec: 145.479
# INFO:tensorflow:loss = 90.7168, step = 13001 (0.687 sec)
# INFO:tensorflow:global_step/sec: 153.89
# INFO:tensorflow:loss = 87.1863, step = 13101 (0.650 sec)
# INFO:tensorflow:global_step/sec: 150.822
# INFO:tensorflow:loss = 85.1545, step = 13201 (0.663 sec)
# INFO:tensorflow:global_step/sec: 152.681
# INFO:tensorflow:loss = 94.1071, step = 13301 (0.655 sec)
# INFO:tensorflow:global_step/sec: 145.847
# INFO:tensorflow:loss = 105.315, step = 13401 (0.686 sec)
# INFO:tensorflow:global_step/sec: 138.146
# INFO:tensorflow:loss = 73.0871, step = 13501 (0.724 sec)
# INFO:tensorflow:global_step/sec: 137.094
# INFO:tensorflow:loss = 95.7385, step = 13601 (0.729 sec)
# INFO:tensorflow:global_step/sec: 134.986
# INFO:tensorflow:loss = 94.3546, step = 13701 (0.741 sec)
# INFO:tensorflow:global_step/sec: 144.826
# INFO:tensorflow:loss = 92.7802, step = 13801 (0.692 sec)
# INFO:tensorflow:global_step/sec: 150.399
# INFO:tensorflow:loss = 85.4734, step = 13901 (0.664 sec)
# INFO:tensorflow:global_step/sec: 148.091
# INFO:tensorflow:loss = 84.6264, step = 14001 (0.675 sec)
# INFO:tensorflow:global_step/sec: 151.066
# INFO:tensorflow:loss = 78.9539, step = 14101 (0.662 sec)
# INFO:tensorflow:global_step/sec: 145.883
# INFO:tensorflow:loss = 79.2954, step = 14201 (0.686 sec)
# INFO:tensorflow:global_step/sec: 142.696
# INFO:tensorflow:loss = 108.639, step = 14301 (0.701 sec)
# INFO:tensorflow:global_step/sec: 153.427
# INFO:tensorflow:loss = 93.1124, step = 14401 (0.652 sec)
# INFO:tensorflow:global_step/sec: 149.095
# INFO:tensorflow:loss = 90.1644, step = 14501 (0.670 sec)
# INFO:tensorflow:global_step/sec: 144.658
# INFO:tensorflow:loss = 86.569, step = 14601 (0.691 sec)
# INFO:tensorflow:global_step/sec: 140.419
# INFO:tensorflow:loss = 82.2626, step = 14701 (0.712 sec)
# INFO:tensorflow:global_step/sec: 148.366
# INFO:tensorflow:loss = 95.8612, step = 14801 (0.674 sec)
# INFO:tensorflow:global_step/sec: 108.409
# INFO:tensorflow:loss = 78.1068, step = 14901 (0.924 sec)
# INFO:tensorflow:global_step/sec: 138.689
# INFO:tensorflow:loss = 96.2311, step = 15001 (0.720 sec)
# INFO:tensorflow:global_step/sec: 142.356
# INFO:tensorflow:loss = 110.424, step = 15101 (0.703 sec)
# INFO:tensorflow:global_step/sec: 136.968
# INFO:tensorflow:loss = 85.3034, step = 15201 (0.730 sec)
# INFO:tensorflow:global_step/sec: 146.964
# INFO:tensorflow:loss = 79.4133, step = 15301 (0.680 sec)
# INFO:tensorflow:global_step/sec: 152.459
# INFO:tensorflow:loss = 92.9031, step = 15401 (0.656 sec)
# INFO:tensorflow:global_step/sec: 147.39
# INFO:tensorflow:loss = 98.4854, step = 15501 (0.678 sec)
# INFO:tensorflow:global_step/sec: 152.295
# INFO:tensorflow:loss = 108.426, step = 15601 (0.657 sec)
# INFO:tensorflow:global_step/sec: 155.259
# INFO:tensorflow:loss = 74.767, step = 15701 (0.644 sec)
# INFO:tensorflow:global_step/sec: 149.73
# INFO:tensorflow:loss = 80.6949, step = 15801 (0.668 sec)
# INFO:tensorflow:global_step/sec: 149.363
# INFO:tensorflow:loss = 85.291, step = 15901 (0.670 sec)
# INFO:tensorflow:global_step/sec: 149.558
# INFO:tensorflow:loss = 96.5879, step = 16001 (0.669 sec)
# INFO:tensorflow:global_step/sec: 136.946
# INFO:tensorflow:loss = 97.653, step = 16101 (0.730 sec)
# INFO:tensorflow:global_step/sec: 147.815
# INFO:tensorflow:loss = 77.4148, step = 16201 (0.677 sec)
# INFO:tensorflow:global_step/sec: 146.939
# INFO:tensorflow:loss = 88.7152, step = 16301 (0.680 sec)
# INFO:tensorflow:global_step/sec: 149.501
# INFO:tensorflow:loss = 86.0502, step = 16401 (0.669 sec)
# INFO:tensorflow:global_step/sec: 150.63
# INFO:tensorflow:loss = 116.81, step = 16501 (0.664 sec)
# INFO:tensorflow:global_step/sec: 152.852
# INFO:tensorflow:loss = 100.284, step = 16601 (0.654 sec)
# INFO:tensorflow:global_step/sec: 151.055
# INFO:tensorflow:loss = 108.675, step = 16701 (0.662 sec)
# INFO:tensorflow:global_step/sec: 152.73
# INFO:tensorflow:loss = 91.5111, step = 16801 (0.655 sec)
# INFO:tensorflow:global_step/sec: 150.664
# INFO:tensorflow:loss = 66.285, step = 16901 (0.663 sec)
# INFO:tensorflow:global_step/sec: 145.637
# INFO:tensorflow:loss = 67.5014, step = 17001 (0.687 sec)
# INFO:tensorflow:global_step/sec: 153.201
# INFO:tensorflow:loss = 88.96, step = 17101 (0.653 sec)
# INFO:tensorflow:global_step/sec: 150.074
# INFO:tensorflow:loss = 98.0362, step = 17201 (0.666 sec)
# INFO:tensorflow:global_step/sec: 151.912
# INFO:tensorflow:loss = 98.4418, step = 17301 (0.658 sec)
# INFO:tensorflow:global_step/sec: 149.012
# INFO:tensorflow:loss = 90.1425, step = 17401 (0.671 sec)
# INFO:tensorflow:global_step/sec: 149.16
# INFO:tensorflow:loss = 96.6684, step = 17501 (0.670 sec)
# INFO:tensorflow:global_step/sec: 147.14
# INFO:tensorflow:loss = 99.3724, step = 17601 (0.680 sec)
# INFO:tensorflow:global_step/sec: 152.064
# INFO:tensorflow:loss = 83.9333, step = 17701 (0.658 sec)
# INFO:tensorflow:global_step/sec: 147.762
# INFO:tensorflow:loss = 88.0347, step = 17801 (0.677 sec)
# INFO:tensorflow:global_step/sec: 116.624
# INFO:tensorflow:loss = 85.3492, step = 17901 (0.857 sec)
# INFO:tensorflow:global_step/sec: 153.368
# INFO:tensorflow:loss = 90.9398, step = 18001 (0.652 sec)
# INFO:tensorflow:global_step/sec: 147.003
# INFO:tensorflow:loss = 96.6119, step = 18101 (0.680 sec)
# INFO:tensorflow:global_step/sec: 146.923
# INFO:tensorflow:loss = 91.9786, step = 18201 (0.681 sec)
# INFO:tensorflow:global_step/sec: 147.02
# INFO:tensorflow:loss = 96.3145, step = 18301 (0.680 sec)
# INFO:tensorflow:global_step/sec: 150.012
# INFO:tensorflow:loss = 79.6721, step = 18401 (0.667 sec)
# INFO:tensorflow:global_step/sec: 150.519
# INFO:tensorflow:loss = 87.0884, step = 18501 (0.664 sec)
# INFO:tensorflow:global_step/sec: 143.56
# INFO:tensorflow:loss = 89.5776, step = 18601 (0.697 sec)
# INFO:tensorflow:global_step/sec: 150.805
# INFO:tensorflow:loss = 92.1418, step = 18701 (0.664 sec)
# INFO:tensorflow:global_step/sec: 150.92
# INFO:tensorflow:loss = 66.6693, step = 18801 (0.662 sec)
# INFO:tensorflow:global_step/sec: 152.686
# INFO:tensorflow:loss = 75.9286, step = 18901 (0.656 sec)
# INFO:tensorflow:global_step/sec: 143.695
# INFO:tensorflow:loss = 116.395, step = 19001 (0.695 sec)
# INFO:tensorflow:global_step/sec: 143.681
# INFO:tensorflow:loss = 86.5731, step = 19101 (0.696 sec)
# INFO:tensorflow:global_step/sec: 143.786
# INFO:tensorflow:loss = 88.5528, step = 19201 (0.696 sec)
# INFO:tensorflow:global_step/sec: 133.142
# INFO:tensorflow:loss = 100.393, step = 19301 (0.751 sec)
# INFO:tensorflow:global_step/sec: 130.495
# INFO:tensorflow:loss = 90.7522, step = 19401 (0.766 sec)
# INFO:tensorflow:global_step/sec: 152.659
# INFO:tensorflow:loss = 98.1217, step = 19501 (0.655 sec)
# INFO:tensorflow:global_step/sec: 153.242
# INFO:tensorflow:loss = 88.808, step = 19601 (0.652 sec)
# INFO:tensorflow:global_step/sec: 154.636
# INFO:tensorflow:loss = 96.0326, step = 19701 (0.647 sec)
# INFO:tensorflow:global_step/sec: 141.28
# INFO:tensorflow:loss = 101.932, step = 19801 (0.708 sec)
# INFO:tensorflow:global_step/sec: 143.682
# INFO:tensorflow:loss = 75.4871, step = 19901 (0.695 sec)
# INFO:tensorflow:global_step/sec: 143.136
# INFO:tensorflow:loss = 66.9889, step = 20001 (0.699 sec)
# INFO:tensorflow:global_step/sec: 146.708
# INFO:tensorflow:loss = 93.4751, step = 20101 (0.682 sec)
# INFO:tensorflow:global_step/sec: 137.781
# INFO:tensorflow:loss = 97.3343, step = 20201 (0.726 sec)
# INFO:tensorflow:global_step/sec: 143.854
# INFO:tensorflow:loss = 91.9645, step = 20301 (0.695 sec)
# INFO:tensorflow:global_step/sec: 137.603
# INFO:tensorflow:loss = 94.275, step = 20401 (0.728 sec)
# INFO:tensorflow:global_step/sec: 135.634
# INFO:tensorflow:loss = 87.0706, step = 20501 (0.736 sec)
# INFO:tensorflow:global_step/sec: 138.93
# INFO:tensorflow:loss = 100.39, step = 20601 (0.720 sec)
# INFO:tensorflow:global_step/sec: 150.264
# INFO:tensorflow:loss = 113.468, step = 20701 (0.666 sec)
# INFO:tensorflow:global_step/sec: 138.375
# INFO:tensorflow:loss = 78.4979, step = 20801 (0.723 sec)
# INFO:tensorflow:global_step/sec: 141.629
# INFO:tensorflow:loss = 84.2422, step = 20901 (0.706 sec)
# INFO:tensorflow:global_step/sec: 144.255
# INFO:tensorflow:loss = 95.1717, step = 21001 (0.693 sec)
# INFO:tensorflow:global_step/sec: 149.821
# INFO:tensorflow:loss = 85.9559, step = 21101 (0.668 sec)
# INFO:tensorflow:global_step/sec: 143.96
# INFO:tensorflow:loss = 78.7861, step = 21201 (0.695 sec)
# INFO:tensorflow:global_step/sec: 148.509
# INFO:tensorflow:loss = 96.7988, step = 21301 (0.673 sec)
# INFO:tensorflow:global_step/sec: 151.578
# INFO:tensorflow:loss = 96.5498, step = 21401 (0.660 sec)
# INFO:tensorflow:global_step/sec: 146.343
# INFO:tensorflow:loss = 91.8034, step = 21501 (0.684 sec)
# INFO:tensorflow:global_step/sec: 149.371
# INFO:tensorflow:loss = 89.8396, step = 21601 (0.669 sec)
# INFO:tensorflow:global_step/sec: 150.43
# INFO:tensorflow:loss = 95.6902, step = 21701 (0.665 sec)
# INFO:tensorflow:global_step/sec: 151.973
# INFO:tensorflow:loss = 98.723, step = 21801 (0.658 sec)
# INFO:tensorflow:global_step/sec: 149.619
# INFO:tensorflow:loss = 96.5036, step = 21901 (0.669 sec)
# INFO:tensorflow:global_step/sec: 152.109
# INFO:tensorflow:loss = 85.523, step = 22001 (0.658 sec)
# INFO:tensorflow:global_step/sec: 153.861
# INFO:tensorflow:loss = 104.86, step = 22101 (0.650 sec)
# INFO:tensorflow:global_step/sec: 146.011
# INFO:tensorflow:loss = 91.9439, step = 22201 (0.685 sec)
# INFO:tensorflow:global_step/sec: 108.152
# INFO:tensorflow:loss = 85.266, step = 22301 (0.924 sec)
# INFO:tensorflow:global_step/sec: 141.434
# INFO:tensorflow:loss = 71.9396, step = 22401 (0.707 sec)
# INFO:tensorflow:global_step/sec: 140.859
# INFO:tensorflow:loss = 81.5152, step = 22501 (0.710 sec)
# INFO:tensorflow:global_step/sec: 143.245
# INFO:tensorflow:loss = 112.043, step = 22601 (0.698 sec)
# INFO:tensorflow:global_step/sec: 136.138
# INFO:tensorflow:loss = 99.0911, step = 22701 (0.734 sec)
# INFO:tensorflow:global_step/sec: 139.603
# INFO:tensorflow:loss = 97.1946, step = 22801 (0.717 sec)
# INFO:tensorflow:global_step/sec: 136.198
# INFO:tensorflow:loss = 104.39, step = 22901 (0.734 sec)
# INFO:tensorflow:global_step/sec: 137.578
# INFO:tensorflow:loss = 87.8183, step = 23001 (0.727 sec)
# INFO:tensorflow:global_step/sec: 139.456
# INFO:tensorflow:loss = 106.028, step = 23101 (0.717 sec)
# INFO:tensorflow:global_step/sec: 133.332
# INFO:tensorflow:loss = 90.7226, step = 23201 (0.750 sec)
# INFO:tensorflow:global_step/sec: 146.731
# INFO:tensorflow:loss = 81.3301, step = 23301 (0.681 sec)
# INFO:tensorflow:global_step/sec: 140.842
# INFO:tensorflow:loss = 88.2912, step = 23401 (0.710 sec)
# INFO:tensorflow:global_step/sec: 140.008
# INFO:tensorflow:loss = 90.2377, step = 23501 (0.714 sec)
# INFO:tensorflow:global_step/sec: 135.741
# INFO:tensorflow:loss = 80.404, step = 23601 (0.737 sec)
# INFO:tensorflow:global_step/sec: 125.125
# INFO:tensorflow:loss = 95.137, step = 23701 (0.799 sec)
# INFO:tensorflow:global_step/sec: 150.577
# INFO:tensorflow:loss = 101.479, step = 23801 (0.664 sec)
# INFO:tensorflow:global_step/sec: 155.621
# INFO:tensorflow:loss = 93.1599, step = 23901 (0.643 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/reg-model-04/model.ckpt.
# INFO:tensorflow:Loss for final step: 82.8311.
# INFO:tensorflow:Starting evaluation at 2017-10-29-20:00:25
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-04/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/100]
# INFO:tensorflow:Evaluation [2/100]
# INFO:tensorflow:Evaluation [3/100]
# INFO:tensorflow:Evaluation [4/100]
# INFO:tensorflow:Evaluation [5/100]
# INFO:tensorflow:Evaluation [6/100]
# INFO:tensorflow:Evaluation [7/100]
# INFO:tensorflow:Evaluation [8/100]
# INFO:tensorflow:Evaluation [9/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [11/100]
# INFO:tensorflow:Evaluation [12/100]
# INFO:tensorflow:Evaluation [13/100]
# INFO:tensorflow:Evaluation [14/100]
# INFO:tensorflow:Evaluation [15/100]
# INFO:tensorflow:Evaluation [16/100]
# INFO:tensorflow:Evaluation [17/100]
# INFO:tensorflow:Evaluation [18/100]
# INFO:tensorflow:Evaluation [19/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [21/100]
# INFO:tensorflow:Evaluation [22/100]
# INFO:tensorflow:Evaluation [23/100]
# INFO:tensorflow:Evaluation [24/100]
# INFO:tensorflow:Evaluation [25/100]
# INFO:tensorflow:Evaluation [26/100]
# INFO:tensorflow:Evaluation [27/100]
# INFO:tensorflow:Evaluation [28/100]
# INFO:tensorflow:Evaluation [29/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [31/100]
# INFO:tensorflow:Evaluation [32/100]
# INFO:tensorflow:Evaluation [33/100]
# INFO:tensorflow:Evaluation [34/100]
# INFO:tensorflow:Evaluation [35/100]
# INFO:tensorflow:Evaluation [36/100]
# INFO:tensorflow:Evaluation [37/100]
# INFO:tensorflow:Evaluation [38/100]
# INFO:tensorflow:Evaluation [39/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [41/100]
# INFO:tensorflow:Evaluation [42/100]
# INFO:tensorflow:Evaluation [43/100]
# INFO:tensorflow:Evaluation [44/100]
# INFO:tensorflow:Evaluation [45/100]
# INFO:tensorflow:Evaluation [46/100]
# INFO:tensorflow:Evaluation [47/100]
# INFO:tensorflow:Evaluation [48/100]
# INFO:tensorflow:Evaluation [49/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [51/100]
# INFO:tensorflow:Evaluation [52/100]
# INFO:tensorflow:Evaluation [53/100]
# INFO:tensorflow:Evaluation [54/100]
# INFO:tensorflow:Evaluation [55/100]
# INFO:tensorflow:Evaluation [56/100]
# INFO:tensorflow:Evaluation [57/100]
# INFO:tensorflow:Evaluation [58/100]
# INFO:tensorflow:Evaluation [59/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [61/100]
# INFO:tensorflow:Evaluation [62/100]
# INFO:tensorflow:Evaluation [63/100]
# INFO:tensorflow:Evaluation [64/100]
# INFO:tensorflow:Evaluation [65/100]
# INFO:tensorflow:Evaluation [66/100]
# INFO:tensorflow:Evaluation [67/100]
# INFO:tensorflow:Evaluation [68/100]
# INFO:tensorflow:Evaluation [69/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [71/100]
# INFO:tensorflow:Evaluation [72/100]
# INFO:tensorflow:Evaluation [73/100]
# INFO:tensorflow:Evaluation [74/100]
# INFO:tensorflow:Evaluation [75/100]
# INFO:tensorflow:Evaluation [76/100]
# INFO:tensorflow:Evaluation [77/100]
# INFO:tensorflow:Evaluation [78/100]
# INFO:tensorflow:Evaluation [79/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [81/100]
# INFO:tensorflow:Evaluation [82/100]
# INFO:tensorflow:Evaluation [83/100]
# INFO:tensorflow:Evaluation [84/100]
# INFO:tensorflow:Evaluation [85/100]
# INFO:tensorflow:Evaluation [86/100]
# INFO:tensorflow:Evaluation [87/100]
# INFO:tensorflow:Evaluation [88/100]
# INFO:tensorflow:Evaluation [89/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [91/100]
# INFO:tensorflow:Evaluation [92/100]
# INFO:tensorflow:Evaluation [93/100]
# INFO:tensorflow:Evaluation [94/100]
# INFO:tensorflow:Evaluation [95/100]
# INFO:tensorflow:Evaluation [96/100]
# INFO:tensorflow:Evaluation [97/100]
# INFO:tensorflow:Evaluation [98/100]
# INFO:tensorflow:Evaluation [99/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2017-10-29-20:00:27
# INFO:tensorflow:Saving dict for global step 24000: global_step = 24000, loss = 98.2418, rmse = 9.9117
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-04/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'trained_models/reg-model-04/export/Servo/1509307227/saved_model.pb'
#
# experiment finished...

# %% [markdown]
# ## 7. Evaluate the Model

# %%
test_size = 5000

test_input_fn = lambda: csv_input_fn(file_names= test_data_files, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= test_size)

estimator = create_estimator(run_config, hparams)
results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print("")
print(results)
rmse = round(results["rmse"],5)
print("")
print("RMSE: {}".format(rmse))
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11d1919b0>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/reg-model-04'}
# INFO:tensorflow:Starting evaluation at 2017-10-29-20:00:29
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-04/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-10-29-20:00:29
# INFO:tensorflow:Saving dict for global step 24000: global_step = 24000, loss = 99.2471, rmse = 9.96228
#
# {'loss': 99.247078, 'rmse': 9.9622831, 'global_step': 24000}
#
# RMSE: 9.9622802734375

# %% [markdown]
# ## 8. Prediction

# %%
import itertools

predict_input_fn = lambda: csv_input_fn(file_names= test_data_files, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)

predictions = estimator.predict(input_fn=predict_input_fn)
print("")
print(list(itertools.islice(predictions, 5)))
# Out:
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/reg-model-04/model.ckpt-24000
# [{'scores': 47.889103}, {'scores': -4.0050755}, {'scores': 17.920849}, {'scores': 2.5622969}, {'scores': 2.7062178}]
