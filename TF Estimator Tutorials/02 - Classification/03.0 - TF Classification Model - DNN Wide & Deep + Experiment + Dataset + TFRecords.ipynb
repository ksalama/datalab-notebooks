# %%
import tensorflow as tf
import numpy as np
from tensorflow import data
import shutil
import math
from datetime import datetime
from tensorflow.python.feature_column import feature_column

from tensorflow.contrib.learn import learn_runner
from tensorflow.contrib.learn import make_export_strategy

print(tf.__version__)
# Out:
# /Users/khalidsalama/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 1.4.0

# %% [markdown]
# ## Steps to use the TF Experiment APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from .tfrecord files + **feature processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Define an **estimator** (LinearCombinedDNNClassifier) with the required **feature columns (wide/deep) & parameters**
# 5. Define a **serving function** to export the model
# 7. Run an **Experiment** with **learn_runner** to train, evaluate, and export the model
# 8. **Evaluate** the model using test data
# 9. Perform **predictions**

# %%
MODEL_NAME = 'class-model-01'

TRAIN_DATA_FILES_PATTERN = 'data/train-*.tfrecords'
VALID_DATA_FILES_PATTERN = 'data/valid-*.tfrecords'
TEST_DATA_FILES_PATTERN = 'data/test-*.tfrecords'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## 1. Define Dataset Metadata
# * tf.example feature names and defaults
# * Numeric and categorical feature names
# * Target feature name
# * Target feature labels
# * Unused features

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

TARGET_LABELS = ['positive', 'negative']

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {} - labels: {}".format(TARGET_NAME, TARGET_LABELS))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target - labels: ['positive', 'negative']
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function
# * Input .tfrecords files name pattern
# * Use TF Dataset APIs to read and process the data
# * Parse tf.exmaples to feature tensors
# * Apply feature processing
# * Return (features, target) tensors

# %% [markdown]
# ### a. parsing and processing logic

# %%
def parse_tf_example(example_proto):

    feature_spec = {}

    for feature_name in NUMERIC_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(), dtype=tf.float32)
    
    for feature_name in CATEGORICAL_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(), dtype=tf.string)
    
    feature_spec[TARGET_NAME] = tf.FixedLenFeature(shape=(), dtype=tf.string)

    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    
    target = parsed_features.pop(TARGET_NAME)
    
    return parsed_features, target


def process_features(features):

    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
    return features

# %% [markdown]
# ### b. data pipeline input function

# %%
def tfrecods_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TFRecordDataset(filenames=file_names)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example))
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target))
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = tfrecods_input_fn(files_name_pattern="")
print("Feature read from TFRecords: {}".format(list(features.keys())))
print("Target read from TFRecords: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# Feature read from TFRecords: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy']
# Target read from TFRecords: Tensor("IteratorGetNext:8", shape=(?,), dtype=string)

# %% [markdown]
# ## 3. Define Feature Columns

# %%
def extend_feature_columns(feature_columns, hparams):
    
    num_buckets = hparams.num_buckets
    embedding_size = hparams.embedding_size

    buckets = np.linspace(-3, 3, num_buckets).tolist()

    alpha_X_beta = tf.feature_column.crossed_column(
            [feature_columns['alpha'], feature_columns['beta']], 4)

    x_bucketized = tf.feature_column.bucketized_column(
            feature_columns['x'], boundaries=buckets)

    y_bucketized = tf.feature_column.bucketized_column(
            feature_columns['y'], boundaries=buckets)

    x_bucketized_X_y_bucketized = tf.feature_column.crossed_column(
           [x_bucketized, y_bucketized], num_buckets**2)

    x_bucketized_X_y_bucketized_embedded = tf.feature_column.embedding_column(
            x_bucketized_X_y_bucketized, dimension=embedding_size)


    feature_columns['alpha_X_beta'] = alpha_X_beta
    feature_columns['x_bucketized_X_y_bucketized'] = x_bucketized_X_y_bucketized
    feature_columns['x_bucketized_X_y_bucketized_embedded'] = x_bucketized_X_y_bucketized_embedded
    
    return feature_columns
    

def get_feature_columns(hparams):
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if PROCESS_FEATURES:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), 'x_bucketized_X_y_bucketized': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), 'x_bucketized_X_y_bucketized_embedded': _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11c81d898>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)}

# %% [markdown]
# ## 4. Define an Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns
# * dense columns = numeric columns + embedding columns
# * categorical columns = vocabolary list columns + bucketized columns
# * sparse columns = hashed categorical columns + crossed columns
# * categorical columns => indicator columns
# * deep columns = dense columns + indicator columns
# * wide columns = categorical columns + sparse columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %%
def create_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedClassifier(
        
        n_classes= len(TARGET_LABELS),
        label_vocabulary=TARGET_LABELS,
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.elu,
        dnn_dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 5. Define Serving Funcion

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='rows_string_tensor')
    
    receiver_tensor = {'rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))

    return tf.estimator.export.ServingInputReceiver(
        process_features(features), receiver_tensor)

# %% [markdown]
# ## 6. Run Experiment

# %% [markdown]
# ### a. Define Experiment Function

# %%
def generate_experiment_fn(**experiment_args):

    def _experiment_fn(run_config, hparams):

        train_input_fn = lambda: tfrecods_input_fn(
            TRAIN_DATA_FILES_PATTERN,
            mode = tf.contrib.learn.ModeKeys.TRAIN,
            num_epochs=hparams.num_epochs,
            batch_size=hparams.batch_size
        )

        eval_input_fn = lambda: tfrecods_input_fn(
            VALID_DATA_FILES_PATTERN,
            mode=tf.contrib.learn.ModeKeys.EVAL,
            num_epochs=1,
            batch_size=hparams.batch_size
        )

        estimator = create_estimator(run_config, hparams, True)

        return tf.contrib.learn.Experiment(
            estimator,
            train_input_fn=train_input_fn,
            eval_input_fn=eval_input_fn,
            eval_steps=None,
            **experiment_args
        )

    return _experiment_fn

# %% [markdown]
# ### b. Set HParam and RunConfig

# %%
TRAIN_SIZE = 12000
NUM_EPOCHS = 1000
BATCH_SIZE = 500
NUM_EVAL = 10
CHECKPOINT_STEPS = int((TRAIN_SIZE/BATCH_SIZE) * (NUM_EPOCHS/NUM_EVAL))

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units=[16, 12, 8],
    num_buckets = 6,
    embedding_size = 3,
    dropout_prob = 0.001)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.contrib.learn.RunConfig(
    save_checkpoints_steps=CHECKPOINT_STEPS,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS)
print("Required Evaluation Steps:", NUM_EVAL) 
print("That is 1 evaluation step after each",NUM_EPOCHS/NUM_EVAL," epochs")
print("Save Checkpoint After",CHECKPOINT_STEPS,"steps")
# Out:
# [('batch_size', 500), ('dropout_prob', 0.001), ('embedding_size', 3), ('hidden_units', [16, 12, 8]), ('num_buckets', 6), ('num_epochs', 1000)]
# Model Directory: trained_models/class-model-01
#
# Dataset Size: 12000
# Batch Size: 500
# Steps per Epoch: 24.0
# Total Steps: 24000.0
# Required Evaluation Steps: 10
# That is 1 evaluation step after each 100.0  epochs
# Save Checkpoint After 2400 steps

# %% [markdown]
# ### c. Run Experiment via learn_runner

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 


tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 


learn_runner.run(
    experiment_fn=generate_experiment_fn(

        export_strategies=[make_export_strategy(
            csv_serving_input_fn,
            exports_to_keep=1
        )]
    ),
    run_config=run_config,
    schedule="train_and_evaluate",
    hparams=hparams
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 16:05:36
# .......................................
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11c81d630>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/class-model-01'}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedClassifier'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x11c81d080>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None)]
#
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From /Users/khalidsalama/anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/class-model-01/model.ckpt.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:05:51
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:05:52
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.545333, accuracy_baseline = 0.5, auc = 0.581047, auc_precision_recall = 0.544995, average_loss = 0.724384, global_step = 1, label/mean = 0.5, loss = 362.192, prediction/mean = 0.402139
# INFO:tensorflow:Validation (step 1): accuracy = 0.545333, accuracy_baseline = 0.5, auc = 0.581047, auc_precision_recall = 0.544995, average_loss = 0.724384, label/mean = 0.5, loss = 362.192, prediction/mean = 0.402139, global_step = 1
# INFO:tensorflow:loss = 367.798, step = 1
# INFO:tensorflow:global_step/sec: 13.1594
# INFO:tensorflow:loss = 300.208, step = 101 (0.900 sec)
# INFO:tensorflow:global_step/sec: 160.11
# INFO:tensorflow:loss = 211.619, step = 201 (0.624 sec)
# INFO:tensorflow:global_step/sec: 161.95
# INFO:tensorflow:loss = 162.349, step = 301 (0.617 sec)
# INFO:tensorflow:global_step/sec: 166.317
# INFO:tensorflow:loss = 124.463, step = 401 (0.601 sec)
# INFO:tensorflow:global_step/sec: 164.162
# INFO:tensorflow:loss = 122.562, step = 501 (0.609 sec)
# INFO:tensorflow:global_step/sec: 162.258
# INFO:tensorflow:loss = 83.5131, step = 601 (0.616 sec)
# INFO:tensorflow:global_step/sec: 163.681
# INFO:tensorflow:loss = 84.2995, step = 701 (0.611 sec)
# INFO:tensorflow:global_step/sec: 163.682
# INFO:tensorflow:loss = 65.9374, step = 801 (0.611 sec)
# INFO:tensorflow:global_step/sec: 167.957
# INFO:tensorflow:loss = 74.7193, step = 901 (0.596 sec)
# INFO:tensorflow:global_step/sec: 161.051
# INFO:tensorflow:loss = 80.7219, step = 1001 (0.620 sec)
# INFO:tensorflow:global_step/sec: 159.664
# INFO:tensorflow:loss = 66.1648, step = 1101 (0.628 sec)
# INFO:tensorflow:global_step/sec: 165.774
# INFO:tensorflow:loss = 54.1094, step = 1201 (0.602 sec)
# INFO:tensorflow:global_step/sec: 164.627
# INFO:tensorflow:loss = 53.8291, step = 1301 (0.608 sec)
# INFO:tensorflow:global_step/sec: 143.871
# INFO:tensorflow:loss = 59.0117, step = 1401 (0.695 sec)
# INFO:tensorflow:global_step/sec: 149.522
# INFO:tensorflow:loss = 67.3785, step = 1501 (0.673 sec)
# INFO:tensorflow:global_step/sec: 134.208
# INFO:tensorflow:loss = 68.933, step = 1601 (0.739 sec)
# INFO:tensorflow:global_step/sec: 173.927
# INFO:tensorflow:loss = 64.3857, step = 1701 (0.574 sec)
# INFO:tensorflow:global_step/sec: 164.676
# INFO:tensorflow:loss = 51.0939, step = 1801 (0.608 sec)
# INFO:tensorflow:global_step/sec: 180.27
# INFO:tensorflow:loss = 44.0319, step = 1901 (0.558 sec)
# INFO:tensorflow:global_step/sec: 144.71
# INFO:tensorflow:loss = 55.9877, step = 2001 (0.688 sec)
# INFO:tensorflow:global_step/sec: 180.56
# INFO:tensorflow:loss = 42.752, step = 2101 (0.554 sec)
# INFO:tensorflow:global_step/sec: 180.843
# INFO:tensorflow:loss = 59.587, step = 2201 (0.553 sec)
# INFO:tensorflow:global_step/sec: 182.429
# INFO:tensorflow:loss = 59.8185, step = 2301 (0.549 sec)
# INFO:tensorflow:Saving checkpoints for 2401 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 48.2513
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:06:13
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-2401
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:06:15
# INFO:tensorflow:Saving dict for global step 2401: accuracy = 0.948667, accuracy_baseline = 0.5, auc = 0.989728, auc_precision_recall = 0.99096, average_loss = 0.127021, global_step = 2401, label/mean = 0.5, loss = 63.5107, prediction/mean = 0.501595
# INFO:tensorflow:Validation (step 2401): accuracy = 0.948667, accuracy_baseline = 0.5, auc = 0.989728, auc_precision_recall = 0.99096, average_loss = 0.127021, label/mean = 0.5, loss = 63.5107, prediction/mean = 0.501595, global_step = 2401
# INFO:tensorflow:loss = 43.2125, step = 2401 (5.815 sec)
# INFO:tensorflow:global_step/sec: 22.8478
# INFO:tensorflow:loss = 51.4669, step = 2501 (0.635 sec)
# INFO:tensorflow:global_step/sec: 156.836
# INFO:tensorflow:loss = 62.8036, step = 2601 (0.638 sec)
# INFO:tensorflow:global_step/sec: 156.997
# INFO:tensorflow:loss = 60.0741, step = 2701 (0.636 sec)
# INFO:tensorflow:global_step/sec: 157.158
# INFO:tensorflow:loss = 89.6466, step = 2801 (0.635 sec)
# INFO:tensorflow:global_step/sec: 156.789
# INFO:tensorflow:loss = 55.1014, step = 2901 (0.639 sec)
# INFO:tensorflow:global_step/sec: 148.183
# INFO:tensorflow:loss = 56.6122, step = 3001 (0.675 sec)
# INFO:tensorflow:global_step/sec: 157.415
# INFO:tensorflow:loss = 57.6482, step = 3101 (0.635 sec)
# INFO:tensorflow:global_step/sec: 144.973
# INFO:tensorflow:loss = 54.1119, step = 3201 (0.695 sec)
# INFO:tensorflow:global_step/sec: 135.834
# INFO:tensorflow:loss = 61.9126, step = 3301 (0.729 sec)
# INFO:tensorflow:global_step/sec: 178.265
# INFO:tensorflow:loss = 53.3086, step = 3401 (0.561 sec)
# INFO:tensorflow:global_step/sec: 180.096
# INFO:tensorflow:loss = 74.519, step = 3501 (0.555 sec)
# INFO:tensorflow:global_step/sec: 179.791
# INFO:tensorflow:loss = 53.2911, step = 3601 (0.556 sec)
# INFO:tensorflow:global_step/sec: 167.91
# INFO:tensorflow:loss = 56.8043, step = 3701 (0.596 sec)
# INFO:tensorflow:global_step/sec: 177.047
# INFO:tensorflow:loss = 50.6941, step = 3801 (0.565 sec)
# INFO:tensorflow:global_step/sec: 185.325
# INFO:tensorflow:loss = 63.9508, step = 3901 (0.541 sec)
# INFO:tensorflow:global_step/sec: 179.786
# INFO:tensorflow:loss = 68.9809, step = 4001 (0.555 sec)
# INFO:tensorflow:global_step/sec: 181.914
# INFO:tensorflow:loss = 58.1893, step = 4101 (0.550 sec)
# INFO:tensorflow:global_step/sec: 169.34
# INFO:tensorflow:loss = 47.9043, step = 4201 (0.592 sec)
# INFO:tensorflow:global_step/sec: 160.241
# INFO:tensorflow:loss = 54.2471, step = 4301 (0.623 sec)
# INFO:tensorflow:global_step/sec: 163.211
# INFO:tensorflow:loss = 40.7804, step = 4401 (0.612 sec)
# INFO:tensorflow:global_step/sec: 192.184
# INFO:tensorflow:loss = 48.1839, step = 4501 (0.520 sec)
# INFO:tensorflow:global_step/sec: 159.995
# INFO:tensorflow:loss = 73.7359, step = 4601 (0.627 sec)
# INFO:tensorflow:global_step/sec: 178.479
# INFO:tensorflow:loss = 54.733, step = 4701 (0.559 sec)
# INFO:tensorflow:Saving checkpoints for 4801 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 39.3793
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:06:34
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-4801
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:06:36
# INFO:tensorflow:Saving dict for global step 4801: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990318, auc_precision_recall = 0.991343, average_loss = 0.123601, global_step = 4801, label/mean = 0.5, loss = 61.8004, prediction/mean = 0.503371
# INFO:tensorflow:Validation (step 4801): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990318, auc_precision_recall = 0.991343, average_loss = 0.123601, label/mean = 0.5, loss = 61.8004, prediction/mean = 0.503371, global_step = 4801
# INFO:tensorflow:loss = 53.9156, step = 4801 (6.762 sec)
# INFO:tensorflow:global_step/sec: 20.6515
# INFO:tensorflow:loss = 55.8483, step = 4901 (0.624 sec)
# INFO:tensorflow:global_step/sec: 160.622
# INFO:tensorflow:loss = 40.7985, step = 5001 (0.620 sec)
# INFO:tensorflow:global_step/sec: 176.257
# INFO:tensorflow:loss = 54.558, step = 5101 (0.567 sec)
# INFO:tensorflow:global_step/sec: 168.386
# INFO:tensorflow:loss = 60.9781, step = 5201 (0.594 sec)
# INFO:tensorflow:global_step/sec: 166.238
# INFO:tensorflow:loss = 67.3702, step = 5301 (0.603 sec)
# INFO:tensorflow:global_step/sec: 156.108
# INFO:tensorflow:loss = 56.3291, step = 5401 (0.640 sec)
# INFO:tensorflow:global_step/sec: 142.236
# INFO:tensorflow:loss = 48.3456, step = 5501 (0.703 sec)
# INFO:tensorflow:global_step/sec: 151.451
# INFO:tensorflow:loss = 49.5535, step = 5601 (0.659 sec)
# INFO:tensorflow:global_step/sec: 146.948
# INFO:tensorflow:loss = 59.5464, step = 5701 (0.684 sec)
# INFO:tensorflow:global_step/sec: 159.279
# INFO:tensorflow:loss = 44.8572, step = 5801 (0.624 sec)
# INFO:tensorflow:global_step/sec: 149.355
# INFO:tensorflow:loss = 53.2054, step = 5901 (0.670 sec)
# INFO:tensorflow:global_step/sec: 154.675
# INFO:tensorflow:loss = 55.1002, step = 6001 (0.648 sec)
# INFO:tensorflow:global_step/sec: 162.879
# INFO:tensorflow:loss = 51.0697, step = 6101 (0.614 sec)
# INFO:tensorflow:global_step/sec: 162.206
# INFO:tensorflow:loss = 48.0757, step = 6201 (0.615 sec)
# INFO:tensorflow:global_step/sec: 149.976
# INFO:tensorflow:loss = 60.4919, step = 6301 (0.668 sec)
# INFO:tensorflow:global_step/sec: 149.672
# INFO:tensorflow:loss = 64.6721, step = 6401 (0.678 sec)
# INFO:tensorflow:global_step/sec: 145.163
# INFO:tensorflow:loss = 40.0768, step = 6501 (0.679 sec)
# INFO:tensorflow:global_step/sec: 174.6
# INFO:tensorflow:loss = 45.7592, step = 6601 (0.570 sec)
# INFO:tensorflow:global_step/sec: 153.068
# INFO:tensorflow:loss = 60.6002, step = 6701 (0.654 sec)
# INFO:tensorflow:global_step/sec: 140.31
# INFO:tensorflow:loss = 55.0018, step = 6801 (0.716 sec)
# INFO:tensorflow:global_step/sec: 137.124
# INFO:tensorflow:loss = 56.4116, step = 6901 (0.729 sec)
# INFO:tensorflow:global_step/sec: 154.162
# INFO:tensorflow:loss = 50.9101, step = 7001 (0.645 sec)
# INFO:tensorflow:global_step/sec: 148.496
# INFO:tensorflow:loss = 56.9551, step = 7101 (0.677 sec)
# INFO:tensorflow:Saving checkpoints for 7201 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 41.4894
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:06:55
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-7201
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:06:57
# INFO:tensorflow:Saving dict for global step 7201: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990835, auc_precision_recall = 0.991604, average_loss = 0.12191, global_step = 7201, label/mean = 0.5, loss = 60.9548, prediction/mean = 0.499908
# INFO:tensorflow:Validation (step 7201): accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990835, auc_precision_recall = 0.991604, average_loss = 0.12191, label/mean = 0.5, loss = 60.9548, prediction/mean = 0.499908, global_step = 7201
# INFO:tensorflow:loss = 52.6766, step = 7201 (6.312 sec)
# INFO:tensorflow:global_step/sec: 20.8878
# INFO:tensorflow:loss = 59.5233, step = 7301 (0.888 sec)
# INFO:tensorflow:global_step/sec: 145.682
# INFO:tensorflow:loss = 54.5579, step = 7401 (0.681 sec)
# INFO:tensorflow:global_step/sec: 139.81
# INFO:tensorflow:loss = 47.1151, step = 7501 (0.716 sec)
# INFO:tensorflow:global_step/sec: 175.156
# INFO:tensorflow:loss = 59.0914, step = 7601 (0.572 sec)
# INFO:tensorflow:global_step/sec: 161.747
# INFO:tensorflow:loss = 44.9465, step = 7701 (0.619 sec)
# INFO:tensorflow:global_step/sec: 153.704
# INFO:tensorflow:loss = 49.3429, step = 7801 (0.651 sec)
# INFO:tensorflow:global_step/sec: 148.177
# INFO:tensorflow:loss = 50.571, step = 7901 (0.673 sec)
# INFO:tensorflow:global_step/sec: 156.243
# INFO:tensorflow:loss = 35.5534, step = 8001 (0.639 sec)
# INFO:tensorflow:global_step/sec: 162.524
# INFO:tensorflow:loss = 47.7327, step = 8101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 154.367
# INFO:tensorflow:loss = 55.5154, step = 8201 (0.643 sec)
# INFO:tensorflow:global_step/sec: 155.462
# INFO:tensorflow:loss = 45.991, step = 8301 (0.645 sec)
# INFO:tensorflow:global_step/sec: 146.655
# INFO:tensorflow:loss = 47.9003, step = 8401 (0.680 sec)
# INFO:tensorflow:global_step/sec: 156.343
# INFO:tensorflow:loss = 56.759, step = 8501 (0.640 sec)
# INFO:tensorflow:global_step/sec: 158.902
# INFO:tensorflow:loss = 68.8786, step = 8601 (0.629 sec)
# INFO:tensorflow:global_step/sec: 162.686
# INFO:tensorflow:loss = 62.8279, step = 8701 (0.615 sec)
# INFO:tensorflow:global_step/sec: 156.213
# INFO:tensorflow:loss = 66.1603, step = 8801 (0.640 sec)
# INFO:tensorflow:global_step/sec: 134.331
# INFO:tensorflow:loss = 53.6692, step = 8901 (0.744 sec)
# INFO:tensorflow:global_step/sec: 173.729
# INFO:tensorflow:loss = 56.0062, step = 9001 (0.576 sec)
# INFO:tensorflow:global_step/sec: 176.568
# INFO:tensorflow:loss = 60.9664, step = 9101 (0.566 sec)
# INFO:tensorflow:global_step/sec: 168.91
# INFO:tensorflow:loss = 33.8594, step = 9201 (0.593 sec)
# INFO:tensorflow:global_step/sec: 173.488
# INFO:tensorflow:loss = 40.6498, step = 9301 (0.575 sec)
# INFO:tensorflow:global_step/sec: 174.028
# INFO:tensorflow:loss = 59.9937, step = 9401 (0.575 sec)
# INFO:tensorflow:global_step/sec: 175.366
# INFO:tensorflow:loss = 64.3405, step = 9501 (0.570 sec)
# INFO:tensorflow:Saving checkpoints for 9601 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 49.2265
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:07:16
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-9601
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:07:18
# INFO:tensorflow:Saving dict for global step 9601: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990895, auc_precision_recall = 0.991642, average_loss = 0.121633, global_step = 9601, label/mean = 0.5, loss = 60.8165, prediction/mean = 0.500383
# INFO:tensorflow:Validation (step 9601): accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990895, auc_precision_recall = 0.991642, average_loss = 0.121633, label/mean = 0.5, loss = 60.8165, prediction/mean = 0.500383, global_step = 9601
# INFO:tensorflow:loss = 47.7602, step = 9601 (6.076 sec)
# INFO:tensorflow:global_step/sec: 21.5223
# INFO:tensorflow:loss = 63.218, step = 9701 (0.602 sec)
# INFO:tensorflow:global_step/sec: 164.513
# INFO:tensorflow:loss = 47.6366, step = 9801 (0.608 sec)
# INFO:tensorflow:global_step/sec: 158.345
# INFO:tensorflow:loss = 54.2859, step = 9901 (0.631 sec)
# INFO:tensorflow:global_step/sec: 151.683
# INFO:tensorflow:loss = 64.6654, step = 10001 (0.664 sec)
# INFO:tensorflow:global_step/sec: 130.583
# INFO:tensorflow:loss = 63.5053, step = 10101 (0.766 sec)
# INFO:tensorflow:global_step/sec: 138.755
# INFO:tensorflow:loss = 59.1471, step = 10201 (0.716 sec)
# INFO:tensorflow:global_step/sec: 170.859
# INFO:tensorflow:loss = 60.5707, step = 10301 (0.585 sec)
# INFO:tensorflow:global_step/sec: 164.601
# INFO:tensorflow:loss = 60.2314, step = 10401 (0.607 sec)
# INFO:tensorflow:global_step/sec: 166.634
# INFO:tensorflow:loss = 35.174, step = 10501 (0.600 sec)
# INFO:tensorflow:global_step/sec: 171.994
# INFO:tensorflow:loss = 45.5049, step = 10601 (0.581 sec)
# INFO:tensorflow:global_step/sec: 170.59
# INFO:tensorflow:loss = 61.0202, step = 10701 (0.586 sec)
# INFO:tensorflow:global_step/sec: 173.061
# INFO:tensorflow:loss = 41.4451, step = 10801 (0.577 sec)
# INFO:tensorflow:global_step/sec: 173.313
# INFO:tensorflow:loss = 65.7566, step = 10901 (0.577 sec)
# INFO:tensorflow:global_step/sec: 171.361
# INFO:tensorflow:loss = 54.438, step = 11001 (0.584 sec)
# INFO:tensorflow:global_step/sec: 177.015
# INFO:tensorflow:loss = 47.2766, step = 11101 (0.565 sec)
# INFO:tensorflow:global_step/sec: 172.237
# INFO:tensorflow:loss = 62.1429, step = 11201 (0.581 sec)
# INFO:tensorflow:global_step/sec: 172.199
# INFO:tensorflow:loss = 47.4337, step = 11301 (0.580 sec)
# INFO:tensorflow:global_step/sec: 174.774
# INFO:tensorflow:loss = 45.8335, step = 11401 (0.575 sec)
# INFO:tensorflow:global_step/sec: 170.552
# INFO:tensorflow:loss = 41.1917, step = 11501 (0.584 sec)
# INFO:tensorflow:global_step/sec: 173.138
# INFO:tensorflow:loss = 45.1506, step = 11601 (0.578 sec)
# INFO:tensorflow:global_step/sec: 158.937
# INFO:tensorflow:loss = 57.6406, step = 11701 (0.631 sec)
# INFO:tensorflow:global_step/sec: 164.404
# INFO:tensorflow:loss = 62.2266, step = 11801 (0.609 sec)
# INFO:tensorflow:global_step/sec: 164.577
# INFO:tensorflow:loss = 46.3194, step = 11901 (0.605 sec)
# INFO:tensorflow:Saving checkpoints for 12001 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 43.1488
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:07:36
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-12001
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:07:38
# INFO:tensorflow:Saving dict for global step 12001: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991, auc_precision_recall = 0.991695, average_loss = 0.121236, global_step = 12001, label/mean = 0.5, loss = 60.6179, prediction/mean = 0.49962
# INFO:tensorflow:Validation (step 12001): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991, auc_precision_recall = 0.991695, average_loss = 0.121236, label/mean = 0.5, loss = 60.6179, prediction/mean = 0.49962, global_step = 12001
# INFO:tensorflow:loss = 40.8159, step = 12001 (6.160 sec)
# INFO:tensorflow:global_step/sec: 21.509
# INFO:tensorflow:loss = 37.4166, step = 12101 (0.814 sec)
# INFO:tensorflow:global_step/sec: 130.458
# INFO:tensorflow:loss = 50.3235, step = 12201 (0.760 sec)
# INFO:tensorflow:global_step/sec: 118.456
# INFO:tensorflow:loss = 52.2078, step = 12301 (0.843 sec)
# INFO:tensorflow:global_step/sec: 120.268
# INFO:tensorflow:loss = 58.3317, step = 12401 (0.836 sec)
# INFO:tensorflow:global_step/sec: 123.641
# INFO:tensorflow:loss = 56.406, step = 12501 (0.814 sec)
# INFO:tensorflow:global_step/sec: 122.398
# INFO:tensorflow:loss = 62.1642, step = 12601 (0.810 sec)
# INFO:tensorflow:global_step/sec: 143.394
# INFO:tensorflow:loss = 44.5875, step = 12701 (0.699 sec)
# INFO:tensorflow:global_step/sec: 140.001
# INFO:tensorflow:loss = 44.3237, step = 12801 (0.710 sec)
# INFO:tensorflow:global_step/sec: 134.004
# INFO:tensorflow:loss = 43.1127, step = 12901 (0.746 sec)
# INFO:tensorflow:global_step/sec: 155.219
# INFO:tensorflow:loss = 73.5175, step = 13001 (0.645 sec)
# INFO:tensorflow:global_step/sec: 155.524
# INFO:tensorflow:loss = 55.8118, step = 13101 (0.645 sec)
# INFO:tensorflow:global_step/sec: 146.528
# INFO:tensorflow:loss = 50.3784, step = 13201 (0.680 sec)
# INFO:tensorflow:global_step/sec: 149.052
# INFO:tensorflow:loss = 47.194, step = 13301 (0.670 sec)
# INFO:tensorflow:global_step/sec: 124.741
# INFO:tensorflow:loss = 43.2756, step = 13401 (0.810 sec)
# INFO:tensorflow:global_step/sec: 149.635
# INFO:tensorflow:loss = 55.137, step = 13501 (0.660 sec)
# INFO:tensorflow:global_step/sec: 146.194
# INFO:tensorflow:loss = 51.9417, step = 13601 (0.690 sec)
# INFO:tensorflow:global_step/sec: 156.287
# INFO:tensorflow:loss = 65.6125, step = 13701 (0.634 sec)
# INFO:tensorflow:global_step/sec: 171.104
# INFO:tensorflow:loss = 59.7105, step = 13801 (0.584 sec)
# INFO:tensorflow:global_step/sec: 174.569
# INFO:tensorflow:loss = 59.71, step = 13901 (0.573 sec)
# INFO:tensorflow:global_step/sec: 176.523
# INFO:tensorflow:loss = 41.7235, step = 14001 (0.568 sec)
# INFO:tensorflow:global_step/sec: 136.197
# INFO:tensorflow:loss = 62.3289, step = 14101 (0.736 sec)
# INFO:tensorflow:global_step/sec: 144.643
# INFO:tensorflow:loss = 53.7547, step = 14201 (0.688 sec)
# INFO:tensorflow:global_step/sec: 148.518
# INFO:tensorflow:loss = 54.4652, step = 14301 (0.676 sec)
# INFO:tensorflow:Saving checkpoints for 14401 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 36.284
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:07:59
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-14401
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:08:01
# INFO:tensorflow:Saving dict for global step 14401: accuracy = 0.953667, accuracy_baseline = 0.5, auc = 0.990981, auc_precision_recall = 0.991663, average_loss = 0.121245, global_step = 14401, label/mean = 0.5, loss = 60.6223, prediction/mean = 0.499904
# INFO:tensorflow:Validation (step 14401): accuracy = 0.953667, accuracy_baseline = 0.5, auc = 0.990981, auc_precision_recall = 0.991663, average_loss = 0.121245, label/mean = 0.5, loss = 60.6223, prediction/mean = 0.499904, global_step = 14401
# INFO:tensorflow:loss = 51.5741, step = 14401 (6.714 sec)
# INFO:tensorflow:global_step/sec: 20.829
# INFO:tensorflow:loss = 54.753, step = 14501 (0.844 sec)
# INFO:tensorflow:global_step/sec: 146.96
# INFO:tensorflow:loss = 61.0252, step = 14601 (0.680 sec)
# INFO:tensorflow:global_step/sec: 157.175
# INFO:tensorflow:loss = 64.008, step = 14701 (0.634 sec)
# INFO:tensorflow:global_step/sec: 172.707
# INFO:tensorflow:loss = 49.3189, step = 14801 (0.579 sec)
# INFO:tensorflow:global_step/sec: 169.769
# INFO:tensorflow:loss = 58.4319, step = 14901 (0.589 sec)
# INFO:tensorflow:global_step/sec: 159.047
# INFO:tensorflow:loss = 56.4073, step = 15001 (0.631 sec)
# INFO:tensorflow:global_step/sec: 148.342
# INFO:tensorflow:loss = 59.6387, step = 15101 (0.674 sec)
# INFO:tensorflow:global_step/sec: 146.232
# INFO:tensorflow:loss = 67.3168, step = 15201 (0.682 sec)
# INFO:tensorflow:global_step/sec: 170.998
# INFO:tensorflow:loss = 53.2103, step = 15301 (0.587 sec)
# INFO:tensorflow:global_step/sec: 155.557
# INFO:tensorflow:loss = 69.8954, step = 15401 (0.640 sec)
# INFO:tensorflow:global_step/sec: 143.854
# INFO:tensorflow:loss = 53.9213, step = 15501 (0.696 sec)
# INFO:tensorflow:global_step/sec: 150.553
# INFO:tensorflow:loss = 49.8122, step = 15601 (0.662 sec)
# INFO:tensorflow:global_step/sec: 156.135
# INFO:tensorflow:loss = 59.6161, step = 15701 (0.644 sec)
# INFO:tensorflow:global_step/sec: 155.251
# INFO:tensorflow:loss = 48.2354, step = 15801 (0.641 sec)
# INFO:tensorflow:global_step/sec: 153.117
# INFO:tensorflow:loss = 41.5582, step = 15901 (0.656 sec)
# INFO:tensorflow:global_step/sec: 127.394
# INFO:tensorflow:loss = 59.6899, step = 16001 (0.784 sec)
# INFO:tensorflow:global_step/sec: 145.204
# INFO:tensorflow:loss = 47.8183, step = 16101 (0.687 sec)
# INFO:tensorflow:global_step/sec: 169.748
# INFO:tensorflow:loss = 48.2806, step = 16201 (0.589 sec)
# INFO:tensorflow:global_step/sec: 159.294
# INFO:tensorflow:loss = 40.7605, step = 16301 (0.628 sec)
# INFO:tensorflow:global_step/sec: 159.536
# INFO:tensorflow:loss = 49.5315, step = 16401 (0.631 sec)
# INFO:tensorflow:global_step/sec: 154.77
# INFO:tensorflow:loss = 53.5297, step = 16501 (0.643 sec)
# INFO:tensorflow:global_step/sec: 159.955
# INFO:tensorflow:loss = 46.6379, step = 16601 (0.626 sec)
# INFO:tensorflow:global_step/sec: 157.701
# INFO:tensorflow:loss = 57.2792, step = 16701 (0.632 sec)
# INFO:tensorflow:Saving checkpoints for 16801 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 41.4856
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:08:21
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-16801
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:08:22
# INFO:tensorflow:Saving dict for global step 16801: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991002, auc_precision_recall = 0.99165, average_loss = 0.121367, global_step = 16801, label/mean = 0.5, loss = 60.6835, prediction/mean = 0.497748
# INFO:tensorflow:Validation (step 16801): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991002, auc_precision_recall = 0.99165, average_loss = 0.121367, label/mean = 0.5, loss = 60.6835, prediction/mean = 0.497748, global_step = 16801
# INFO:tensorflow:loss = 42.8698, step = 16801 (6.658 sec)
# INFO:tensorflow:global_step/sec: 20.4032
# INFO:tensorflow:loss = 50.3401, step = 16901 (0.655 sec)
# INFO:tensorflow:global_step/sec: 139.943
# INFO:tensorflow:loss = 44.6719, step = 17001 (0.714 sec)
# INFO:tensorflow:global_step/sec: 133.196
# INFO:tensorflow:loss = 33.619, step = 17101 (0.756 sec)
# INFO:tensorflow:global_step/sec: 120.909
# INFO:tensorflow:loss = 58.4876, step = 17201 (0.826 sec)
# INFO:tensorflow:global_step/sec: 146.894
# INFO:tensorflow:loss = 70.57, step = 17301 (0.678 sec)
# INFO:tensorflow:global_step/sec: 144.629
# INFO:tensorflow:loss = 50.9063, step = 17401 (0.693 sec)
# INFO:tensorflow:global_step/sec: 135.851
# INFO:tensorflow:loss = 46.2028, step = 17501 (0.735 sec)
# INFO:tensorflow:global_step/sec: 144.79
# INFO:tensorflow:loss = 39.7614, step = 17601 (0.692 sec)
# INFO:tensorflow:global_step/sec: 138.5
# INFO:tensorflow:loss = 48.1493, step = 17701 (0.724 sec)
# INFO:tensorflow:global_step/sec: 158.132
# INFO:tensorflow:loss = 54.7027, step = 17801 (0.630 sec)
# INFO:tensorflow:global_step/sec: 151.154
# INFO:tensorflow:loss = 55.7525, step = 17901 (0.660 sec)
# INFO:tensorflow:global_step/sec: 142.727
# INFO:tensorflow:loss = 48.5197, step = 18001 (0.703 sec)
# INFO:tensorflow:global_step/sec: 163.692
# INFO:tensorflow:loss = 47.9747, step = 18101 (0.611 sec)
# INFO:tensorflow:global_step/sec: 153.172
# INFO:tensorflow:loss = 32.2431, step = 18201 (0.650 sec)
# INFO:tensorflow:global_step/sec: 158.459
# INFO:tensorflow:loss = 49.7439, step = 18301 (0.632 sec)
# INFO:tensorflow:global_step/sec: 155.33
# INFO:tensorflow:loss = 52.7422, step = 18401 (0.643 sec)
# INFO:tensorflow:global_step/sec: 153.836
# INFO:tensorflow:loss = 51.0026, step = 18501 (0.651 sec)
# INFO:tensorflow:global_step/sec: 152.914
# INFO:tensorflow:loss = 51.0279, step = 18601 (0.653 sec)
# INFO:tensorflow:global_step/sec: 139.074
# INFO:tensorflow:loss = 67.6928, step = 18701 (0.724 sec)
# INFO:tensorflow:global_step/sec: 151.531
# INFO:tensorflow:loss = 40.5942, step = 18801 (0.657 sec)
# INFO:tensorflow:global_step/sec: 164.839
# INFO:tensorflow:loss = 76.1572, step = 18901 (0.607 sec)
# INFO:tensorflow:global_step/sec: 150.645
# INFO:tensorflow:loss = 57.2259, step = 19001 (0.661 sec)
# INFO:tensorflow:global_step/sec: 157.297
# INFO:tensorflow:loss = 52.327, step = 19101 (0.638 sec)
# INFO:tensorflow:Saving checkpoints for 19201 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.2423
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:08:43
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-19201
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:08:45
# INFO:tensorflow:Saving dict for global step 19201: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990925, auc_precision_recall = 0.991602, average_loss = 0.12184, global_step = 19201, label/mean = 0.5, loss = 60.92, prediction/mean = 0.499761
# INFO:tensorflow:Validation (step 19201): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990925, auc_precision_recall = 0.991602, average_loss = 0.12184, label/mean = 0.5, loss = 60.92, prediction/mean = 0.499761, global_step = 19201
# INFO:tensorflow:loss = 44.078, step = 19201 (6.746 sec)
# INFO:tensorflow:global_step/sec: 20.6189
# INFO:tensorflow:loss = 49.0712, step = 19301 (0.591 sec)
# INFO:tensorflow:global_step/sec: 164.244
# INFO:tensorflow:loss = 65.2483, step = 19401 (0.604 sec)
# INFO:tensorflow:global_step/sec: 180.196
# INFO:tensorflow:loss = 41.6333, step = 19501 (0.556 sec)
# INFO:tensorflow:global_step/sec: 188.942
# INFO:tensorflow:loss = 70.4016, step = 19601 (0.529 sec)
# INFO:tensorflow:global_step/sec: 163.018
# INFO:tensorflow:loss = 46.5377, step = 19701 (0.612 sec)
# INFO:tensorflow:global_step/sec: 169.309
# INFO:tensorflow:loss = 46.9032, step = 19801 (0.592 sec)
# INFO:tensorflow:global_step/sec: 150.713
# INFO:tensorflow:loss = 46.2393, step = 19901 (0.665 sec)
# INFO:tensorflow:global_step/sec: 147.718
# INFO:tensorflow:loss = 33.4292, step = 20001 (0.675 sec)
# INFO:tensorflow:global_step/sec: 149.448
# INFO:tensorflow:loss = 51.4318, step = 20101 (0.670 sec)
# INFO:tensorflow:global_step/sec: 149.149
# INFO:tensorflow:loss = 60.9859, step = 20201 (0.674 sec)
# INFO:tensorflow:global_step/sec: 148.347
# INFO:tensorflow:loss = 52.5739, step = 20301 (0.670 sec)
# INFO:tensorflow:global_step/sec: 144.879
# INFO:tensorflow:loss = 50.3749, step = 20401 (0.690 sec)
# INFO:tensorflow:global_step/sec: 150.849
# INFO:tensorflow:loss = 48.6444, step = 20501 (0.665 sec)
# INFO:tensorflow:global_step/sec: 150.046
# INFO:tensorflow:loss = 48.185, step = 20601 (0.666 sec)
# INFO:tensorflow:global_step/sec: 158.397
# INFO:tensorflow:loss = 53.1283, step = 20701 (0.630 sec)
# INFO:tensorflow:global_step/sec: 152.197
# INFO:tensorflow:loss = 56.8052, step = 20801 (0.657 sec)
# INFO:tensorflow:global_step/sec: 162.953
# INFO:tensorflow:loss = 51.5109, step = 20901 (0.615 sec)
# INFO:tensorflow:global_step/sec: 147.792
# INFO:tensorflow:loss = 52.3609, step = 21001 (0.675 sec)
# INFO:tensorflow:global_step/sec: 155.692
# INFO:tensorflow:loss = 55.9556, step = 21101 (0.642 sec)
# INFO:tensorflow:global_step/sec: 179.534
# INFO:tensorflow:loss = 51.1583, step = 21201 (0.556 sec)
# INFO:tensorflow:global_step/sec: 199.339
# INFO:tensorflow:loss = 58.6974, step = 21301 (0.502 sec)
# INFO:tensorflow:global_step/sec: 200.727
# INFO:tensorflow:loss = 46.9463, step = 21401 (0.497 sec)
# INFO:tensorflow:global_step/sec: 206.598
# INFO:tensorflow:loss = 61.6762, step = 21501 (0.484 sec)
# INFO:tensorflow:Saving checkpoints for 21601 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 50.5
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:09:03
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-21601
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:09:04
# INFO:tensorflow:Saving dict for global step 21601: accuracy = 0.951667, accuracy_baseline = 0.5, auc = 0.990969, auc_precision_recall = 0.991605, average_loss = 0.121861, global_step = 21601, label/mean = 0.5, loss = 60.9303, prediction/mean = 0.498808
# INFO:tensorflow:Validation (step 21601): accuracy = 0.951667, accuracy_baseline = 0.5, auc = 0.990969, auc_precision_recall = 0.991605, average_loss = 0.121861, label/mean = 0.5, loss = 60.9303, prediction/mean = 0.498808, global_step = 21601
# INFO:tensorflow:loss = 49.5881, step = 21601 (4.812 sec)
# INFO:tensorflow:global_step/sec: 28.7541
# INFO:tensorflow:loss = 43.3981, step = 21701 (0.649 sec)
# INFO:tensorflow:global_step/sec: 171.965
# INFO:tensorflow:loss = 59.7745, step = 21801 (0.579 sec)
# INFO:tensorflow:global_step/sec: 184.328
# INFO:tensorflow:loss = 47.4286, step = 21901 (0.543 sec)
# INFO:tensorflow:global_step/sec: 176.596
# INFO:tensorflow:loss = 52.8188, step = 22001 (0.568 sec)
# INFO:tensorflow:global_step/sec: 163.929
# INFO:tensorflow:loss = 54.1217, step = 22101 (0.609 sec)
# INFO:tensorflow:global_step/sec: 162.406
# INFO:tensorflow:loss = 46.0651, step = 22201 (0.616 sec)
# INFO:tensorflow:global_step/sec: 183.047
# INFO:tensorflow:loss = 62.771, step = 22301 (0.546 sec)
# INFO:tensorflow:global_step/sec: 159.167
# INFO:tensorflow:loss = 46.2049, step = 22401 (0.630 sec)
# INFO:tensorflow:global_step/sec: 193.958
# INFO:tensorflow:loss = 53.8034, step = 22501 (0.513 sec)
# INFO:tensorflow:global_step/sec: 173.205
# INFO:tensorflow:loss = 64.6988, step = 22601 (0.577 sec)
# INFO:tensorflow:global_step/sec: 162.533
# INFO:tensorflow:loss = 74.1382, step = 22701 (0.615 sec)
# INFO:tensorflow:global_step/sec: 168.841
# INFO:tensorflow:loss = 55.4112, step = 22801 (0.593 sec)
# INFO:tensorflow:global_step/sec: 167.679
# INFO:tensorflow:loss = 49.725, step = 22901 (0.595 sec)
# INFO:tensorflow:global_step/sec: 172.518
# INFO:tensorflow:loss = 52.0909, step = 23001 (0.581 sec)
# INFO:tensorflow:global_step/sec: 164.221
# INFO:tensorflow:loss = 53.1299, step = 23101 (0.608 sec)
# INFO:tensorflow:global_step/sec: 166.324
# INFO:tensorflow:loss = 41.5742, step = 23201 (0.601 sec)
# INFO:tensorflow:global_step/sec: 175.506
# INFO:tensorflow:loss = 63.9089, step = 23301 (0.569 sec)
# INFO:tensorflow:global_step/sec: 170.754
# INFO:tensorflow:loss = 50.7253, step = 23401 (0.587 sec)
# INFO:tensorflow:global_step/sec: 163.789
# INFO:tensorflow:loss = 49.1982, step = 23501 (0.610 sec)
# INFO:tensorflow:global_step/sec: 167.609
# INFO:tensorflow:loss = 42.5395, step = 23601 (0.597 sec)
# INFO:tensorflow:global_step/sec: 169.34
# INFO:tensorflow:loss = 62.4304, step = 23701 (0.591 sec)
# INFO:tensorflow:global_step/sec: 183.119
# INFO:tensorflow:loss = 56.8523, step = 23801 (0.545 sec)
# INFO:tensorflow:global_step/sec: 188.868
# INFO:tensorflow:loss = 62.437, step = 23901 (0.531 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 54.2932.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:09:22
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:09:23
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.991163, auc_precision_recall = 0.991653, average_loss = 0.121782, global_step = 24000, label/mean = 0.5, loss = 60.8909, prediction/mean = 0.497856
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"trained_models/class-model-01/export/Servo/temp-b'1510416564'/saved_model.pb"
# .......................................
# Experiment finished at 16:09:26
#
# Experiment elapsed time: 229.925823 seconds

# %% [markdown]
# ## 7. Evaluate the Model

# %%
TRAIN_SIZE = 12000
VALID_SIZE = 3000
TEST_SIZE = 5000
train_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

valid_input_fn = lambda: tfrecods_input_fn(files_name_pattern= VALID_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= VALID_SIZE)

test_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
print()
print("############################################################################################")
print("# Train Measures: {}".format(train_results))
print("############################################################################################")

valid_results = estimator.evaluate(input_fn=valid_input_fn, steps=1)
print()
print("############################################################################################")
print("# Valid Measures: {}".format(valid_results))
print("############################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print()
print("############################################################################################")
print("# Test Measures: {}".format(test_results))
print("############################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11c81d630>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/class-model-01'}
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 12000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:09:28
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:09:30
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.957917, accuracy_baseline = 0.5, auc = 0.993336, auc_precision_recall = 0.993439, average_loss = 0.104192, global_step = 24000, label/mean = 0.5, loss = 1250.3, prediction/mean = 0.502052
#
# ############################################################################################
# # Train Measures: {'accuracy': 0.95791668, 'accuracy_baseline': 0.5, 'auc': 0.9933362, 'auc_precision_recall': 0.9934386, 'average_loss': 0.10419194, 'label/mean': 0.5, 'loss': 1250.3032, 'prediction/mean': 0.50205207, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 3000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:09:32
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:09:33
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.991163, auc_precision_recall = 0.991653, average_loss = 0.121782, global_step = 24000, label/mean = 0.5, loss = 365.345, prediction/mean = 0.497856
#
# ############################################################################################
# # Valid Measures: {'accuracy': 0.95233333, 'accuracy_baseline': 0.5, 'auc': 0.99116331, 'auc_precision_recall': 0.99165344, 'average_loss': 0.12178176, 'label/mean': 0.5, 'loss': 365.34528, 'prediction/mean': 0.49785584, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-11-16:09:36
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-11-16:09:37
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.9524, accuracy_baseline = 0.5, auc = 0.990539, auc_precision_recall = 0.991224, average_loss = 0.123451, global_step = 24000, label/mean = 0.5, loss = 617.257, prediction/mean = 0.499188
#
# ############################################################################################
# # Test Measures: {'accuracy': 0.95240003, 'accuracy_baseline': 0.5, 'auc': 0.99053907, 'auc_precision_recall': 0.99122417, 'average_loss': 0.12345144, 'label/mean': 0.5, 'loss': 617.2572, 'prediction/mean': 0.49918783, 'global_step': 24000}
# ############################################################################################

# %% [markdown]
# ## 8. Prediction

# %%
import itertools

predict_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)


predictions = list(itertools.islice(estimator.predict(input_fn=predict_input_fn),5))

print("")
print("* Predicted Classes: {}".format(list(map(lambda item: item["class_ids"][0]
    ,predictions))))

print("* Predicted Probabilities: {}".format(list(map(lambda item: list(item["probabilities"])
    ,predictions))))
# Out:
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5
# Epoch Count: None
# Mode: infer
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
#
# * Predicted Classes: [0, 1, 1, 0, 1]
# * Predicted Probabilities: [[0.98284829, 0.017151766], [0.00044470496, 0.99955529], [0.00017617996, 0.99982387], [0.99743325, 0.0025667532], [0.010059897, 0.98994011]]
