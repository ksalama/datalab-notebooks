# %%
import tensorflow as tf
import numpy as np
from tensorflow import data
import shutil
import math
from datetime import datetime
from tensorflow.python.feature_column import feature_column

from tensorflow.contrib.learn import learn_runner
from tensorflow.contrib.learn import make_export_strategy

print(tf.__version__)
# Out:
# /Users/khalidsalama/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# 1.4.0

# %% [markdown]
# ## Steps to use the TF Experiment APIs
# 1. Define dataset **metadata**
# 2. Define **data input function** to read the data from .tfrecord files + **feature processing**
# 3. Create TF **feature columns** based on metadata + **extended feature columns**
# 4. Define an **estimator** (LinearCombinedDNNClassifier) with the required **feature columns (wide/deep) & parameters**
# 7. Run an **Experiment** with **learn_runner** to train, evaluate, and export the model
# 8. **Evaluate** the model using test data
# 9. Perform **predictions** & **serving** the exported model

# %%
MODEL_NAME = 'class-model-01'

TRAIN_DATA_FILES_PATTERN = 'data/train-*.tfrecords'
VALID_DATA_FILES_PATTERN = 'data/valid-*.tfrecords'
TEST_DATA_FILES_PATTERN = 'data/test-*.tfrecords'

RESUME_TRAINING = False
PROCESS_FEATURES = True
EXTEND_FEATURE_COLUMNS = True
MULTI_THREADING = True

# %% [markdown]
# ## 1. Define Dataset Metadata
# * tf.example feature names and defaults
# * Numeric and categorical feature names
# * Target feature name
# * Target feature labels
# * Unused features

# %%
HEADER = ['key','x','y','alpha','beta','target']
HEADER_DEFAULTS = [[0], [0.0], [0.0], ['NA'], ['NA'], [0.0]]

NUMERIC_FEATURE_NAMES = ['x', 'y']  

CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY = {'alpha':['ax01', 'ax02'], 'beta':['bx01', 'bx02']}
CATEGORICAL_FEATURE_NAMES = list(CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.keys())

FEATURE_NAMES = NUMERIC_FEATURE_NAMES + CATEGORICAL_FEATURE_NAMES

TARGET_NAME = 'target'

TARGET_LABELS = ['positive', 'negative']

UNUSED_FEATURE_NAMES = list(set(HEADER) - set(FEATURE_NAMES) - {TARGET_NAME})

print("Header: {}".format(HEADER))
print("Numeric Features: {}".format(NUMERIC_FEATURE_NAMES))
print("Categorical Features: {}".format(CATEGORICAL_FEATURE_NAMES))
print("Target: {} - labels: {}".format(TARGET_NAME, TARGET_LABELS))
print("Unused Features: {}".format(UNUSED_FEATURE_NAMES))
# Out:
# Header: ['key', 'x', 'y', 'alpha', 'beta', 'target']
# Numeric Features: ['x', 'y']
# Categorical Features: ['alpha', 'beta']
# Target: target - labels: ['positive', 'negative']
# Unused Features: ['key']

# %% [markdown]
# ## 2. Define Data Input Function
# * Input .tfrecords files name pattern
# * Use TF Dataset APIs to read and process the data
# * Parse tf.exmaples to feature tensors
# * Apply feature processing
# * Return (features, target) tensors

# %% [markdown]
# ### a. parsing and processing logic

# %%
def parse_tf_example(example_proto):

    feature_spec = {}

    for feature_name in NUMERIC_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(), dtype=tf.float32)
    
    for feature_name in CATEGORICAL_FEATURE_NAMES:
        feature_spec[feature_name] = tf.FixedLenFeature(shape=(), dtype=tf.string)
    
    feature_spec[TARGET_NAME] = tf.FixedLenFeature(shape=(), dtype=tf.string)

    parsed_features = tf.parse_example(serialized=example_proto, features=feature_spec)
    
    target = parsed_features.pop(TARGET_NAME)
    
    return parsed_features, target


def process_features(features):

    features["x_2"] = tf.square(features['x'])
    features["y_2"] = tf.square(features['y'])
    features["xy"] = tf.multiply(features['x'], features['y']) # features['x'] * features['y']
    features['dist_xy'] =  tf.sqrt(tf.squared_difference(features['x'],features['y']))
    
    return features

# %% [markdown]
# ### b. data pipeline input function

# %%
def tfrecods_input_fn(files_name_pattern, mode=tf.estimator.ModeKeys.EVAL, 
                 num_epochs=None, 
                 batch_size=200):
    
    shuffle = True if mode == tf.estimator.ModeKeys.TRAIN else False
    
    print("")
    print("* data input_fn:")
    print("================")
    print("Input file(s): {}".format(files_name_pattern))
    print("Batch size: {}".format(batch_size))
    print("Epoch Count: {}".format(num_epochs))
    print("Mode: {}".format(mode))
    print("Shuffle: {}".format(shuffle))
    print("================")
    print("")

    file_names = tf.matching_files(files_name_pattern)
    dataset = data.TFRecordDataset(filenames=file_names)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=2 * batch_size + 1)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(lambda tf_example: parse_tf_example(tf_example))
    
    if PROCESS_FEATURES:
        dataset = dataset.map(lambda features, target: (process_features(features), target))
        
    dataset = dataset.repeat(num_epochs)
    iterator = dataset.make_one_shot_iterator()
    
    features, target = iterator.get_next()
    return features, target

# %%
features, target = tfrecods_input_fn(files_name_pattern="")
print("Feature read from TFRecords: {}".format(list(features.keys())))
print("Target read from TFRecords: {}".format(target))
# Out:
# * data input_fn:
# ================
# Input file(s):
# Batch size: 200
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# Feature read from TFRecords: ['alpha', 'beta', 'x', 'y', 'x_2', 'y_2', 'xy', 'dist_xy']
# Target read from TFRecords: Tensor("IteratorGetNext:8", shape=(?,), dtype=string)

# %% [markdown]
# ## 3. Define Feature Columns

# %%
def extend_feature_columns(feature_columns, hparams):
    
    num_buckets = hparams.num_buckets
    embedding_size = hparams.embedding_size

    buckets = np.linspace(-3, 3, num_buckets).tolist()

    alpha_X_beta = tf.feature_column.crossed_column(
            [feature_columns['alpha'], feature_columns['beta']], 4)

    x_bucketized = tf.feature_column.bucketized_column(
            feature_columns['x'], boundaries=buckets)

    y_bucketized = tf.feature_column.bucketized_column(
            feature_columns['y'], boundaries=buckets)

    x_bucketized_X_y_bucketized = tf.feature_column.crossed_column(
           [x_bucketized, y_bucketized], num_buckets**2)

    x_bucketized_X_y_bucketized_embedded = tf.feature_column.embedding_column(
            x_bucketized_X_y_bucketized, dimension=embedding_size)


    feature_columns['alpha_X_beta'] = alpha_X_beta
    feature_columns['x_bucketized_X_y_bucketized'] = x_bucketized_X_y_bucketized
    feature_columns['x_bucketized_X_y_bucketized_embedded'] = x_bucketized_X_y_bucketized_embedded
    
    return feature_columns
    

def get_feature_columns(hparams):
    
    CONSTRUCTED_NUMERIC_FEATURES_NAMES = ['x_2', 'y_2', 'xy', 'dist_xy']
    all_numeric_feature_names = NUMERIC_FEATURE_NAMES.copy() 
    
    if PROCESS_FEATURES:
        all_numeric_feature_names += CONSTRUCTED_NUMERIC_FEATURES_NAMES

    numeric_columns = {feature_name: tf.feature_column.numeric_column(feature_name)
                       for feature_name in all_numeric_feature_names}

    categorical_column_with_vocabulary = \
        {item[0]: tf.feature_column.categorical_column_with_vocabulary_list(item[0], item[1])
         for item in CATEGORICAL_FEATURE_NAMES_WITH_VOCABULARY.items()}
        
    feature_columns = {}

    if numeric_columns is not None:
        feature_columns.update(numeric_columns)

    if categorical_column_with_vocabulary is not None:
        feature_columns.update(categorical_column_with_vocabulary)
    
    if EXTEND_FEATURE_COLUMNS:
        feature_columns = extend_feature_columns(feature_columns, hparams)
        
    return feature_columns

feature_columns = get_feature_columns(tf.contrib.training.HParams(num_buckets=5,embedding_size=3))
print("Feature Columns: {}".format(feature_columns))
# Out:
# Feature Columns: {'x': _NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y': _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'x_2': _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'y_2': _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'xy': _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'dist_xy': _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), 'alpha': _VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'beta': _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), 'alpha_X_beta': _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), 'x_bucketized_X_y_bucketized': _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), 'x_bucketized_X_y_bucketized_embedded': _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.5, 0.0, 1.5, 3.0))), hash_bucket_size=25, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x121edc7f0>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True)}

# %% [markdown]
# ## 4. Define an Estimator Creation Function

# %% [markdown]
# ### a. Get wide and deep feature columns
# * dense columns = numeric columns + embedding columns
# * categorical columns = vocabolary list columns + bucketized columns
# * sparse columns = hashed categorical columns + crossed columns
# * categorical columns => indicator columns
# * deep columns = dense columns + indicator columns
# * wide columns = categorical columns + sparse columns

# %%
def get_wide_deep_columns():
    
    feature_columns = list(get_feature_columns(hparams).values())
    
    dense_columns = list(
        filter(lambda column: isinstance(column, feature_column._NumericColumn) |
                              isinstance(column, feature_column._EmbeddingColumn),
               feature_columns
        )
    )

    categorical_columns = list(
        filter(lambda column: isinstance(column, feature_column._VocabularyListCategoricalColumn) |
                              isinstance(column, feature_column._BucketizedColumn),
                   feature_columns)
    )
    
    sparse_columns = list(
        filter(lambda column: isinstance(column,feature_column._HashedCategoricalColumn) |
                              isinstance(column, feature_column._CrossedColumn),
               feature_columns)
    )

    indicator_columns = list(
            map(lambda column: tf.feature_column.indicator_column(column),
                categorical_columns)
    )
    
    deep_feature_columns = dense_columns + indicator_columns
    wide_feature_columns = categorical_columns + sparse_columns
    
    return wide_feature_columns, deep_feature_columns

# %%
def create_estimator(run_config, hparams, print_desc=False):
    
    wide_feature_columns, deep_feature_columns = get_wide_deep_columns()
    
    estimator = tf.estimator.DNNLinearCombinedClassifier(
        
        n_classes= len(TARGET_LABELS),
        label_vocabulary=TARGET_LABELS,
        
        dnn_feature_columns = deep_feature_columns,
        linear_feature_columns = wide_feature_columns,
        
        dnn_hidden_units= hparams.hidden_units,
        
        dnn_optimizer= tf.train.AdamOptimizer(),
        
        dnn_activation_fn= tf.nn.elu,
        dnn_dropout= hparams.dropout_prob,
        
        config= run_config
    )
    
    if print_desc:
        print("")
        print("*Estimator Type:")
        print("================")
        print(type(estimator))
        print("")
        print("*deep columns:")
        print("==============")
        print(deep_feature_columns)
        print("")
        print("wide columns:")
        print("=============")
        print(wide_feature_columns)
        print("")
    
    return estimator

# %% [markdown]
# ## 5. Run Experiment

# %% [markdown]
# ### a. Define Experiment Function

# %%
def generate_experiment_fn(**experiment_args):

    def _experiment_fn(run_config, hparams):

        train_input_fn = lambda: tfrecods_input_fn(
            TRAIN_DATA_FILES_PATTERN,
            mode = tf.contrib.learn.ModeKeys.TRAIN,
            num_epochs=hparams.num_epochs,
            batch_size=hparams.batch_size
        )

        eval_input_fn = lambda: tfrecods_input_fn(
            VALID_DATA_FILES_PATTERN,
            mode=tf.contrib.learn.ModeKeys.EVAL,
            num_epochs=1,
            batch_size=hparams.batch_size
        )

        estimator = create_estimator(run_config, hparams, True)

        return tf.contrib.learn.Experiment(
            estimator,
            train_input_fn=train_input_fn,
            eval_input_fn=eval_input_fn,
            eval_steps=None,
            **experiment_args
        )

    return _experiment_fn

# %% [markdown]
# ### b. Set HParam and RunConfig

# %%
TRAIN_SIZE = 12000
NUM_EPOCHS = 1000
BATCH_SIZE = 500
NUM_EVAL = 10
CHECKPOINT_STEPS = int((TRAIN_SIZE/BATCH_SIZE) * (NUM_EPOCHS/NUM_EVAL))

hparams  = tf.contrib.training.HParams(
    num_epochs = NUM_EPOCHS,
    batch_size = BATCH_SIZE,
    hidden_units=[16, 12, 8],
    num_buckets = 6,
    embedding_size = 3,
    dropout_prob = 0.001)

model_dir = 'trained_models/{}'.format(MODEL_NAME)

run_config = tf.contrib.learn.RunConfig(
    save_checkpoints_steps=CHECKPOINT_STEPS,
    tf_random_seed=19830610,
    model_dir=model_dir
)

print(hparams)
print("Model Directory:", run_config.model_dir)
print("")
print("Dataset Size:", TRAIN_SIZE)
print("Batch Size:", BATCH_SIZE)
print("Steps per Epoch:",TRAIN_SIZE/BATCH_SIZE)
print("Total Steps:", (TRAIN_SIZE/BATCH_SIZE)*NUM_EPOCHS)
print("Required Evaluation Steps:", NUM_EVAL) 
print("That is 1 evaluation step after each",NUM_EPOCHS/NUM_EVAL," epochs")
print("Save Checkpoint After",CHECKPOINT_STEPS,"steps")
# Out:
# [('batch_size', 500), ('dropout_prob', 0.001), ('embedding_size', 3), ('hidden_units', [16, 12, 8]), ('num_buckets', 6), ('num_epochs', 1000)]
# Model Directory: trained_models/class-model-01
#
# Dataset Size: 12000
# Batch Size: 500
# Steps per Epoch: 24.0
# Total Steps: 24000.0
# Required Evaluation Steps: 10
# That is 1 evaluation step after each 100.0  epochs
# Save Checkpoint After 2400 steps

# %% [markdown]
# ### c. Define Serving Function

# %%
def csv_serving_input_fn():
    
    SERVING_HEADER = ['x','y','alpha','beta']
    SERVING_HEADER_DEFAULTS = [[0.0], [0.0], ['NA'], ['NA']]

    rows_string_tensor = tf.placeholder(dtype=tf.string,
                                         shape=[None],
                                         name='csv_rows')
    
    receiver_tensor = {'csv_rows': rows_string_tensor}

    row_columns = tf.expand_dims(rows_string_tensor, -1)
    columns = tf.decode_csv(row_columns, record_defaults=SERVING_HEADER_DEFAULTS)
    features = dict(zip(SERVING_HEADER, columns))

    return tf.estimator.export.ServingInputReceiver(
        process_features(features), receiver_tensor)

# %% [markdown]
# ### d. Run Experiment via learn_runner

# %%
if not RESUME_TRAINING:
    print("Removing previous artifacts...")
    shutil.rmtree(model_dir, ignore_errors=True)
else:
    print("Resuming training...") 


tf.logging.set_verbosity(tf.logging.INFO)

time_start = datetime.utcnow() 
print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
print(".......................................") 


learn_runner.run(
    experiment_fn=generate_experiment_fn(

        export_strategies=[make_export_strategy(
            csv_serving_input_fn,
            exports_to_keep=1
        )]
    ),
    run_config=run_config,
    schedule="train_and_evaluate",
    hparams=hparams
)

time_end = datetime.utcnow() 
print(".......................................")
print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
print("")
time_elapsed = time_end - time_start
print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
# Out:
# Removing previous artifacts...
# Experiment started at 10:47:36
# .......................................
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x121edc320>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/class-model-01'}
#
# *Estimator Type:
# ================
# <class 'tensorflow.python.estimator.canned.dnn_linear_combined.DNNLinearCombinedClassifier'>
#
# *deep columns:
# ==============
# [_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='x_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='y_2', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _NumericColumn(key='dist_xy', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), _EmbeddingColumn(categorical_column=_CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None), dimension=3, combiner='mean', initializer=<tensorflow.python.ops.init_ops.TruncatedNormal object at 0x121ed4a20>, ckpt_to_load_from=None, tensor_name_in_ckpt=None, max_norm=None, trainable=True), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), _IndicatorColumn(categorical_column=_VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0))]
#
# wide columns:
# =============
# [_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _CrossedColumn(keys=(_VocabularyListCategoricalColumn(key='alpha', vocabulary_list=('ax01', 'ax02'), dtype=tf.string, default_value=-1, num_oov_buckets=0), _VocabularyListCategoricalColumn(key='beta', vocabulary_list=('bx01', 'bx02'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), hash_bucket_size=4, hash_key=None), _CrossedColumn(keys=(_BucketizedColumn(source_column=_NumericColumn(key='x', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0)), _BucketizedColumn(source_column=_NumericColumn(key='y', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(-3.0, -1.8, -0.6000000000000001, 0.5999999999999996, 1.7999999999999998, 3.0))), hash_bucket_size=36, hash_key=None)]
#
# WARNING:tensorflow:RunConfig.uid (from tensorflow.contrib.learn.python.learn.estimators.run_config) is experimental and may change or be removed at any time, and without warning.
# WARNING:tensorflow:From /Users/khalidsalama/anaconda/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 500
# Epoch Count: 1000
# Mode: train
# Shuffle: True
# ================
#
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into trained_models/class-model-01/model.ckpt.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:47:50
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:47:51
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.545333, accuracy_baseline = 0.5, auc = 0.581047, auc_precision_recall = 0.544995, average_loss = 0.724384, global_step = 1, label/mean = 0.5, loss = 362.192, prediction/mean = 0.402139
# INFO:tensorflow:Validation (step 1): accuracy = 0.545333, accuracy_baseline = 0.5, auc = 0.581047, auc_precision_recall = 0.544995, average_loss = 0.724384, label/mean = 0.5, loss = 362.192, prediction/mean = 0.402139, global_step = 1
# INFO:tensorflow:loss = 367.798, step = 1
# INFO:tensorflow:global_step/sec: 16.6184
# INFO:tensorflow:loss = 300.208, step = 101 (0.757 sec)
# INFO:tensorflow:global_step/sec: 188.398
# INFO:tensorflow:loss = 211.619, step = 201 (0.531 sec)
# INFO:tensorflow:global_step/sec: 187.915
# INFO:tensorflow:loss = 162.349, step = 301 (0.532 sec)
# INFO:tensorflow:global_step/sec: 189.759
# INFO:tensorflow:loss = 124.463, step = 401 (0.528 sec)
# INFO:tensorflow:global_step/sec: 189.447
# INFO:tensorflow:loss = 122.562, step = 501 (0.526 sec)
# INFO:tensorflow:global_step/sec: 190.359
# INFO:tensorflow:loss = 83.5131, step = 601 (0.525 sec)
# INFO:tensorflow:global_step/sec: 185.999
# INFO:tensorflow:loss = 84.2995, step = 701 (0.538 sec)
# INFO:tensorflow:global_step/sec: 187.056
# INFO:tensorflow:loss = 65.9374, step = 801 (0.535 sec)
# INFO:tensorflow:global_step/sec: 190.496
# INFO:tensorflow:loss = 74.7193, step = 901 (0.525 sec)
# INFO:tensorflow:global_step/sec: 188.906
# INFO:tensorflow:loss = 80.7219, step = 1001 (0.530 sec)
# INFO:tensorflow:global_step/sec: 186.392
# INFO:tensorflow:loss = 66.1648, step = 1101 (0.536 sec)
# INFO:tensorflow:global_step/sec: 191.481
# INFO:tensorflow:loss = 54.1094, step = 1201 (0.522 sec)
# INFO:tensorflow:global_step/sec: 168.217
# INFO:tensorflow:loss = 53.8291, step = 1301 (0.596 sec)
# INFO:tensorflow:global_step/sec: 189.662
# INFO:tensorflow:loss = 59.0117, step = 1401 (0.526 sec)
# INFO:tensorflow:global_step/sec: 144.008
# INFO:tensorflow:loss = 67.3785, step = 1501 (0.698 sec)
# INFO:tensorflow:global_step/sec: 127.791
# INFO:tensorflow:loss = 68.933, step = 1601 (0.782 sec)
# INFO:tensorflow:global_step/sec: 139.866
# INFO:tensorflow:loss = 64.3857, step = 1701 (0.726 sec)
# INFO:tensorflow:global_step/sec: 119.694
# INFO:tensorflow:loss = 51.0939, step = 1801 (0.825 sec)
# INFO:tensorflow:global_step/sec: 145.07
# INFO:tensorflow:loss = 44.0319, step = 1901 (0.690 sec)
# INFO:tensorflow:global_step/sec: 141.173
# INFO:tensorflow:loss = 55.9877, step = 2001 (0.707 sec)
# INFO:tensorflow:global_step/sec: 137.617
# INFO:tensorflow:loss = 42.752, step = 2101 (0.727 sec)
# INFO:tensorflow:global_step/sec: 146.674
# INFO:tensorflow:loss = 59.587, step = 2201 (0.682 sec)
# INFO:tensorflow:global_step/sec: 143.356
# INFO:tensorflow:loss = 59.8185, step = 2301 (0.698 sec)
# INFO:tensorflow:Saving checkpoints for 2401 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 36.6322
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:48:12
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-2401
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:48:13
# INFO:tensorflow:Saving dict for global step 2401: accuracy = 0.948667, accuracy_baseline = 0.5, auc = 0.989728, auc_precision_recall = 0.99096, average_loss = 0.127021, global_step = 2401, label/mean = 0.5, loss = 63.5107, prediction/mean = 0.501595
# INFO:tensorflow:Validation (step 2401): accuracy = 0.948667, accuracy_baseline = 0.5, auc = 0.989728, auc_precision_recall = 0.99096, average_loss = 0.127021, label/mean = 0.5, loss = 63.5107, prediction/mean = 0.501595, global_step = 2401
# INFO:tensorflow:loss = 43.2125, step = 2401 (6.067 sec)
# INFO:tensorflow:global_step/sec: 24.899
# INFO:tensorflow:loss = 51.4669, step = 2501 (0.676 sec)
# INFO:tensorflow:global_step/sec: 161.76
# INFO:tensorflow:loss = 62.8036, step = 2601 (0.619 sec)
# INFO:tensorflow:global_step/sec: 157.281
# INFO:tensorflow:loss = 60.0741, step = 2701 (0.637 sec)
# INFO:tensorflow:global_step/sec: 121.359
# INFO:tensorflow:loss = 89.6466, step = 2801 (0.828 sec)
# INFO:tensorflow:global_step/sec: 112.265
# INFO:tensorflow:loss = 55.1014, step = 2901 (0.888 sec)
# INFO:tensorflow:global_step/sec: 123.958
# INFO:tensorflow:loss = 56.6122, step = 3001 (0.810 sec)
# INFO:tensorflow:global_step/sec: 117.189
# INFO:tensorflow:loss = 57.6482, step = 3101 (0.864 sec)
# INFO:tensorflow:global_step/sec: 107.788
# INFO:tensorflow:loss = 54.1119, step = 3201 (0.913 sec)
# INFO:tensorflow:global_step/sec: 142.283
# INFO:tensorflow:loss = 61.9126, step = 3301 (0.701 sec)
# INFO:tensorflow:global_step/sec: 136.632
# INFO:tensorflow:loss = 53.3086, step = 3401 (0.731 sec)
# INFO:tensorflow:global_step/sec: 182.479
# INFO:tensorflow:loss = 74.519, step = 3501 (0.547 sec)
# INFO:tensorflow:global_step/sec: 201.561
# INFO:tensorflow:loss = 53.2911, step = 3601 (0.497 sec)
# INFO:tensorflow:global_step/sec: 202.966
# INFO:tensorflow:loss = 56.8043, step = 3701 (0.493 sec)
# INFO:tensorflow:global_step/sec: 189.687
# INFO:tensorflow:loss = 50.6941, step = 3801 (0.527 sec)
# INFO:tensorflow:global_step/sec: 205.492
# INFO:tensorflow:loss = 63.9508, step = 3901 (0.486 sec)
# INFO:tensorflow:global_step/sec: 203.017
# INFO:tensorflow:loss = 68.9809, step = 4001 (0.492 sec)
# INFO:tensorflow:global_step/sec: 207.653
# INFO:tensorflow:loss = 58.1893, step = 4101 (0.482 sec)
# INFO:tensorflow:global_step/sec: 208.645
# INFO:tensorflow:loss = 47.9043, step = 4201 (0.479 sec)
# INFO:tensorflow:global_step/sec: 163.606
# INFO:tensorflow:loss = 54.2471, step = 4301 (0.615 sec)
# INFO:tensorflow:global_step/sec: 140.354
# INFO:tensorflow:loss = 40.7804, step = 4401 (0.710 sec)
# INFO:tensorflow:global_step/sec: 201.481
# INFO:tensorflow:loss = 48.1839, step = 4501 (0.496 sec)
# INFO:tensorflow:global_step/sec: 205.76
# INFO:tensorflow:loss = 73.7359, step = 4601 (0.486 sec)
# INFO:tensorflow:global_step/sec: 193.106
# INFO:tensorflow:loss = 54.733, step = 4701 (0.518 sec)
# INFO:tensorflow:Saving checkpoints for 4801 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 40.8083
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:48:33
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-4801
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:48:34
# INFO:tensorflow:Saving dict for global step 4801: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990318, auc_precision_recall = 0.991343, average_loss = 0.123601, global_step = 4801, label/mean = 0.5, loss = 61.8004, prediction/mean = 0.503371
# INFO:tensorflow:Validation (step 4801): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990318, auc_precision_recall = 0.991343, average_loss = 0.123601, label/mean = 0.5, loss = 61.8004, prediction/mean = 0.503371, global_step = 4801
# INFO:tensorflow:loss = 53.9156, step = 4801 (6.638 sec)
# INFO:tensorflow:global_step/sec: 21.3909
# INFO:tensorflow:loss = 55.8483, step = 4901 (0.487 sec)
# INFO:tensorflow:global_step/sec: 204.476
# INFO:tensorflow:loss = 40.7985, step = 5001 (0.490 sec)
# INFO:tensorflow:global_step/sec: 204.909
# INFO:tensorflow:loss = 54.558, step = 5101 (0.488 sec)
# INFO:tensorflow:global_step/sec: 202.069
# INFO:tensorflow:loss = 60.9781, step = 5201 (0.495 sec)
# INFO:tensorflow:global_step/sec: 204.239
# INFO:tensorflow:loss = 67.3702, step = 5301 (0.490 sec)
# INFO:tensorflow:global_step/sec: 204.127
# INFO:tensorflow:loss = 56.3291, step = 5401 (0.489 sec)
# INFO:tensorflow:global_step/sec: 206.488
# INFO:tensorflow:loss = 48.3456, step = 5501 (0.484 sec)
# INFO:tensorflow:global_step/sec: 203.556
# INFO:tensorflow:loss = 49.5535, step = 5601 (0.492 sec)
# INFO:tensorflow:global_step/sec: 198.441
# INFO:tensorflow:loss = 59.5464, step = 5701 (0.504 sec)
# INFO:tensorflow:global_step/sec: 197.207
# INFO:tensorflow:loss = 44.8572, step = 5801 (0.511 sec)
# INFO:tensorflow:global_step/sec: 172.551
# INFO:tensorflow:loss = 53.2054, step = 5901 (0.577 sec)
# INFO:tensorflow:global_step/sec: 181.03
# INFO:tensorflow:loss = 55.1002, step = 6001 (0.550 sec)
# INFO:tensorflow:global_step/sec: 202.298
# INFO:tensorflow:loss = 51.0697, step = 6101 (0.494 sec)
# INFO:tensorflow:global_step/sec: 205.331
# INFO:tensorflow:loss = 48.0757, step = 6201 (0.487 sec)
# INFO:tensorflow:global_step/sec: 205.77
# INFO:tensorflow:loss = 60.4919, step = 6301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 203.845
# INFO:tensorflow:loss = 64.6721, step = 6401 (0.491 sec)
# INFO:tensorflow:global_step/sec: 201.313
# INFO:tensorflow:loss = 40.0768, step = 6501 (0.497 sec)
# INFO:tensorflow:global_step/sec: 206.789
# INFO:tensorflow:loss = 45.7592, step = 6601 (0.483 sec)
# INFO:tensorflow:global_step/sec: 205.861
# INFO:tensorflow:loss = 60.6002, step = 6701 (0.486 sec)
# INFO:tensorflow:global_step/sec: 203.884
# INFO:tensorflow:loss = 55.0018, step = 6801 (0.494 sec)
# INFO:tensorflow:global_step/sec: 197.573
# INFO:tensorflow:loss = 56.4116, step = 6901 (0.502 sec)
# INFO:tensorflow:global_step/sec: 201.888
# INFO:tensorflow:loss = 50.9101, step = 7001 (0.496 sec)
# INFO:tensorflow:global_step/sec: 202.29
# INFO:tensorflow:loss = 56.9551, step = 7101 (0.494 sec)
# INFO:tensorflow:Saving checkpoints for 7201 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 49.5364
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:48:50
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-7201
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:48:52
# INFO:tensorflow:Saving dict for global step 7201: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990835, auc_precision_recall = 0.991604, average_loss = 0.12191, global_step = 7201, label/mean = 0.5, loss = 60.9548, prediction/mean = 0.499908
# INFO:tensorflow:Validation (step 7201): accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990835, auc_precision_recall = 0.991604, average_loss = 0.12191, label/mean = 0.5, loss = 60.9548, prediction/mean = 0.499908, global_step = 7201
# INFO:tensorflow:loss = 52.6766, step = 7201 (6.304 sec)
# INFO:tensorflow:global_step/sec: 19.9559
# INFO:tensorflow:loss = 59.5233, step = 7301 (0.732 sec)
# INFO:tensorflow:global_step/sec: 132.307
# INFO:tensorflow:loss = 54.5579, step = 7401 (0.752 sec)
# INFO:tensorflow:global_step/sec: 138.832
# INFO:tensorflow:loss = 47.1151, step = 7501 (0.719 sec)
# INFO:tensorflow:global_step/sec: 131.95
# INFO:tensorflow:loss = 59.0914, step = 7601 (0.763 sec)
# INFO:tensorflow:global_step/sec: 127.514
# INFO:tensorflow:loss = 44.9465, step = 7701 (0.782 sec)
# INFO:tensorflow:global_step/sec: 120.813
# INFO:tensorflow:loss = 49.3429, step = 7801 (0.828 sec)
# INFO:tensorflow:global_step/sec: 161.882
# INFO:tensorflow:loss = 50.571, step = 7901 (0.614 sec)
# INFO:tensorflow:global_step/sec: 145.843
# INFO:tensorflow:loss = 35.5534, step = 8001 (0.691 sec)
# INFO:tensorflow:global_step/sec: 152.191
# INFO:tensorflow:loss = 47.7327, step = 8101 (0.653 sec)
# INFO:tensorflow:global_step/sec: 158.159
# INFO:tensorflow:loss = 55.5154, step = 8201 (0.631 sec)
# INFO:tensorflow:global_step/sec: 173.279
# INFO:tensorflow:loss = 45.991, step = 8301 (0.576 sec)
# INFO:tensorflow:global_step/sec: 177.057
# INFO:tensorflow:loss = 47.9003, step = 8401 (0.564 sec)
# INFO:tensorflow:global_step/sec: 198.749
# INFO:tensorflow:loss = 56.759, step = 8501 (0.504 sec)
# INFO:tensorflow:global_step/sec: 182.828
# INFO:tensorflow:loss = 68.8786, step = 8601 (0.548 sec)
# INFO:tensorflow:global_step/sec: 163.002
# INFO:tensorflow:loss = 62.8279, step = 8701 (0.613 sec)
# INFO:tensorflow:global_step/sec: 185.434
# INFO:tensorflow:loss = 66.1603, step = 8801 (0.539 sec)
# INFO:tensorflow:global_step/sec: 136.639
# INFO:tensorflow:loss = 53.6692, step = 8901 (0.732 sec)
# INFO:tensorflow:global_step/sec: 186.351
# INFO:tensorflow:loss = 56.0062, step = 9001 (0.536 sec)
# INFO:tensorflow:global_step/sec: 182.181
# INFO:tensorflow:loss = 60.9664, step = 9101 (0.548 sec)
# INFO:tensorflow:global_step/sec: 199.446
# INFO:tensorflow:loss = 33.8594, step = 9201 (0.502 sec)
# INFO:tensorflow:global_step/sec: 197.628
# INFO:tensorflow:loss = 40.6498, step = 9301 (0.506 sec)
# INFO:tensorflow:global_step/sec: 167.179
# INFO:tensorflow:loss = 59.9937, step = 9401 (0.601 sec)
# INFO:tensorflow:global_step/sec: 195.628
# INFO:tensorflow:loss = 64.3405, step = 9501 (0.509 sec)
# INFO:tensorflow:Saving checkpoints for 9601 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 53.7176
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:49:10
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-9601
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:49:12
# INFO:tensorflow:Saving dict for global step 9601: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990895, auc_precision_recall = 0.991642, average_loss = 0.121633, global_step = 9601, label/mean = 0.5, loss = 60.8165, prediction/mean = 0.500383
# INFO:tensorflow:Validation (step 9601): accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.990895, auc_precision_recall = 0.991642, average_loss = 0.121633, label/mean = 0.5, loss = 60.8165, prediction/mean = 0.500383, global_step = 9601
# INFO:tensorflow:loss = 47.7602, step = 9601 (5.092 sec)
# INFO:tensorflow:global_step/sec: 26.4291
# INFO:tensorflow:loss = 63.218, step = 9701 (0.552 sec)
# INFO:tensorflow:global_step/sec: 190.492
# INFO:tensorflow:loss = 47.6366, step = 9801 (0.526 sec)
# INFO:tensorflow:global_step/sec: 179.792
# INFO:tensorflow:loss = 54.2859, step = 9901 (0.557 sec)
# INFO:tensorflow:global_step/sec: 101.847
# INFO:tensorflow:loss = 64.6654, step = 10001 (0.983 sec)
# INFO:tensorflow:global_step/sec: 187.233
# INFO:tensorflow:loss = 63.5053, step = 10101 (0.532 sec)
# INFO:tensorflow:global_step/sec: 144.83
# INFO:tensorflow:loss = 59.1471, step = 10201 (0.690 sec)
# INFO:tensorflow:global_step/sec: 194.061
# INFO:tensorflow:loss = 60.5707, step = 10301 (0.515 sec)
# INFO:tensorflow:global_step/sec: 193.979
# INFO:tensorflow:loss = 60.2314, step = 10401 (0.516 sec)
# INFO:tensorflow:global_step/sec: 193.212
# INFO:tensorflow:loss = 35.174, step = 10501 (0.519 sec)
# INFO:tensorflow:global_step/sec: 198.5
# INFO:tensorflow:loss = 45.5049, step = 10601 (0.503 sec)
# INFO:tensorflow:global_step/sec: 179.401
# INFO:tensorflow:loss = 61.0202, step = 10701 (0.557 sec)
# INFO:tensorflow:global_step/sec: 178.979
# INFO:tensorflow:loss = 41.4451, step = 10801 (0.559 sec)
# INFO:tensorflow:global_step/sec: 181.486
# INFO:tensorflow:loss = 65.7566, step = 10901 (0.550 sec)
# INFO:tensorflow:global_step/sec: 178.929
# INFO:tensorflow:loss = 54.438, step = 11001 (0.560 sec)
# INFO:tensorflow:global_step/sec: 190.342
# INFO:tensorflow:loss = 47.2766, step = 11101 (0.524 sec)
# INFO:tensorflow:global_step/sec: 176.425
# INFO:tensorflow:loss = 62.1429, step = 11201 (0.569 sec)
# INFO:tensorflow:global_step/sec: 182.891
# INFO:tensorflow:loss = 47.4337, step = 11301 (0.545 sec)
# INFO:tensorflow:global_step/sec: 140.915
# INFO:tensorflow:loss = 45.8335, step = 11401 (0.712 sec)
# INFO:tensorflow:global_step/sec: 127.033
# INFO:tensorflow:loss = 41.1917, step = 11501 (0.789 sec)
# INFO:tensorflow:global_step/sec: 150.61
# INFO:tensorflow:loss = 45.1506, step = 11601 (0.663 sec)
# INFO:tensorflow:global_step/sec: 168.823
# INFO:tensorflow:loss = 57.6406, step = 11701 (0.589 sec)
# INFO:tensorflow:global_step/sec: 194.927
# INFO:tensorflow:loss = 62.2266, step = 11801 (0.512 sec)
# INFO:tensorflow:global_step/sec: 184.942
# INFO:tensorflow:loss = 46.3194, step = 11901 (0.543 sec)
# INFO:tensorflow:Saving checkpoints for 12001 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 31.3855
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:49:31
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-12001
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:49:32
# INFO:tensorflow:Saving dict for global step 12001: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991, auc_precision_recall = 0.991695, average_loss = 0.121236, global_step = 12001, label/mean = 0.5, loss = 60.6179, prediction/mean = 0.49962
# INFO:tensorflow:Validation (step 12001): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991, auc_precision_recall = 0.991695, average_loss = 0.121236, label/mean = 0.5, loss = 60.6179, prediction/mean = 0.49962, global_step = 12001
# INFO:tensorflow:loss = 40.8159, step = 12001 (6.637 sec)
# INFO:tensorflow:global_step/sec: 24.4841
# INFO:tensorflow:loss = 37.4166, step = 12101 (0.633 sec)
# INFO:tensorflow:global_step/sec: 144.372
# INFO:tensorflow:loss = 50.3235, step = 12201 (0.691 sec)
# INFO:tensorflow:global_step/sec: 166.847
# INFO:tensorflow:loss = 52.2078, step = 12301 (0.600 sec)
# INFO:tensorflow:global_step/sec: 144.251
# INFO:tensorflow:loss = 58.3317, step = 12401 (0.696 sec)
# INFO:tensorflow:global_step/sec: 156.228
# INFO:tensorflow:loss = 56.406, step = 12501 (0.637 sec)
# INFO:tensorflow:global_step/sec: 168.088
# INFO:tensorflow:loss = 62.1642, step = 12601 (0.595 sec)
# INFO:tensorflow:global_step/sec: 166.348
# INFO:tensorflow:loss = 44.5875, step = 12701 (0.602 sec)
# INFO:tensorflow:global_step/sec: 145.226
# INFO:tensorflow:loss = 44.3237, step = 12801 (0.688 sec)
# INFO:tensorflow:global_step/sec: 152.835
# INFO:tensorflow:loss = 43.1127, step = 12901 (0.659 sec)
# INFO:tensorflow:global_step/sec: 141.284
# INFO:tensorflow:loss = 73.5175, step = 13001 (0.703 sec)
# INFO:tensorflow:global_step/sec: 185.312
# INFO:tensorflow:loss = 55.8118, step = 13101 (0.540 sec)
# INFO:tensorflow:global_step/sec: 193.255
# INFO:tensorflow:loss = 50.3784, step = 13201 (0.517 sec)
# INFO:tensorflow:global_step/sec: 191.034
# INFO:tensorflow:loss = 47.194, step = 13301 (0.523 sec)
# INFO:tensorflow:global_step/sec: 188.586
# INFO:tensorflow:loss = 43.2756, step = 13401 (0.530 sec)
# INFO:tensorflow:global_step/sec: 205.414
# INFO:tensorflow:loss = 55.137, step = 13501 (0.486 sec)
# INFO:tensorflow:global_step/sec: 199.952
# INFO:tensorflow:loss = 51.9417, step = 13601 (0.503 sec)
# INFO:tensorflow:global_step/sec: 154.705
# INFO:tensorflow:loss = 65.6125, step = 13701 (0.649 sec)
# INFO:tensorflow:global_step/sec: 178.809
# INFO:tensorflow:loss = 59.7105, step = 13801 (0.560 sec)
# INFO:tensorflow:global_step/sec: 144.432
# INFO:tensorflow:loss = 59.71, step = 13901 (0.690 sec)
# INFO:tensorflow:global_step/sec: 182.232
# INFO:tensorflow:loss = 41.7235, step = 14001 (0.547 sec)
# INFO:tensorflow:global_step/sec: 186.101
# INFO:tensorflow:loss = 62.3289, step = 14101 (0.539 sec)
# INFO:tensorflow:global_step/sec: 188.945
# INFO:tensorflow:loss = 53.7547, step = 14201 (0.527 sec)
# INFO:tensorflow:global_step/sec: 202.411
# INFO:tensorflow:loss = 54.4652, step = 14301 (0.494 sec)
# INFO:tensorflow:Saving checkpoints for 14401 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 49.3556
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:49:49
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-14401
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:49:51
# INFO:tensorflow:Saving dict for global step 14401: accuracy = 0.953667, accuracy_baseline = 0.5, auc = 0.990981, auc_precision_recall = 0.991663, average_loss = 0.121245, global_step = 14401, label/mean = 0.5, loss = 60.6223, prediction/mean = 0.499904
# INFO:tensorflow:Validation (step 14401): accuracy = 0.953667, accuracy_baseline = 0.5, auc = 0.990981, auc_precision_recall = 0.991663, average_loss = 0.121245, label/mean = 0.5, loss = 60.6223, prediction/mean = 0.499904, global_step = 14401
# INFO:tensorflow:loss = 51.5741, step = 14401 (5.336 sec)
# INFO:tensorflow:global_step/sec: 26.2275
# INFO:tensorflow:loss = 54.753, step = 14501 (0.503 sec)
# INFO:tensorflow:global_step/sec: 197.624
# INFO:tensorflow:loss = 61.0252, step = 14601 (0.505 sec)
# INFO:tensorflow:global_step/sec: 197.924
# INFO:tensorflow:loss = 64.008, step = 14701 (0.506 sec)
# INFO:tensorflow:global_step/sec: 199.452
# INFO:tensorflow:loss = 49.3189, step = 14801 (0.502 sec)
# INFO:tensorflow:global_step/sec: 184.76
# INFO:tensorflow:loss = 58.4319, step = 14901 (0.541 sec)
# INFO:tensorflow:global_step/sec: 186.713
# INFO:tensorflow:loss = 56.4073, step = 15001 (0.543 sec)
# INFO:tensorflow:global_step/sec: 164.189
# INFO:tensorflow:loss = 59.6387, step = 15101 (0.603 sec)
# INFO:tensorflow:global_step/sec: 163.461
# INFO:tensorflow:loss = 67.3168, step = 15201 (0.611 sec)
# INFO:tensorflow:global_step/sec: 190.427
# INFO:tensorflow:loss = 53.2103, step = 15301 (0.524 sec)
# INFO:tensorflow:global_step/sec: 188.992
# INFO:tensorflow:loss = 69.8954, step = 15401 (0.531 sec)
# INFO:tensorflow:global_step/sec: 152.9
# INFO:tensorflow:loss = 53.9213, step = 15501 (0.654 sec)
# INFO:tensorflow:global_step/sec: 194.226
# INFO:tensorflow:loss = 49.8122, step = 15601 (0.515 sec)
# INFO:tensorflow:global_step/sec: 186.664
# INFO:tensorflow:loss = 59.6161, step = 15701 (0.534 sec)
# INFO:tensorflow:global_step/sec: 140.358
# INFO:tensorflow:loss = 48.2354, step = 15801 (0.718 sec)
# INFO:tensorflow:global_step/sec: 155.075
# INFO:tensorflow:loss = 41.5582, step = 15901 (0.641 sec)
# INFO:tensorflow:global_step/sec: 149.359
# INFO:tensorflow:loss = 59.6899, step = 16001 (0.671 sec)
# INFO:tensorflow:global_step/sec: 150.744
# INFO:tensorflow:loss = 47.8183, step = 16101 (0.663 sec)
# INFO:tensorflow:global_step/sec: 159.216
# INFO:tensorflow:loss = 48.2806, step = 16201 (0.628 sec)
# INFO:tensorflow:global_step/sec: 166.292
# INFO:tensorflow:loss = 40.7605, step = 16301 (0.600 sec)
# INFO:tensorflow:global_step/sec: 150.195
# INFO:tensorflow:loss = 49.5315, step = 16401 (0.666 sec)
# INFO:tensorflow:global_step/sec: 154.046
# INFO:tensorflow:loss = 53.5297, step = 16501 (0.649 sec)
# INFO:tensorflow:global_step/sec: 158.848
# INFO:tensorflow:loss = 46.6379, step = 16601 (0.630 sec)
# INFO:tensorflow:global_step/sec: 145.65
# INFO:tensorflow:loss = 57.2792, step = 16701 (0.691 sec)
# INFO:tensorflow:Saving checkpoints for 16801 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 45.4343
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:50:09
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-16801
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:50:10
# INFO:tensorflow:Saving dict for global step 16801: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991002, auc_precision_recall = 0.99165, average_loss = 0.121367, global_step = 16801, label/mean = 0.5, loss = 60.6835, prediction/mean = 0.497748
# INFO:tensorflow:Validation (step 16801): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.991002, auc_precision_recall = 0.99165, average_loss = 0.121367, label/mean = 0.5, loss = 60.6835, prediction/mean = 0.497748, global_step = 16801
# INFO:tensorflow:loss = 42.8698, step = 16801 (5.983 sec)
# INFO:tensorflow:global_step/sec: 22.3484
# INFO:tensorflow:loss = 50.3401, step = 16901 (0.687 sec)
# INFO:tensorflow:global_step/sec: 187.654
# INFO:tensorflow:loss = 44.6719, step = 17001 (0.531 sec)
# INFO:tensorflow:global_step/sec: 151.064
# INFO:tensorflow:loss = 33.619, step = 17101 (0.670 sec)
# INFO:tensorflow:global_step/sec: 132.564
# INFO:tensorflow:loss = 58.4876, step = 17201 (0.750 sec)
# INFO:tensorflow:global_step/sec: 142.746
# INFO:tensorflow:loss = 70.57, step = 17301 (0.698 sec)
# INFO:tensorflow:global_step/sec: 178.948
# INFO:tensorflow:loss = 50.9063, step = 17401 (0.559 sec)
# INFO:tensorflow:global_step/sec: 186.37
# INFO:tensorflow:loss = 46.2028, step = 17501 (0.537 sec)
# INFO:tensorflow:global_step/sec: 174.24
# INFO:tensorflow:loss = 39.7614, step = 17601 (0.573 sec)
# INFO:tensorflow:global_step/sec: 160.345
# INFO:tensorflow:loss = 48.1493, step = 17701 (0.627 sec)
# INFO:tensorflow:global_step/sec: 149.074
# INFO:tensorflow:loss = 54.7027, step = 17801 (0.670 sec)
# INFO:tensorflow:global_step/sec: 151.484
# INFO:tensorflow:loss = 55.7525, step = 17901 (0.660 sec)
# INFO:tensorflow:global_step/sec: 155.052
# INFO:tensorflow:loss = 48.5197, step = 18001 (0.646 sec)
# INFO:tensorflow:global_step/sec: 149.306
# INFO:tensorflow:loss = 47.9747, step = 18101 (0.669 sec)
# INFO:tensorflow:global_step/sec: 146.729
# INFO:tensorflow:loss = 32.2431, step = 18201 (0.679 sec)
# INFO:tensorflow:global_step/sec: 183.433
# INFO:tensorflow:loss = 49.7439, step = 18301 (0.545 sec)
# INFO:tensorflow:global_step/sec: 192.058
# INFO:tensorflow:loss = 52.7422, step = 18401 (0.522 sec)
# INFO:tensorflow:global_step/sec: 179.263
# INFO:tensorflow:loss = 51.0026, step = 18501 (0.561 sec)
# INFO:tensorflow:global_step/sec: 167.667
# INFO:tensorflow:loss = 51.0279, step = 18601 (0.596 sec)
# INFO:tensorflow:global_step/sec: 126.023
# INFO:tensorflow:loss = 67.6928, step = 18701 (0.790 sec)
# INFO:tensorflow:global_step/sec: 157.161
# INFO:tensorflow:loss = 40.5942, step = 18801 (0.651 sec)
# INFO:tensorflow:global_step/sec: 161.489
# INFO:tensorflow:loss = 76.1572, step = 18901 (0.604 sec)
# INFO:tensorflow:global_step/sec: 174.659
# INFO:tensorflow:loss = 57.2259, step = 19001 (0.573 sec)
# INFO:tensorflow:global_step/sec: 171.235
# INFO:tensorflow:loss = 52.327, step = 19101 (0.584 sec)
# INFO:tensorflow:Saving checkpoints for 19201 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 46.9211
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:50:29
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-19201
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:50:30
# INFO:tensorflow:Saving dict for global step 19201: accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990925, auc_precision_recall = 0.991602, average_loss = 0.12184, global_step = 19201, label/mean = 0.5, loss = 60.92, prediction/mean = 0.499761
# INFO:tensorflow:Validation (step 19201): accuracy = 0.952667, accuracy_baseline = 0.5, auc = 0.990925, auc_precision_recall = 0.991602, average_loss = 0.12184, label/mean = 0.5, loss = 60.92, prediction/mean = 0.499761, global_step = 19201
# INFO:tensorflow:loss = 44.078, step = 19201 (5.545 sec)
# INFO:tensorflow:global_step/sec: 24.8626
# INFO:tensorflow:loss = 49.0712, step = 19301 (0.608 sec)
# INFO:tensorflow:global_step/sec: 145.232
# INFO:tensorflow:loss = 65.2483, step = 19401 (0.692 sec)
# INFO:tensorflow:global_step/sec: 171.492
# INFO:tensorflow:loss = 41.6333, step = 19501 (0.578 sec)
# INFO:tensorflow:global_step/sec: 151.576
# INFO:tensorflow:loss = 70.4016, step = 19601 (0.661 sec)
# INFO:tensorflow:global_step/sec: 147.299
# INFO:tensorflow:loss = 46.5377, step = 19701 (0.678 sec)
# INFO:tensorflow:global_step/sec: 190.115
# INFO:tensorflow:loss = 46.9032, step = 19801 (0.525 sec)
# INFO:tensorflow:global_step/sec: 192.531
# INFO:tensorflow:loss = 46.2393, step = 19901 (0.519 sec)
# INFO:tensorflow:global_step/sec: 193.22
# INFO:tensorflow:loss = 33.4292, step = 20001 (0.517 sec)
# INFO:tensorflow:global_step/sec: 196.5
# INFO:tensorflow:loss = 51.4318, step = 20101 (0.509 sec)
# INFO:tensorflow:global_step/sec: 192.817
# INFO:tensorflow:loss = 60.9859, step = 20201 (0.519 sec)
# INFO:tensorflow:global_step/sec: 193.571
# INFO:tensorflow:loss = 52.5739, step = 20301 (0.517 sec)
# INFO:tensorflow:global_step/sec: 188.946
# INFO:tensorflow:loss = 50.3749, step = 20401 (0.529 sec)
# INFO:tensorflow:global_step/sec: 192.756
# INFO:tensorflow:loss = 48.6444, step = 20501 (0.519 sec)
# INFO:tensorflow:global_step/sec: 199.813
# INFO:tensorflow:loss = 48.185, step = 20601 (0.501 sec)
# INFO:tensorflow:global_step/sec: 194.255
# INFO:tensorflow:loss = 53.1283, step = 20701 (0.515 sec)
# INFO:tensorflow:global_step/sec: 196.19
# INFO:tensorflow:loss = 56.8052, step = 20801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 196.178
# INFO:tensorflow:loss = 51.5109, step = 20901 (0.510 sec)
# INFO:tensorflow:global_step/sec: 201.576
# INFO:tensorflow:loss = 52.3609, step = 21001 (0.496 sec)
# INFO:tensorflow:global_step/sec: 194.644
# INFO:tensorflow:loss = 55.9556, step = 21101 (0.514 sec)
# INFO:tensorflow:global_step/sec: 192.953
# INFO:tensorflow:loss = 51.1583, step = 21201 (0.518 sec)
# INFO:tensorflow:global_step/sec: 195.408
# INFO:tensorflow:loss = 58.6974, step = 21301 (0.511 sec)
# INFO:tensorflow:global_step/sec: 197.416
# INFO:tensorflow:loss = 46.9463, step = 21401 (0.506 sec)
# INFO:tensorflow:global_step/sec: 196.085
# INFO:tensorflow:loss = 61.6762, step = 21501 (0.510 sec)
# INFO:tensorflow:Saving checkpoints for 21601 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:global_step/sec: 49.4375
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:50:47
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-21601
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:50:48
# INFO:tensorflow:Saving dict for global step 21601: accuracy = 0.951667, accuracy_baseline = 0.5, auc = 0.990969, auc_precision_recall = 0.991605, average_loss = 0.121861, global_step = 21601, label/mean = 0.5, loss = 60.9303, prediction/mean = 0.498808
# INFO:tensorflow:Validation (step 21601): accuracy = 0.951667, accuracy_baseline = 0.5, auc = 0.990969, auc_precision_recall = 0.991605, average_loss = 0.121861, label/mean = 0.5, loss = 60.9303, prediction/mean = 0.498808, global_step = 21601
# INFO:tensorflow:loss = 49.5881, step = 21601 (4.841 sec)
# INFO:tensorflow:global_step/sec: 29.4582
# INFO:tensorflow:loss = 43.3981, step = 21701 (0.578 sec)
# INFO:tensorflow:global_step/sec: 170.898
# INFO:tensorflow:loss = 59.7745, step = 21801 (0.585 sec)
# INFO:tensorflow:global_step/sec: 169.358
# INFO:tensorflow:loss = 47.4286, step = 21901 (0.591 sec)
# INFO:tensorflow:global_step/sec: 168.537
# INFO:tensorflow:loss = 52.8188, step = 22001 (0.593 sec)
# INFO:tensorflow:global_step/sec: 168.906
# INFO:tensorflow:loss = 54.1217, step = 22101 (0.592 sec)
# INFO:tensorflow:global_step/sec: 169.548
# INFO:tensorflow:loss = 46.0651, step = 22201 (0.590 sec)
# INFO:tensorflow:global_step/sec: 169.882
# INFO:tensorflow:loss = 62.771, step = 22301 (0.589 sec)
# INFO:tensorflow:global_step/sec: 171.153
# INFO:tensorflow:loss = 46.2049, step = 22401 (0.584 sec)
# INFO:tensorflow:global_step/sec: 167.095
# INFO:tensorflow:loss = 53.8034, step = 22501 (0.598 sec)
# INFO:tensorflow:global_step/sec: 166.805
# INFO:tensorflow:loss = 64.6988, step = 22601 (0.599 sec)
# INFO:tensorflow:global_step/sec: 169.347
# INFO:tensorflow:loss = 74.1382, step = 22701 (0.590 sec)
# INFO:tensorflow:global_step/sec: 168.25
# INFO:tensorflow:loss = 55.4112, step = 22801 (0.594 sec)
# INFO:tensorflow:global_step/sec: 169.304
# INFO:tensorflow:loss = 49.725, step = 22901 (0.591 sec)
# INFO:tensorflow:global_step/sec: 168.845
# INFO:tensorflow:loss = 52.0909, step = 23001 (0.593 sec)
# INFO:tensorflow:global_step/sec: 168.847
# INFO:tensorflow:loss = 53.1299, step = 23101 (0.592 sec)
# INFO:tensorflow:global_step/sec: 171.826
# INFO:tensorflow:loss = 41.5742, step = 23201 (0.581 sec)
# INFO:tensorflow:global_step/sec: 169.502
# INFO:tensorflow:loss = 63.9089, step = 23301 (0.590 sec)
# INFO:tensorflow:global_step/sec: 170.58
# INFO:tensorflow:loss = 50.7253, step = 23401 (0.587 sec)
# INFO:tensorflow:global_step/sec: 165.586
# INFO:tensorflow:loss = 49.1982, step = 23501 (0.603 sec)
# INFO:tensorflow:global_step/sec: 174.212
# INFO:tensorflow:loss = 42.5395, step = 23601 (0.574 sec)
# INFO:tensorflow:global_step/sec: 171.959
# INFO:tensorflow:loss = 62.4304, step = 23701 (0.581 sec)
# INFO:tensorflow:global_step/sec: 172.803
# INFO:tensorflow:loss = 56.8523, step = 23801 (0.579 sec)
# INFO:tensorflow:global_step/sec: 172.532
# INFO:tensorflow:loss = 62.437, step = 23901 (0.579 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into trained_models/class-model-01/model.ckpt.
# INFO:tensorflow:Loss for final step: 54.2932.
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 500
# Epoch Count: 1
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:51:05
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:51:06
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.991163, auc_precision_recall = 0.991653, average_loss = 0.121782, global_step = 24000, label/mean = 0.5, loss = 60.8909, prediction/mean = 0.497856
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"trained_models/class-model-01/export/Servo/temp-b'1510829467'/saved_model.pb"
# .......................................
# Experiment finished at 10:51:09
#
# Experiment elapsed time: 212.677442 seconds

# %% [markdown]
# ## 6. Evaluate the Model

# %%
TRAIN_SIZE = 12000
VALID_SIZE = 3000
TEST_SIZE = 5000
train_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TRAIN_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TRAIN_SIZE)

valid_input_fn = lambda: tfrecods_input_fn(files_name_pattern= VALID_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= VALID_SIZE)

test_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.EVAL,
                                      batch_size= TEST_SIZE)

estimator = create_estimator(run_config, hparams)

train_results = estimator.evaluate(input_fn=train_input_fn, steps=1)
print()
print("############################################################################################")
print("# Train Measures: {}".format(train_results))
print("############################################################################################")

valid_results = estimator.evaluate(input_fn=valid_input_fn, steps=1)
print()
print("############################################################################################")
print("# Valid Measures: {}".format(valid_results))
print("############################################################################################")

test_results = estimator.evaluate(input_fn=test_input_fn, steps=1)
print()
print("############################################################################################")
print("# Test Measures: {}".format(test_results))
print("############################################################################################")
# Out:
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x121edc320>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1
# }
# , '_tf_random_seed': 19830610, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_session_config': None, '_save_checkpoints_steps': 2400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': 'trained_models/class-model-01'}
#
# * data input_fn:
# ================
# Input file(s): data/train-*.tfrecords
# Batch size: 12000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:51:11
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:51:12
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.957917, accuracy_baseline = 0.5, auc = 0.993336, auc_precision_recall = 0.993439, average_loss = 0.104192, global_step = 24000, label/mean = 0.5, loss = 1250.3, prediction/mean = 0.502052
#
# ############################################################################################
# # Train Measures: {'accuracy': 0.95791668, 'accuracy_baseline': 0.5, 'auc': 0.9933362, 'auc_precision_recall': 0.9934386, 'average_loss': 0.10419194, 'label/mean': 0.5, 'loss': 1250.3032, 'prediction/mean': 0.50205207, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/valid-*.tfrecords
# Batch size: 3000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:51:14
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:51:15
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.952333, accuracy_baseline = 0.5, auc = 0.991163, auc_precision_recall = 0.991653, average_loss = 0.121782, global_step = 24000, label/mean = 0.5, loss = 365.345, prediction/mean = 0.497856
#
# ############################################################################################
# # Valid Measures: {'accuracy': 0.95233333, 'accuracy_baseline': 0.5, 'auc': 0.99116331, 'auc_precision_recall': 0.99165344, 'average_loss': 0.12178176, 'label/mean': 0.5, 'loss': 365.34528, 'prediction/mean': 0.49785584, 'global_step': 24000}
# ############################################################################################
#
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5000
# Epoch Count: None
# Mode: eval
# Shuffle: False
# ================
#
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-11-16-10:51:17
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2017-11-16-10:51:18
# INFO:tensorflow:Saving dict for global step 24000: accuracy = 0.9524, accuracy_baseline = 0.5, auc = 0.990539, auc_precision_recall = 0.991224, average_loss = 0.123451, global_step = 24000, label/mean = 0.5, loss = 617.257, prediction/mean = 0.499188
#
# ############################################################################################
# # Test Measures: {'accuracy': 0.95240003, 'accuracy_baseline': 0.5, 'auc': 0.99053907, 'auc_precision_recall': 0.99122417, 'average_loss': 0.12345144, 'label/mean': 0.5, 'loss': 617.2572, 'prediction/mean': 0.49918783, 'global_step': 24000}
# ############################################################################################

# %% [markdown]
# ## 7. Prediction

# %%
import itertools

predict_input_fn = lambda: tfrecods_input_fn(files_name_pattern= TEST_DATA_FILES_PATTERN, 
                                      mode= tf.estimator.ModeKeys.PREDICT,
                                      batch_size= 5)


predictions = list(itertools.islice(estimator.predict(input_fn=predict_input_fn),5))

print("")
print("* Predicted Classes: {}".format(list(map(lambda item: item["class_ids"][0]
    ,predictions))))

print("* Predicted Probabilities: {}".format(list(map(lambda item: list(item["probabilities"])
    ,predictions))))
# Out:
# * data input_fn:
# ================
# Input file(s): data/test-*.tfrecords
# Batch size: 5
# Epoch Count: None
# Mode: infer
# Shuffle: False
# ================
#
# WARNING:tensorflow:Input graph does not contain a QueueRunner. That means predict yields forever. This is probably a mistake.
# INFO:tensorflow:Restoring parameters from trained_models/class-model-01/model.ckpt-24000
#
# * Predicted Classes: [0, 1, 1, 0, 1]
# * Predicted Probabilities: [[0.98284829, 0.017151766], [0.00044470496, 0.99955529], [0.00017617996, 0.99982387], [0.99743325, 0.0025667532], [0.010059897, 0.98994011]]

# %% [markdown]
# ## Serving via the Saved Model

# %%
import os

export_dir = model_dir +"/export/Servo/"

saved_model_dir = export_dir + "/" + os.listdir(path=export_dir)[-1] 

print(saved_model_dir)

predictor_fn = tf.contrib.predictor.from_saved_model(
    export_dir = saved_model_dir,
    signature_def_key="predict"
)

output = predictor_fn({'csv_rows': ["0.5,1,ax01,bx02", "-0.5,-1,ax02,bx02"]})
print(output)
# Out:
# trained_models/class-model-01/export/Servo//1510829467
# INFO:tensorflow:Restoring parameters from b'trained_models/class-model-01/export/Servo//1510829467/variables/variables'
# {'logits': array([[ 6.35565805],
#        [ 6.37263775]], dtype=float32), 'logistic': array([[ 0.99826616],
#        [ 0.99829525]], dtype=float32), 'probabilities': array([[ 0.00173388,  0.99826616],
#        [ 0.00170474,  0.99829525]], dtype=float32), 'class_ids': array([[1],
#        [1]]), 'classes': array([[b'negative'],
#        [b'negative']], dtype=object)}
