# %%
# %%bash

# pip install -U protobuf
# pip install -U apache_beam

# %%
import pandas
import time
import datetime
from google.cloud import pubsub
import json
import apache_beam as beam
import os
print(beam.__version__)
# Out:
# 2.2.0
# No handlers could be found for logger "oauth2client.contrib.multistore_file"

# %%
TIME_FORMAT = '%Y-%m-%d %H:%M:%S'
RUNNER = "Dataflow"
PROJECT = 'ksalama-gcp-playground'
DATASET = 'playground_ds'
TABLE = 'babyweight_estimates'
STG_BUCKET = 'stagging-ksalama-gcs-cloudml'
REGION = 'europe-west1'
TOPIC = 'babyweights'
SUBSCRIPTION='babyweights-sub'

# %% [markdown]
# ## Submit Dataflow Stream Processing Job

# %%
pubsub_subscription = "projects/{}/subscriptions/{}".format(PROJECT,SUBSCRIPTION)
pubsub_topic = "projects/{}/topics/{}".format(PROJECT,TOPIC)

print(pubsub_subscription)
print(DATASET,TABLE)


def estimate_weight(json_message):
    
    PROJECT='ksalama-gcp-playground'
    MODEL_NAME='babyweight_estimator'
    VERSION='v1'
    
    import json
    from googleapiclient import discovery
    from oauth2client.client import GoogleCredentials
    
    credentials = GoogleCredentials.get_application_default()
    api = discovery.build('ml', 'v1', credentials=credentials,
                discoveryServiceUrl='https://storage.googleapis.com/cloud-ml/discovery/ml_v1_discovery.json')

    instance = json.loads(json_message)
    source_id = instance.pop('source_id')
    source_timestamp = instance.pop('source_timestamp')
    
    request_data = {'instances': [instance]}

    model_url = 'projects/{}/models/{}/versions/{}'.format(PROJECT, MODEL_NAME, VERSION)
    response = api.projects().predict(body=request_data, name=model_url).execute()

    estimates = list(map(lambda item: round(item["scores"],2)
        ,response["predictions"]
    ))
    
    estimated_weight_kg =  round(int(estimates[0]) * 0.453592,2)
    
    instance['estimated_weight_kg'] = estimated_weight_kg
    instance['source_id'] = source_id
    instance['source_timestamp'] = source_timestamp

    return instance

# def process_events(json_message):
#     import json
#     message = json.loads(json_message)
#     message['estimated_weight_kg'] = 7
#     return message
  
def run_babyweight_estimates_streaming_pipeline():
    
    job_name = 'ingest-babyweight-estimates-{}'.format(datetime.datetime.now().strftime('%y%m%d-%H%M%S'))
    print 'Launching Dataflow job {}'.format(job_name)
    print 'Check the Dataflow jobs on Google Cloud Console...'

    STG_DIR = 'gs://{}/babyweight'.format(STG_BUCKET)

    options = {
        'staging_location': os.path.join(STG_DIR, 'tmp', 'staging'),
        'temp_location': os.path.join(STG_DIR, 'tmp'),
        'job_name': job_name,
        'project': PROJECT,
        'streaming': True,
        'teardown_policy': 'TEARDOWN_ALWAYS',
        'no_save_main_session': True
      }


    opts = beam.pipeline.PipelineOptions(flags=[], **options)
    
    pipeline = beam.Pipeline(RUNNER, options=opts)
      
    (
      pipeline | 'Read data from PubSub' >> beam.io.ReadStringsFromPubSub(subscription=pubsub_subscription) 
               | 'Process message' >> beam.Map(estimate_weight)
               | 'Write to BigQuery' >> beam.io.WriteToBigQuery(project=PROJECT, dataset=DATASET, table=TABLE)
    )

    pipeline.run()
# Out:
# projects/ksalama-gcp-playground/subscriptions/babyweights-sub
# ('playground_ds', 'babyweight_estimates')

# %%
run_babyweight_estimates_streaming_pipeline()
# Out:
# Launching Dataflow job ingest-babyweight-estimates-180210-000925
# Check the Dataflow jobs on Google Cloud Console...

# %%
instances =  [
      {
        'is_male': 'True',
        'mother_age': 26.0,
        'mother_race': 'Asian Indian',
        'plurality': 1.0,
        'gestation_weeks': 39,
        'mother_married': 'True',
        'cigarette_use': 'False',
        'alcohol_use': 'False'
      },
      {
        'is_male': 'False',
        'mother_age': 29.0,
        'mother_race': 'Asian Indian',
        'plurality': 1.0,
        'gestation_weeks': 38,
        'mother_married': 'True',
        'cigarette_use': 'False',
        'alcohol_use': 'False'
      },
      {
        'is_male': 'True',
        'mother_age': 26.0,
        'mother_race': 'White',
        'plurality': 1.0,
        'gestation_weeks': 39,
        'mother_married': 'True',
        'cigarette_use': 'False',
        'alcohol_use': 'False'
      },
      {
        'is_male': 'True',
        'mother_age': 26.0,
        'mother_race': 'White',
        'plurality': 2.0,
        'gestation_weeks': 37,
        'mother_married': 'True',
        'cigarette_use': 'False',
        'alcohol_use': 'True'
      }
  ]

# %% [markdown]
# ## Send Data Points to PubSub

# %%
from random import shuffle

iterations = 100
sleep_time = 1

client = pubsub.Client()
topic = client.topic(TOPIC)

if not topic.exists():
    print ('Creating pub/sub topic {}...'.format(TOPIC))
    topic.create()

print ('Pub/sub topic {} is up and running'.format(TOPIC))
print("")

for i in range(iterations):
    
    shuffle(instances)
    
    for data_point in instances:
        
        source_timestamp = datetime.datetime.now().strftime(TIME_FORMAT)
        source_id = str(abs(hash(str(data_point)+str(source_timestamp))) % (10 ** 10))
        data_point['source_id'] = source_id
        data_point['source_timestamp'] = source_timestamp
        
        message = json.dumps(data_point)
        topic.publish(message=message, source_id = source_id, source_timestamp=source_timestamp)

    print("Batch {} was sent. Last Message was: {}".format(i, message))
    print("")

    time.sleep(sleep_time)

print("Done!")
# Out:
# Pub/sub topic babyweights is up and running
#
# Batch 0 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:44", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "1539574372", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 1 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:46", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3937756422", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 2 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:47", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "4943153006", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 3 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:48", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3559238402", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 4 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:50", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "8419014082", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 5 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:51", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "4813170524", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 6 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:52", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "6078908136", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 7 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:54", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "7212398937", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 8 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:55", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "9045281945", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 9 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:56", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3975703483", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 10 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:58", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "852557153", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 11 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:09:59", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "724304382", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 12 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:01", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "2585352492", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 13 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:02", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "4599551005", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 14 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:03", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "7062061712", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 15 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:04", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "4316429700", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 16 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:06", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "1268465035", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 17 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:07", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "7228630904", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 18 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:08", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "5376307715", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 19 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:09", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "2142842536", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 20 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:10", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "1059019444", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 21 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:12", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "316288320", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 22 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:13", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "9965201498", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 23 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:14", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "9185917688", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 24 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:16", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "8749757267", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 25 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:17", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "47050404", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 26 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:18", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "2078686308", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 27 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:20", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "2568825149", "mother_age": 26.0, "alcohol_use": "False"}
# Batch 28 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:21", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "4723452901", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 29 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:22", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "421366883", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 30 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:24", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "2729298372", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 31 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:25", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "2594688937", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 32 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:26", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3216330316", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 33 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:27", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "6390902567", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 34 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:29", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "4345212529", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 35 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:30", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "9561792058", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 36 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:32", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "9363699972", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 37 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:33", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "1233172288", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 38 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:35", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "7571622072", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 39 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:36", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "7569486473", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 40 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:38", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "4826534679", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 41 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:39", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "8837323672", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 42 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:40", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "8111572110", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 43 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:41", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "7971680239", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 44 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:42", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "9935792733", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 45 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:44", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "8568881846", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 46 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:45", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "8681358455", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 47 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:46", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "5785474803", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 48 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:47", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "829148012", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 49 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:49", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "9640701115", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 50 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:50", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3259136415", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 51 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:51", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "939809697", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 52 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:53", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "4687450969", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 53 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:54", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "955825511", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 54 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:55", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "3870082831", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 55 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:56", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "1546848332", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 56 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:58", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "2655498412", "mother_age": 26.0, "alcohol_use": "False"}
# Batch 57 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:10:59", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "653479650", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 58 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:00", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "4281173090", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 59 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:02", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "1864781930", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 60 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:03", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "1501191369", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 61 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:04", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "5901081683", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 62 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:06", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "7490065970", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 63 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:07", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "3661880720", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 64 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:09", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "3216555618", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 65 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:10", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "9581086183", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 66 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:11", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "6519029200", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 67 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:12", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3410551750", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 68 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:14", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "793261480", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 69 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:15", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "3894903603", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 70 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:16", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "4766824877", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 71 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:17", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "3626873259", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 72 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:19", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "7592297144", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 73 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:20", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "3833264546", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 74 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:21", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "9148859388", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 75 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:23", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "3538232405", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 76 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:24", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "1354898577", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 77 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:25", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "4435737350", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 78 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:27", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "2293250656", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 79 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:29", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "586855685", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 80 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:30", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "9158990946", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 81 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:31", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "4190053610", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 82 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:32", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "6665749272", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 83 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:33", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "8893258527", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 84 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:35", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "8696481976", "mother_age": 26.0, "alcohol_use": "True"}
# Batch 85 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:36", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "4241160443", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 86 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:37", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "8573732661", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 87 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:39", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "5709891883", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 88 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:40", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "837294285", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 89 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:41", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "5885958925", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 90 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:42", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "7959344489", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 91 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:43", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "8316272286", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 92 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:45", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "6764060863", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 93 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:46", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "224258363", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 94 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:47", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "744588279", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 95 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:48", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "7998936700", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 96 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:50", "plurality": 2.0, "gestation_weeks": 37, "mother_married": "True", "is_male": "True", "source_id": "8573834166", "mother_age": 26.0, "alcohol_use": "True"}
#
# Batch 97 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:51", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "5895707249", "mother_age": 29.0, "alcohol_use": "False"}
#
# Batch 98 was sent. Last Message was: {"mother_race": "White", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:53", "plurality": 1.0, "gestation_weeks": 39, "mother_married": "True", "is_male": "True", "source_id": "2918061624", "mother_age": 26.0, "alcohol_use": "False"}
#
# Batch 99 was sent. Last Message was: {"mother_race": "Asian Indian", "cigarette_use": "False", "source_timestamp": "2018-02-10 00:11:54", "plurality": 1.0, "gestation_weeks": 38, "mother_married": "True", "is_male": "False", "source_id": "9179822880", "mother_age": 29.0, "alcohol_use": "False"}
#
# Done!

# %% [markdown]
# ## Consume PubSub Topic

# %%
client = pubsub.Client()
topic = client.topic(TOPIC)
subscription = topic.subscription(SUBSCRIPTION)
message = subscription.pull()

# print(message[0][1].source_timestamp)
print("source_id", message[0][1].attributes["source_id"])
print("source_timestamp:", message[0][1].attributes["source_timestamp"])
print("")
print(message[0][1].data)
